# %%
# output folder, dist type, optional parameter for dist type

import sys
import os
import torch

cwd = os.getcwd()
root = cwd.split("BernsteinMartingaleNet")[0] + "BernsteinMartingaleNet"
if root not in sys.path:
    sys.path.append(root)

from lib.utils import train_model, get_full_sequence_data_by_day
from lib.BLogistic import BLogistic, MixedBLogistic
from lib.DistHead import NormalHead, StudentTHead, SkewedStudentTHead
from lib.Michenkow import MichenkowManytoMany
assert torch.cuda.is_available()
device = torch.device('cuda')

# %%
dist_type  = "BLogistic"
dist_param = "16"
output_folder =  root + f"/MichenkowResults/{dist_type}NoReg_NoRV/"

# %%
dist_head = None
if dist_type == "Normal":
    dist_head = NormalHead(device)
elif dist_type == "StudentT":
    dist_head = StudentTHead(device)
elif dist_type == "SkewedStudentT":
    dist_head = SkewedStudentTHead(device)
elif dist_type == "BLogistic":
    if dist_param == "":
        raise ValueError("BLogistic dist type requires a degree parameter")
    dof = int(dist_param)
    dist_head = BLogistic(dof - 2, device)
elif dist_type == "MixedBLogistic":
    if dist_param == "":
        raise ValueError("MixedBLogistic dist type requires a degree parameter")
    dof = int(dist_param)
    dist_head = MixedBLogistic(dof, device)
else:
    raise ValueError(f"Invalid dist type: {dist_type}")

folder_path = root + "/MarketData/historical_data"

# %%
train, dev, test = get_full_sequence_data_by_day(folder_path, 0.2, 0.2, force_recompute=True)
print("train", train.shape)
print("dev", dev.shape)
print("test", test.shape)
# Out:
# skipping 2020-11-27
# skipping 2020-12-24
# skipping 2021-11-26
# skipping 2022-11-25
# skipping 2023-07-03
# skipping 2023-11-24
# skipping 2024-07-03
# skipping 2024-11-29
# skipping 2024-12-24
# skipping 2025-07-03
# 1246
# train (748, 391, 3)
# dev (249, 391, 3)
# test (249, 391, 3)

# %%
train = torch.tensor(train, device=device)
dev = torch.tensor(dev, device=device)
test = torch.tensor(test, device=device)

train_xs = train[:, :-1, 0:1]
dev_xs = dev[:, :-1, 0:1]
test_xs = test[:, :-1, 0:1]

train_ys = train[:, 1:, 1]
dev_ys = dev[:, 1:, 1]
test_ys = test[:, 1:, 1]

std_x = torch.sqrt((train_xs**2).mean(dim=(0, 1)))  # Shape: (2,)
mean_x = train_xs.mean(dim=(0, 1))

print("std x:", std_x)
print("mean_x:", mean_x)

std_y = torch.sqrt((train_ys**2).mean(dim=(0, 1)))  # Shape: (2,)
mean_y = train_ys.mean(dim=(0, 1))

print("std y:", std_y)
print("mean y:", mean_y)

train_xs = (train_xs-mean_x) / std_x
dev_xs = (dev_xs-mean_x) / std_x
test_xs = (test_xs-mean_x) / std_x
train_ys = (train_ys-mean_y) / std_y
dev_ys = (dev_ys-mean_y) / std_y
test_ys = (test_ys-mean_y) / std_y

print("X train:", train_xs.shape, "y train", train_ys.shape)
print("X dev:", dev_xs.shape, "y dev", dev_ys.shape)
print("X test:", test_xs.shape, "y test", test_ys.shape)
# Out:
# std x: tensor([0.0004], device='cuda:0')
# mean_x: tensor([-2.3330e-07], device='cuda:0')
# std y: tensor(5.1853e-07, device='cuda:0')
# mean y: tensor(1.7846e-07, device='cuda:0')
# X train: torch.Size([748, 390, 1]) y train torch.Size([748, 390])
# X dev: torch.Size([249, 390, 1]) y dev torch.Size([249, 390])
# X test: torch.Size([249, 390, 1]) y test torch.Size([249, 390])

# %%
train = torch.tensor(train, device=device)
dev = torch.tensor(dev, device=device)
test = torch.tensor(test, device=device)

train_xs = train[:, :-1, 0:1]
dev_xs = dev[:, :-1, 0:1]
test_xs = test[:, :-1, 0:1]

train_ys = train[:, 1:, 0]
dev_ys = dev[:, 1:, 0]
test_ys = test[:, 1:, 0]

std_x = torch.sqrt((train_xs**2).mean(dim=(0, 1)))  # Shape: (2,)
mean_x = train_xs.mean(dim=(0, 1))

print("std x:", std_x)
print("mean_x:", mean_x)

std_y = torch.sqrt((train_ys**2).mean(dim=(0, 1)))  # Shape: (2,)
mean_y = train_ys.mean(dim=(0, 1))

print("std y:", std_y)
print("mean y:", mean_y)

train_xs = (train_xs-mean_x) / std_x
dev_xs = (dev_xs-mean_x) / std_x
test_xs = (test_xs-mean_x) / std_x
train_ys = (train_ys-mean_y) / std_y
dev_ys = (dev_ys-mean_y) / std_y
test_ys = (test_ys-mean_y) / std_y

print("X train:", train_xs.shape, "y train", train_ys.shape)
print("X dev:", dev_xs.shape, "y dev", dev_ys.shape)
print("X test:", test_xs.shape, "y test", test_ys.shape)
# Out:
# std x: tensor([0.0004], device='cuda:0')
# mean_x: tensor([-2.3330e-07], device='cuda:0')
# std y: tensor(0.0004, device='cuda:0')
# mean y: tensor(-2.1644e-07, device='cuda:0')
# X train: torch.Size([748, 390, 1]) y train torch.Size([748, 390])
# X dev: torch.Size([249, 390, 1]) y dev torch.Size([249, 390])
# X test: torch.Size([249, 390, 1]) y test torch.Size([249, 390])
# C:\Users\MainUser\AppData\Local\Temp\ipykernel_27960\426480493.py:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   train = torch.tensor(train, device=device)
# C:\Users\MainUser\AppData\Local\Temp\ipykernel_27960\426480493.py:2: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   dev = torch.tensor(dev, device=device)
# C:\Users\MainUser\AppData\Local\Temp\ipykernel_27960\426480493.py:3: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   test = torch.tensor(test, device=device)

# %%
lr = 0.002
decay_step = 200
decay_gamma = 0.5
weight_decay = 0
weight_decay = 0.000
num_steps = 400 + 1
batch_size = 1024

# %%
m2m_model = MichenkowManytoMany(dist_head, device, feature_size=1)

model, train_losses, dev_losses = train_model(m2m_model,
                                              train_xs, train_ys, dev_xs, dev_ys, test_xs,test_ys, lr, weight_decay, num_steps, batch_size=batch_size, device=device, output_folder=output_folder, lr_decay_step=decay_step, lr_decay_gamma=decay_gamma)
# Out:
# Initializing LSTM with dist=BLogistic, dof=16
# num batches 0
# Init, Train Loss: 1.3795, Dev Loss: 1.3826, Dev Loss confidence interval: 1.3779, 1.3872
# Step 0, Train Loss: 1.3745, Dev Loss: 1.3778, Dev Loss confidence interval: 1.3731, 1.3824, LR: 0.002000
# Step 10, Train Loss: 1.2665, Dev Loss: 1.2786, Dev Loss confidence interval: 1.2710, 1.2863, LR: 0.002000
# Step 20, Train Loss: 1.2611, Dev Loss: 1.2724, Dev Loss confidence interval: 1.2654, 1.2794, LR: 0.002000
# Step 30, Train Loss: 1.2564, Dev Loss: 1.2695, Dev Loss confidence interval: 1.2623, 1.2767, LR: 0.002000
# Step 40, Train Loss: 1.2548, Dev Loss: 1.2687, Dev Loss confidence interval: 1.2616, 1.2758, LR: 0.002000
# Step 50, Train Loss: 1.2504, Dev Loss: 1.2656, Dev Loss confidence interval: 1.2587, 1.2726, LR: 0.002000
# Step 60, Train Loss: 1.2419, Dev Loss: 1.2539, Dev Loss confidence interval: 1.2466, 1.2612, LR: 0.002000
# Step 70, Train Loss: 1.2445, Dev Loss: 1.2564, Dev Loss confidence interval: 1.2495, 1.2632, LR: 0.002000
# Step 80, Train Loss: 1.2441, Dev Loss: 1.2578, Dev Loss confidence interval: 1.2507, 1.2649, LR: 0.002000
# Step 90, Train Loss: 1.2513, Dev Loss: 1.2663, Dev Loss confidence interval: 1.2591, 1.2734, LR: 0.002000
# Step 100, Train Loss: 1.2502, Dev Loss: 1.2657, Dev Loss confidence interval: 1.2585, 1.2729, LR: 0.002000
# Step 110, Train Loss: 1.2512, Dev Loss: 1.2648, Dev Loss confidence interval: 1.2584, 1.2713, LR: 0.002000
# Step 120, Train Loss: 1.2510, Dev Loss: 1.2671, Dev Loss confidence interval: 1.2599, 1.2743, LR: 0.002000
# Step 130, Train Loss: 1.2465, Dev Loss: 1.2600, Dev Loss confidence interval: 1.2531, 1.2669, LR: 0.002000
# Step 140, Train Loss: 1.2339, Dev Loss: 1.2459, Dev Loss confidence interval: 1.2392, 1.2527, LR: 0.002000
# Step 150, Train Loss: 1.2355, Dev Loss: 1.2506, Dev Loss confidence interval: 1.2429, 1.2583, LR: 0.002000
# Step 160, Train Loss: 1.2381, Dev Loss: 1.2534, Dev Loss confidence interval: 1.2472, 1.2595, LR: 0.002000
# Step 170, Train Loss: 1.2101, Dev Loss: 1.2333, Dev Loss confidence interval: 1.2262, 1.2403, LR: 0.002000
# Step 180, Train Loss: 1.1961, Dev Loss: 1.2112, Dev Loss confidence interval: 1.2049, 1.2176, LR: 0.002000
# Step 190, Train Loss: 1.1888, Dev Loss: 1.2024, Dev Loss confidence interval: 1.1962, 1.2086, LR: 0.002000
# Step 200, Train Loss: 1.1535, Dev Loss: 1.1717, Dev Loss confidence interval: 1.1652, 1.1782, LR: 0.001000
# Step 210, Train Loss: 1.1319, Dev Loss: 1.1523, Dev Loss confidence interval: 1.1463, 1.1582, LR: 0.001000
# Step 220, Train Loss: 1.1162, Dev Loss: 1.1357, Dev Loss confidence interval: 1.1295, 1.1419, LR: 0.001000
# Step 230, Train Loss: 1.1067, Dev Loss: 1.1284, Dev Loss confidence interval: 1.1220, 1.1348, LR: 0.001000
# Step 240, Train Loss: 1.1027, Dev Loss: 1.1244, Dev Loss confidence interval: 1.1179, 1.1309, LR: 0.001000
# Step 250, Train Loss: 1.0993, Dev Loss: 1.1215, Dev Loss confidence interval: 1.1152, 1.1277, LR: 0.001000
# Step 260, Train Loss: 1.0968, Dev Loss: 1.1194, Dev Loss confidence interval: 1.1131, 1.1257, LR: 0.001000
# Step 270, Train Loss: 1.0949, Dev Loss: 1.1178, Dev Loss confidence interval: 1.1114, 1.1242, LR: 0.001000
# Step 280, Train Loss: 1.0938, Dev Loss: 1.1168, Dev Loss confidence interval: 1.1105, 1.1231, LR: 0.001000
# Step 290, Train Loss: 1.0924, Dev Loss: 1.1156, Dev Loss confidence interval: 1.1092, 1.1220, LR: 0.001000
# Step 300, Train Loss: 1.0918, Dev Loss: 1.1150, Dev Loss confidence interval: 1.1087, 1.1213, LR: 0.001000
# Step 310, Train Loss: 1.0908, Dev Loss: 1.1140, Dev Loss confidence interval: 1.1077, 1.1204, LR: 0.001000
# Step 320, Train Loss: 1.0901, Dev Loss: 1.1133, Dev Loss confidence interval: 1.1069, 1.1197, LR: 0.001000
# Step 330, Train Loss: 1.0895, Dev Loss: 1.1128, Dev Loss confidence interval: 1.1064, 1.1191, LR: 0.001000
# Step 340, Train Loss: 1.0891, Dev Loss: 1.1124, Dev Loss confidence interval: 1.1061, 1.1187, LR: 0.001000
# Step 350, Train Loss: 1.0885, Dev Loss: 1.1119, Dev Loss confidence interval: 1.1056, 1.1183, LR: 0.001000
# Step 360, Train Loss: 1.0882, Dev Loss: 1.1116, Dev Loss confidence interval: 1.1053, 1.1179, LR: 0.001000
# Step 370, Train Loss: 1.0876, Dev Loss: 1.1112, Dev Loss confidence interval: 1.1048, 1.1175, LR: 0.001000
# Step 380, Train Loss: 1.0871, Dev Loss: 1.1109, Dev Loss confidence interval: 1.1044, 1.1173, LR: 0.001000
# Step 390, Train Loss: 1.0868, Dev Loss: 1.1106, Dev Loss confidence interval: 1.1043, 1.1169, LR: 0.001000
# Step 400, Train Loss: 1.0863, Dev Loss: 1.1102, Dev Loss confidence interval: 1.1038, 1.1165, LR: 0.000500
# Best epoch: 400
# Final Train Loss: 1.0863, Final Train Loss confidence interval: 1.0826, 1.0901
# Final Dev Loss: 1.1102, Final Dev Loss confidence interval: 1.1037, 1.1167
# Test Loss: 1.0607, Test Loss confidence interval: 1.0540, 1.0675

# %%
import matplotlib.pyplot as plt
import numpy as np

steps = np.arange(0, len(train_losses) * 10, 10)  # Since you log every 10 steps

plt.figure(figsize=(10, 6))
plt.plot(steps, train_losses, label='Train Loss', linewidth=2)
plt.plot(steps, dev_losses, label='Dev Loss', linewidth=2)
plt.xlabel('Training Step')
plt.ylabel('Loss (Negative Log-Likelihood)')
plt.title(f"Training and Validation Loss of {dist_type}_NoReg_NoRV")
plt.legend()
plt.grid(True, alpha=0.3)
plt.axhline(y=0, color='r', linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()
