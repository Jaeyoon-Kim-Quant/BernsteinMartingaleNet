# %%
# output folder, dist type, optional parameter for dist type

import sys
import os
import torch

cwd = os.getcwd()
root = cwd.split("BernsteinMartingaleNet")[0] + "BernsteinMartingaleNet"
if root not in sys.path:
    sys.path.append(root)

from lib.utils import train_model, get_full_sequence_data_by_day
from lib.BLogistic import BLogistic, MixedBLogistic
from lib.DistHead import NormalHead, StudentTHead, SkewedStudentTHead
from lib.Michenkow import MichenkowManytoMany
assert torch.cuda.is_available()
device = torch.device('cuda')

# %%
dist_type  = "BLogistic"
dist_param = "16"
output_folder =  root + f"/MichenkowResults/{dist_type}NoReg_NoRV/"

# %%
dist_head = None
if dist_type == "Normal":
    dist_head = NormalHead(device)
elif dist_type == "StudentT":
    dist_head = StudentTHead(device)
elif dist_type == "SkewedStudentT":
    dist_head = SkewedStudentTHead(device)
elif dist_type == "BLogistic":
    if dist_param == "":
        raise ValueError("BLogistic dist type requires a degree parameter")
    dof = int(dist_param)
    dist_head = BLogistic(dof - 2, device)
elif dist_type == "MixedBLogistic":
    if dist_param == "":
        raise ValueError("MixedBLogistic dist type requires a degree parameter")
    dof = int(dist_param)
    dist_head = MixedBLogistic(dof, device)
else:
    raise ValueError(f"Invalid dist type: {dist_type}")

folder_path = root + "/MarketData/historical_data"

# %%
train, dev, test = get_full_sequence_data_by_day(folder_path, 0.2, 0.2, force_recompute=True)
print("train", train.shape)
print("dev", dev.shape)
print("test", test.shape)
# Out:
# skipping 2020-11-27
# skipping 2020-12-24
# skipping 2021-11-26
# skipping 2022-11-25
# skipping 2023-07-03
# skipping 2023-11-24
# skipping 2024-07-03
# skipping 2024-11-29
# skipping 2024-12-24
# skipping 2025-07-03
# 1246
# train (748, 391, 3)
# dev (249, 391, 3)
# test (249, 391, 3)

# %%
train = torch.tensor(train, device=device)
dev = torch.tensor(dev, device=device)
test = torch.tensor(test, device=device)

train_xs = train[:, :-1, 0:1]
dev_xs = dev[:, :-1, 0:1]
test_xs = test[:, :-1, 0:1]

train_ys = train[:, 1:, 1]
dev_ys = dev[:, 1:, 1]
test_ys = test[:, 1:, 1]

std_x = torch.sqrt((train_xs**2).mean(dim=(0, 1)))  # Shape: (2,)
mean_x = train_xs.mean(dim=(0, 1))

print("std x:", std_x)
print("mean_x:", mean_x)

std_y = torch.sqrt((train_ys**2).mean(dim=(0, 1)))  # Shape: (2,)
mean_y = train_ys.mean(dim=(0, 1))

print("std y:", std_y)
print("mean y:", mean_y)

train_xs = (train_xs-mean_x) / std_x
dev_xs = (dev_xs-mean_x) / std_x
test_xs = (test_xs-mean_x) / std_x
train_ys = (train_ys-mean_y) / std_y
dev_ys = (dev_ys-mean_y) / std_y
test_ys = (test_ys-mean_y) / std_y

print("X train:", train_xs.shape, "y train", train_ys.shape)
print("X dev:", dev_xs.shape, "y dev", dev_ys.shape)
print("X test:", test_xs.shape, "y test", test_ys.shape)
# Out:
# std x: tensor([0.0004], device='cuda:0')
# mean_x: tensor([-2.3330e-07], device='cuda:0')
# std y: tensor(5.1853e-07, device='cuda:0')
# mean y: tensor(1.7846e-07, device='cuda:0')
# X train: torch.Size([748, 390, 1]) y train torch.Size([748, 390])
# X dev: torch.Size([249, 390, 1]) y dev torch.Size([249, 390])
# X test: torch.Size([249, 390, 1]) y test torch.Size([249, 390])

# %%
train = torch.tensor(train, device=device)
dev = torch.tensor(dev, device=device)
test = torch.tensor(test, device=device)

train_xs = train[:, :-1, 0:1]
dev_xs = dev[:, :-1, 0:1]
test_xs = test[:, :-1, 0:1]

train_ys = train[:, 1:, 1]
dev_ys = dev[:, 1:, 1]
test_ys = test[:, 1:, 1]

std_x = torch.sqrt((train_xs**2).mean(dim=(0, 1)))  # Shape: (2,)
mean_x = train_xs.mean(dim=(0, 1))

print("std x:", std_x)
print("mean_x:", mean_x)

std_y = torch.sqrt((train_ys**2).mean(dim=(0, 1)))  # Shape: (2,)
mean_y = train_ys.mean(dim=(0, 1))

print("std y:", std_y)
print("mean y:", mean_y)

train_xs = (train_xs-mean_x) / std_x
dev_xs = (dev_xs-mean_x) / std_x
test_xs = (test_xs-mean_x) / std_x
train_ys = (train_ys-mean_y) / std_y
dev_ys = (dev_ys-mean_y) / std_y
test_ys = (test_ys-mean_y) / std_y

print("X train:", train_xs.shape, "y train", train_ys.shape)
print("X dev:", dev_xs.shape, "y dev", dev_ys.shape)
print("X test:", test_xs.shape, "y test", test_ys.shape)
# Out:
# std x: tensor([0.0004], device='cuda:0')
# mean_x: tensor([-2.3330e-07], device='cuda:0')
# std y: tensor(5.1853e-07, device='cuda:0')
# mean y: tensor(1.7846e-07, device='cuda:0')
# X train: torch.Size([748, 390, 1]) y train torch.Size([748, 390])
# X dev: torch.Size([249, 390, 1]) y dev torch.Size([249, 390])
# X test: torch.Size([249, 390, 1]) y test torch.Size([249, 390])
# C:\Users\MainUser\AppData\Local\Temp\ipykernel_27960\2556267257.py:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   train = torch.tensor(train, device=device)
# C:\Users\MainUser\AppData\Local\Temp\ipykernel_27960\2556267257.py:2: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   dev = torch.tensor(dev, device=device)
# C:\Users\MainUser\AppData\Local\Temp\ipykernel_27960\2556267257.py:3: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   test = torch.tensor(test, device=device)

# %%
lr = 0.002
decay_step = 200
decay_gamma = 0.5
weight_decay = 0
weight_decay = 0.000
num_steps = 400 + 1
batch_size = 1024

# %%
m2m_model = MichenkowManytoMany(dist_head, device, feature_size=1)

model, train_losses, dev_losses = train_model(m2m_model,
                                              train_xs, train_ys, dev_xs, dev_ys, test_xs,test_ys, lr, weight_decay, num_steps, batch_size=batch_size, device=device, output_folder=output_folder, lr_decay_step=decay_step, lr_decay_gamma=decay_gamma)
# Out:
# Initializing LSTM with dist=BLogistic, dof=16
# num batches 0
# Init, Train Loss: 1.1481, Dev Loss: 1.1253, Dev Loss confidence interval: 1.1217, 1.1289
# Step 0, Train Loss: 1.1374, Dev Loss: 1.1145, Dev Loss confidence interval: 1.1109, 1.1182, LR: 0.002000
# Step 10, Train Loss: 0.6603, Dev Loss: 0.6316, Dev Loss confidence interval: 0.6258, 0.6375, LR: 0.002000
# Step 20, Train Loss: 0.3596, Dev Loss: 0.3143, Dev Loss confidence interval: 0.3032, 0.3254, LR: 0.002000
# Step 30, Train Loss: 0.2368, Dev Loss: 0.2104, Dev Loss confidence interval: 0.2010, 0.2199, LR: 0.002000
# Step 40, Train Loss: 0.1837, Dev Loss: 0.1613, Dev Loss confidence interval: 0.1510, 0.1716, LR: 0.002000
# Step 50, Train Loss: 0.1127, Dev Loss: 0.1249, Dev Loss confidence interval: 0.1141, 0.1356, LR: 0.002000
# Step 60, Train Loss: 0.1004, Dev Loss: 0.1267, Dev Loss confidence interval: 0.1149, 0.1384, LR: 0.002000
# Step 70, Train Loss: 0.0993, Dev Loss: 0.1145, Dev Loss confidence interval: 0.1022, 0.1268, LR: 0.002000
# Step 80, Train Loss: 0.0954, Dev Loss: 0.1040, Dev Loss confidence interval: 0.0920, 0.1161, LR: 0.002000
# Step 90, Train Loss: 0.0875, Dev Loss: 0.0952, Dev Loss confidence interval: 0.0834, 0.1070, LR: 0.002000
# Step 100, Train Loss: 0.0615, Dev Loss: 0.0802, Dev Loss confidence interval: 0.0682, 0.0922, LR: 0.002000
# Step 110, Train Loss: 0.0246, Dev Loss: 0.0649, Dev Loss confidence interval: 0.0525, 0.0772, LR: 0.002000
# Step 120, Train Loss: -0.0217, Dev Loss: 0.0237, Dev Loss confidence interval: 0.0127, 0.0348, LR: 0.002000
# Step 130, Train Loss: -0.0045, Dev Loss: 0.0253, Dev Loss confidence interval: 0.0126, 0.0379, LR: 0.002000
# Step 140, Train Loss: -0.0186, Dev Loss: -0.0035, Dev Loss confidence interval: -0.0124, 0.0054, LR: 0.002000
# Step 150, Train Loss: -0.0405, Dev Loss: -0.0209, Dev Loss confidence interval: -0.0300, -0.0118, LR: 0.002000
# Step 160, Train Loss: -0.0646, Dev Loss: -0.0401, Dev Loss confidence interval: -0.0498, -0.0305, LR: 0.002000
# Step 170, Train Loss: -0.0999, Dev Loss: -0.0742, Dev Loss confidence interval: -0.0847, -0.0637, LR: 0.002000
# Step 180, Train Loss: -0.1773, Dev Loss: -0.1526, Dev Loss confidence interval: -0.1628, -0.1424, LR: 0.002000
# Step 190, Train Loss: -0.2245, Dev Loss: -0.1989, Dev Loss confidence interval: -0.2092, -0.1886, LR: 0.002000
# Step 200, Train Loss: -0.2655, Dev Loss: -0.2384, Dev Loss confidence interval: -0.2491, -0.2278, LR: 0.001000
# Step 210, Train Loss: -0.2805, Dev Loss: -0.2540, Dev Loss confidence interval: -0.2647, -0.2433, LR: 0.001000
# Step 220, Train Loss: -0.2926, Dev Loss: -0.2664, Dev Loss confidence interval: -0.2773, -0.2556, LR: 0.001000
# Step 230, Train Loss: -0.3045, Dev Loss: -0.2788, Dev Loss confidence interval: -0.2895, -0.2681, LR: 0.001000
# Step 240, Train Loss: -0.3149, Dev Loss: -0.2892, Dev Loss confidence interval: -0.2999, -0.2785, LR: 0.001000
# Step 250, Train Loss: -0.3225, Dev Loss: -0.2969, Dev Loss confidence interval: -0.3075, -0.2863, LR: 0.001000
# Step 260, Train Loss: -0.3311, Dev Loss: -0.3047, Dev Loss confidence interval: -0.3153, -0.2942, LR: 0.001000
# Step 270, Train Loss: -0.2990, Dev Loss: -0.2722, Dev Loss confidence interval: -0.2827, -0.2616, LR: 0.001000
# Step 280, Train Loss: -0.3371, Dev Loss: -0.3105, Dev Loss confidence interval: -0.3209, -0.3000, LR: 0.001000
# Step 290, Train Loss: -0.3439, Dev Loss: -0.3184, Dev Loss confidence interval: -0.3287, -0.3080, LR: 0.001000
# Step 300, Train Loss: -0.3482, Dev Loss: -0.3218, Dev Loss confidence interval: -0.3322, -0.3115, LR: 0.001000
# Step 310, Train Loss: -0.3514, Dev Loss: -0.3242, Dev Loss confidence interval: -0.3346, -0.3137, LR: 0.001000
# Step 320, Train Loss: -0.3571, Dev Loss: -0.3297, Dev Loss confidence interval: -0.3402, -0.3193, LR: 0.001000
# Step 330, Train Loss: -0.3602, Dev Loss: -0.3327, Dev Loss confidence interval: -0.3431, -0.3223, LR: 0.001000
# Step 340, Train Loss: -0.3641, Dev Loss: -0.3363, Dev Loss confidence interval: -0.3467, -0.3258, LR: 0.001000
# Step 350, Train Loss: -0.3667, Dev Loss: -0.3388, Dev Loss confidence interval: -0.3492, -0.3283, LR: 0.001000
# Step 360, Train Loss: -0.3697, Dev Loss: -0.3411, Dev Loss confidence interval: -0.3516, -0.3306, LR: 0.001000
# Step 370, Train Loss: -0.3723, Dev Loss: -0.3432, Dev Loss confidence interval: -0.3537, -0.3326, LR: 0.001000
# Step 380, Train Loss: -0.3745, Dev Loss: -0.3455, Dev Loss confidence interval: -0.3560, -0.3350, LR: 0.001000
# Step 390, Train Loss: -0.3774, Dev Loss: -0.3480, Dev Loss confidence interval: -0.3586, -0.3374, LR: 0.001000
# Step 400, Train Loss: -0.3783, Dev Loss: -0.3490, Dev Loss confidence interval: -0.3595, -0.3385, LR: 0.000500
# Best epoch: 400
# Final Train Loss: -0.3783, Final Train Loss confidence interval: -0.3847, -0.3720
# Final Dev Loss: -0.3490, Final Dev Loss confidence interval: -0.3597, -0.3383
# Test Loss: -0.3623, Test Loss confidence interval: -0.3793, -0.3453

# %%
import matplotlib.pyplot as plt
import numpy as np

steps = np.arange(0, len(train_losses) * 10, 10)  # Since you log every 10 steps

plt.figure(figsize=(10, 6))
plt.plot(steps, train_losses, label='Train Loss', linewidth=2)
plt.plot(steps, dev_losses, label='Dev Loss', linewidth=2)
plt.xlabel('Training Step')
plt.ylabel('Loss (Negative Log-Likelihood)')
plt.title(f"Training and Validation Loss of {dist_type}_NoReg_NoRV")
plt.legend()
plt.grid(True, alpha=0.3)
plt.axhline(y=0, color='r', linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()
