# %%
# output folder, dist type, optional parameter for dist type

import sys
import os
import torch

cwd = os.getcwd()
root = cwd.split("BernsteinMartingaleNet")[0] + "BernsteinMartingaleNet"
if root not in sys.path:
    sys.path.append(root)

from lib.utils import train_model, get_full_sequence_data_by_day
from lib.BLogistic import BLogistic, MixedBLogistic
from lib.DistHead import NormalHead, StudentTHead, SkewedStudentTHead
from lib.Michenkow import MichenkowManytoMany
assert torch.cuda.is_available()
device = torch.device('cuda')

# %%
dist_type  = "SkewedStudentT"
dist_param = ""
output_folder =  root + f"/MichenkowResults/{dist_type}NoReg_RV_Decay/"

# %%
dist_head = None
if dist_type == "Normal":
    dist_head = NormalHead(device)
elif dist_type == "StudentT":
    dist_head = StudentTHead(device)
elif dist_type == "SkewedStudentT":
    dist_head = SkewedStudentTHead(device)
elif dist_type == "BLogistic":
    if dist_param == "":
        raise ValueError("BLogistic dist type requires a degree parameter")
    dof = int(dist_param)
    dist_head = BLogistic(dof - 2, device)
elif dist_type == "MixedBLogistic":
    if dist_param == "":
        raise ValueError("MixedBLogistic dist type requires a degree parameter")
    dof = int(dist_param)
    dist_head = MixedBLogistic(dof, device)
else:
    raise ValueError(f"Invalid dist type: {dist_type}")

folder_path = root + "/MarketData/historical_data"

# %%
train, dev, test = get_full_sequence_data_by_day(folder_path, 0.2, 0.2, force_recompute=True)
print("train", train.shape)
print("dev", dev.shape)
print("test", test.shape)
# Out:
# skipping 2020-11-27
# skipping 2020-12-24
# skipping 2021-11-26
# skipping 2022-11-25
# skipping 2023-07-03
# skipping 2023-11-24
# skipping 2024-07-03
# skipping 2024-11-29
# skipping 2024-12-24
# skipping 2025-07-03
# train (748, 391, 3)
# dev (249, 391, 3)
# test (249, 391, 3)

# %%
train = torch.tensor(train, device=device)
dev = torch.tensor(dev, device=device)
test = torch.tensor(test, device=device)

train_xs = train[:, :-1, 0:3]
dev_xs = dev[:, :-1, 0:3]
test_xs = test[:, :-1, 0:3]

train_ys = train[:, 1:, 0]
dev_ys = dev[:, 1:, 0]
test_ys = test[:, 1:, 0]

std_x = torch.sqrt((train_xs**2).mean(dim=(0, 1)))  # Shape: (2,)
mean_x = train_xs.mean(dim=(0, 1))

print("std x:", std_x)
print("mean_x:", mean_x)

std_y = torch.sqrt((train_ys**2).mean(dim=(0, 1)))  # Shape: (2,)
mean_y = train_ys.mean(dim=(0, 1))

print("std y:", std_y)
print("mean y:", mean_y)

train_xs = (train_xs-mean_x) / std_x
dev_xs = (dev_xs-mean_x) / std_x
test_xs = (test_xs-mean_x) / std_x
train_ys = (train_ys-mean_y) / std_y
dev_ys = (dev_ys-mean_y) / std_y
test_ys = (test_ys-mean_y) / std_y

print("X train:", train_xs.shape, "y train", train_ys.shape)
print("X dev:", dev_xs.shape, "y dev", dev_ys.shape)
print("X test:", test_xs.shape, "y test", test_ys.shape)
# Out:
# std x: tensor([4.2369e-04, 5.0592e-07, 1.3484e+04], device='cuda:0')
# mean_x: tensor([-2.3330e-07,  1.7856e-07,  1.1670e+04], device='cuda:0')
# std y: tensor(0.0004, device='cuda:0')
# mean y: tensor(-2.1644e-07, device='cuda:0')
# X train: torch.Size([748, 390, 3]) y train torch.Size([748, 390])
# X dev: torch.Size([249, 390, 3]) y dev torch.Size([249, 390])
# X test: torch.Size([249, 390, 3]) y test torch.Size([249, 390])

# %%
lr = 0.002
decay_step = 200
decay_gamma = 0.5
weight_decay = 0
weight_decay = 0.000
num_steps = 400 + 1
batch_size = 1024

# %%
m2m_model = MichenkowManytoMany(dist_head, device, feature_size=train_xs.shape[2])

model, train_losses, dev_losses = train_model(m2m_model,
                                              train_xs, train_ys, dev_xs, dev_ys, test_xs,test_ys, lr, weight_decay, num_steps, batch_size=batch_size, device=device, output_folder=output_folder, lr_decay_step=decay_step, lr_decay_gamma=decay_gamma)
# Out:
# Initializing LSTM with dist=SkewedStudentTHead, dof=3
# num batches 0
# Init, Train Loss: 1.5413, Dev Loss: 1.5443, Dev Loss confidence interval: 1.5396, 1.5491
# Step 0, Train Loss: 1.5327, Dev Loss: 1.5359, Dev Loss confidence interval: 1.5311, 1.5407, LR: 0.002000
# Step 10, Train Loss: 1.2614, Dev Loss: 1.2804, Dev Loss confidence interval: 1.2737, 1.2871, LR: 0.002000
# Step 20, Train Loss: 1.2339, Dev Loss: 1.2593, Dev Loss confidence interval: 1.2523, 1.2663, LR: 0.002000
# Step 30, Train Loss: 1.2260, Dev Loss: 1.2491, Dev Loss confidence interval: 1.2422, 1.2560, LR: 0.002000
# Step 40, Train Loss: 1.2160, Dev Loss: 1.2413, Dev Loss confidence interval: 1.2343, 1.2484, LR: 0.002000
# Step 50, Train Loss: 1.1922, Dev Loss: 1.2133, Dev Loss confidence interval: 1.2065, 1.2201, LR: 0.002000
# Step 60, Train Loss: 1.1728, Dev Loss: 1.1961, Dev Loss confidence interval: 1.1890, 1.2032, LR: 0.002000
# Step 70, Train Loss: 1.1766, Dev Loss: 1.1990, Dev Loss confidence interval: 1.1928, 1.2051, LR: 0.002000
# Step 80, Train Loss: 1.1356, Dev Loss: 1.1561, Dev Loss confidence interval: 1.1495, 1.1626, LR: 0.002000
# Step 90, Train Loss: 1.1199, Dev Loss: 1.1423, Dev Loss confidence interval: 1.1357, 1.1488, LR: 0.002000
# Step 100, Train Loss: 1.1076, Dev Loss: 1.1297, Dev Loss confidence interval: 1.1232, 1.1362, LR: 0.002000
# Step 110, Train Loss: 1.1000, Dev Loss: 1.1225, Dev Loss confidence interval: 1.1162, 1.1288, LR: 0.002000
# Step 120, Train Loss: 1.0955, Dev Loss: 1.1179, Dev Loss confidence interval: 1.1116, 1.1242, LR: 0.002000
# Step 130, Train Loss: 1.0939, Dev Loss: 1.1163, Dev Loss confidence interval: 1.1102, 1.1224, LR: 0.002000
# Step 140, Train Loss: 1.0910, Dev Loss: 1.1135, Dev Loss confidence interval: 1.1073, 1.1196, LR: 0.002000
# Step 150, Train Loss: 1.0893, Dev Loss: 1.1118, Dev Loss confidence interval: 1.1055, 1.1180, LR: 0.002000
# Step 160, Train Loss: 1.0893, Dev Loss: 1.1119, Dev Loss confidence interval: 1.1059, 1.1180, LR: 0.002000
# Step 170, Train Loss: 1.0874, Dev Loss: 1.1101, Dev Loss confidence interval: 1.1040, 1.1163, LR: 0.002000
# Step 180, Train Loss: 1.0860, Dev Loss: 1.1087, Dev Loss confidence interval: 1.1026, 1.1149, LR: 0.002000
# Step 190, Train Loss: 1.0849, Dev Loss: 1.1077, Dev Loss confidence interval: 1.1014, 1.1140, LR: 0.002000
# Step 200, Train Loss: 1.0839, Dev Loss: 1.1067, Dev Loss confidence interval: 1.1005, 1.1129, LR: 0.001000
# Step 210, Train Loss: 1.0834, Dev Loss: 1.1063, Dev Loss confidence interval: 1.1001, 1.1125, LR: 0.001000
# Step 220, Train Loss: 1.0831, Dev Loss: 1.1060, Dev Loss confidence interval: 1.0998, 1.1121, LR: 0.001000
# Step 230, Train Loss: 1.0826, Dev Loss: 1.1055, Dev Loss confidence interval: 1.0993, 1.1117, LR: 0.001000
# Step 240, Train Loss: 1.0823, Dev Loss: 1.1052, Dev Loss confidence interval: 1.0990, 1.1114, LR: 0.001000
# Step 250, Train Loss: 1.0819, Dev Loss: 1.1048, Dev Loss confidence interval: 1.0986, 1.1110, LR: 0.001000
# Step 260, Train Loss: 1.0815, Dev Loss: 1.1045, Dev Loss confidence interval: 1.0983, 1.1107, LR: 0.001000
# Step 270, Train Loss: 1.0813, Dev Loss: 1.1043, Dev Loss confidence interval: 1.0981, 1.1104, LR: 0.001000
# Step 280, Train Loss: 1.0810, Dev Loss: 1.1041, Dev Loss confidence interval: 1.0979, 1.1102, LR: 0.001000
# Step 290, Train Loss: 1.0808, Dev Loss: 1.1038, Dev Loss confidence interval: 1.0977, 1.1100, LR: 0.001000
# Step 300, Train Loss: 1.0804, Dev Loss: 1.1035, Dev Loss confidence interval: 1.0973, 1.1097, LR: 0.001000
# Step 310, Train Loss: 1.0801, Dev Loss: 1.1032, Dev Loss confidence interval: 1.0969, 1.1094, LR: 0.001000
# Step 320, Train Loss: 1.0801, Dev Loss: 1.1032, Dev Loss confidence interval: 1.0971, 1.1094, LR: 0.001000
# Step 330, Train Loss: 1.0796, Dev Loss: 1.1027, Dev Loss confidence interval: 1.0966, 1.1089, LR: 0.001000
# Step 340, Train Loss: 1.0794, Dev Loss: 1.1026, Dev Loss confidence interval: 1.0963, 1.1089, LR: 0.001000
# Step 350, Train Loss: 1.0791, Dev Loss: 1.1023, Dev Loss confidence interval: 1.0961, 1.1085, LR: 0.001000
# Step 360, Train Loss: 1.0789, Dev Loss: 1.1021, Dev Loss confidence interval: 1.0959, 1.1083, LR: 0.001000
# Step 370, Train Loss: 1.0786, Dev Loss: 1.1019, Dev Loss confidence interval: 1.0957, 1.1081, LR: 0.001000
# Step 380, Train Loss: 1.0785, Dev Loss: 1.1018, Dev Loss confidence interval: 1.0957, 1.1080, LR: 0.001000
# Step 390, Train Loss: 1.0782, Dev Loss: 1.1015, Dev Loss confidence interval: 1.0953, 1.1077, LR: 0.001000
# Step 400, Train Loss: 1.0780, Dev Loss: 1.1013, Dev Loss confidence interval: 1.0951, 1.1075, LR: 0.000500
# Best epoch: 400
# Final Train Loss: 1.0780, Final Train Loss confidence interval: 1.0743, 1.0817
# Final Dev Loss: 1.1013, Final Dev Loss confidence interval: 1.0950, 1.1077
# Test Loss: 1.0499, Test Loss confidence interval: 1.0435, 1.0564

# %%
import matplotlib.pyplot as plt
import numpy as np

steps = np.arange(0, len(train_losses) * 10, 10)  # Since you log every 10 steps

plt.figure(figsize=(10, 6))
plt.plot(steps, train_losses, label='Train Loss', linewidth=2)
plt.plot(steps, dev_losses, label='Dev Loss', linewidth=2)
plt.xlabel('Training Step')
plt.ylabel('Loss (Negative Log-Likelihood)')
plt.title(f"Training and Validation Loss of {dist_type}_NoReg_RV_Decay")
plt.legend()
plt.grid(True, alpha=0.3)
plt.axhline(y=0, color='r', linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()
