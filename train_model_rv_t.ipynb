# %%
# output folder, dist type, optional parameter for dist type

import sys
import os
import torch

cwd = os.getcwd()
root = cwd.split("BernsteinMartingaleNet")[0] + "BernsteinMartingaleNet"
if root not in sys.path:
    sys.path.append(root)

from lib.utils import train_model, get_full_sequence_data_by_day
from lib.BLogistic import BLogistic, MixedBLogistic
from lib.DistHead import NormalHead, StudentTHead, SkewedStudentTHead
from lib.Michenkow import MichenkowManytoMany
assert torch.cuda.is_available()
device = torch.device('cuda')

# %%
dist_type  = "StudentT"
dist_param = ""
output_folder =  root + f"/MichenkowResults/{dist_type}NoReg_RV/"

# %%
dist_head = None
if dist_type == "Normal":
    dist_head = NormalHead(device)
elif dist_type == "StudentT":
    dist_head = StudentTHead(device)
elif dist_type == "SkewedStudentT":
    dist_head = SkewedStudentTHead(device)
elif dist_type == "BLogistic":
    if dist_param == "":
        raise ValueError("BLogistic dist type requires a degree parameter")
    dof = int(dist_param)
    dist_head = BLogistic(dof - 2, device)
elif dist_type == "MixedBLogistic":
    if dist_param == "":
        raise ValueError("MixedBLogistic dist type requires a degree parameter")
    dof = int(dist_param)
    dist_head = MixedBLogistic(dof, device)
else:
    raise ValueError(f"Invalid dist type: {dist_type}")

folder_path = root + "/MarketData/historical_data"

# %%
train, dev, test = get_full_sequence_data_by_day(folder_path, 0.2, 0.2, force_recompute=True)
print("train", train.shape)
print("dev", dev.shape)
print("test", test.shape)
# Out:
# skipping 2020-11-27
# skipping 2020-12-24
# skipping 2021-11-26
# skipping 2022-11-25
# skipping 2023-07-03
# skipping 2023-11-24
# skipping 2024-07-03
# skipping 2024-11-29
# skipping 2024-12-24
# skipping 2025-07-03
# train (748, 391, 3)
# dev (249, 391, 3)
# test (249, 391, 3)

# %%
train = torch.tensor(train, device=device)
dev = torch.tensor(dev, device=device)
test = torch.tensor(test, device=device)

train_xs = train[:, :-1, 0:2]
dev_xs = dev[:, :-1, 0:2]
test_xs = test[:, :-1, 0:2]

train_ys = train[:, 1:, 0]
dev_ys = dev[:, 1:, 0]
test_ys = test[:, 1:, 0]

std_x = torch.sqrt((train_xs**2).mean(dim=(0, 1)))  # Shape: (2,)
mean_x = train_xs.mean(dim=(0, 1))

print("std x:", std_x)
print("mean_x:", mean_x)

std_y = torch.sqrt((train_ys**2).mean(dim=(0, 1)))  # Shape: (2,)
mean_y = train_ys.mean(dim=(0, 1))

print("std y:", std_y)
print("mean y:", mean_y)

train_xs = (train_xs-mean_x) / std_x
dev_xs = (dev_xs-mean_x) / std_x
test_xs = (test_xs-mean_x) / std_x
train_ys = (train_ys-mean_y) / std_y
dev_ys = (dev_ys-mean_y) / std_y
test_ys = (test_ys-mean_y) / std_y

print("X train:", train_xs.shape, "y train", train_ys.shape)
print("X dev:", dev_xs.shape, "y dev", dev_ys.shape)
print("X test:", test_xs.shape, "y test", test_ys.shape)
# Out:
# std x: tensor([4.2369e-04, 5.0592e-07], device='cuda:0')
# mean_x: tensor([-2.3330e-07,  1.7856e-07], device='cuda:0')
# std y: tensor(0.0004, device='cuda:0')
# mean y: tensor(-2.1644e-07, device='cuda:0')
# X train: torch.Size([748, 390, 2]) y train torch.Size([748, 390])
# X dev: torch.Size([249, 390, 2]) y dev torch.Size([249, 390])
# X test: torch.Size([249, 390, 2]) y test torch.Size([249, 390])

# %%
lr = 0.002
decay_step = 200
decay_gamma = 0.5
weight_decay = 0
weight_decay = 0.000
num_steps = 400 + 1
batch_size = 1024

# %%
m2m_model = MichenkowManytoMany(dist_head, device, feature_size=2)

model, train_losses, dev_losses = train_model(m2m_model,
                                              train_xs, train_ys, dev_xs, dev_ys, test_xs,test_ys, lr, weight_decay, num_steps, batch_size=batch_size, device=device, output_folder=output_folder, lr_decay_step=decay_step, lr_decay_gamma=decay_gamma)
# Out:
# Initializing LSTM with dist=StudentTHead, dof=2
# num batches 0
# Init, Train Loss: 1.3045, Dev Loss: 1.3182, Dev Loss confidence interval: 1.3130, 1.3235
# Step 0, Train Loss: 1.3024, Dev Loss: 1.3162, Dev Loss confidence interval: 1.3110, 1.3215, LR: 0.002000
# Step 10, Train Loss: 1.2470, Dev Loss: 1.2713, Dev Loss confidence interval: 1.2640, 1.2786, LR: 0.002000
# Step 20, Train Loss: 1.1883, Dev Loss: 1.2091, Dev Loss confidence interval: 1.2032, 1.2150, LR: 0.002000
# Step 30, Train Loss: 1.1488, Dev Loss: 1.1718, Dev Loss confidence interval: 1.1653, 1.1782, LR: 0.002000
# Step 40, Train Loss: 1.1339, Dev Loss: 1.1566, Dev Loss confidence interval: 1.1500, 1.1633, LR: 0.002000
# Step 50, Train Loss: 1.1300, Dev Loss: 1.1530, Dev Loss confidence interval: 1.1466, 1.1594, LR: 0.002000
# Step 60, Train Loss: 1.1255, Dev Loss: 1.1487, Dev Loss confidence interval: 1.1423, 1.1551, LR: 0.002000
# Step 70, Train Loss: 1.1201, Dev Loss: 1.1434, Dev Loss confidence interval: 1.1369, 1.1499, LR: 0.002000
# Step 80, Train Loss: 1.1147, Dev Loss: 1.1380, Dev Loss confidence interval: 1.1315, 1.1444, LR: 0.002000
# Step 90, Train Loss: 1.1077, Dev Loss: 1.1308, Dev Loss confidence interval: 1.1244, 1.1372, LR: 0.002000
# Step 100, Train Loss: 1.0999, Dev Loss: 1.1227, Dev Loss confidence interval: 1.1164, 1.1291, LR: 0.002000
# Step 110, Train Loss: 1.0939, Dev Loss: 1.1166, Dev Loss confidence interval: 1.1104, 1.1228, LR: 0.002000
# Step 120, Train Loss: 1.0899, Dev Loss: 1.1125, Dev Loss confidence interval: 1.1063, 1.1188, LR: 0.002000
# Step 130, Train Loss: 1.0875, Dev Loss: 1.1103, Dev Loss confidence interval: 1.1041, 1.1165, LR: 0.002000
# Step 140, Train Loss: 1.0895, Dev Loss: 1.1127, Dev Loss confidence interval: 1.1061, 1.1192, LR: 0.002000
# Step 150, Train Loss: 1.0876, Dev Loss: 1.1103, Dev Loss confidence interval: 1.1043, 1.1164, LR: 0.002000
# Step 160, Train Loss: 1.0841, Dev Loss: 1.1072, Dev Loss confidence interval: 1.1009, 1.1135, LR: 0.002000
# Step 170, Train Loss: 1.0831, Dev Loss: 1.1063, Dev Loss confidence interval: 1.1001, 1.1124, LR: 0.002000
# Step 180, Train Loss: 1.0817, Dev Loss: 1.1051, Dev Loss confidence interval: 1.0989, 1.1112, LR: 0.002000
# Step 190, Train Loss: 1.0810, Dev Loss: 1.1044, Dev Loss confidence interval: 1.0982, 1.1106, LR: 0.002000
# Step 200, Train Loss: 1.0804, Dev Loss: 1.1039, Dev Loss confidence interval: 1.0977, 1.1101, LR: 0.001000
# Step 210, Train Loss: 1.0802, Dev Loss: 1.1037, Dev Loss confidence interval: 1.0975, 1.1099, LR: 0.001000
# Step 220, Train Loss: 1.0799, Dev Loss: 1.1035, Dev Loss confidence interval: 1.0973, 1.1097, LR: 0.001000
# Step 230, Train Loss: 1.0797, Dev Loss: 1.1034, Dev Loss confidence interval: 1.0972, 1.1095, LR: 0.001000
# Step 240, Train Loss: 1.0795, Dev Loss: 1.1032, Dev Loss confidence interval: 1.0970, 1.1093, LR: 0.001000
# Step 250, Train Loss: 1.0793, Dev Loss: 1.1030, Dev Loss confidence interval: 1.0968, 1.1092, LR: 0.001000
# Step 260, Train Loss: 1.0790, Dev Loss: 1.1028, Dev Loss confidence interval: 1.0966, 1.1090, LR: 0.001000
# Step 270, Train Loss: 1.0789, Dev Loss: 1.1027, Dev Loss confidence interval: 1.0965, 1.1089, LR: 0.001000
# Step 280, Train Loss: 1.0786, Dev Loss: 1.1025, Dev Loss confidence interval: 1.0963, 1.1087, LR: 0.001000
# Step 290, Train Loss: 1.0785, Dev Loss: 1.1024, Dev Loss confidence interval: 1.0962, 1.1086, LR: 0.001000
# Step 300, Train Loss: 1.0783, Dev Loss: 1.1022, Dev Loss confidence interval: 1.0960, 1.1084, LR: 0.001000
# Step 310, Train Loss: 1.0780, Dev Loss: 1.1021, Dev Loss confidence interval: 1.0959, 1.1083, LR: 0.001000
# Step 320, Train Loss: 1.0779, Dev Loss: 1.1019, Dev Loss confidence interval: 1.0958, 1.1081, LR: 0.001000
# Step 330, Train Loss: 1.0777, Dev Loss: 1.1018, Dev Loss confidence interval: 1.0956, 1.1080, LR: 0.001000
# Step 340, Train Loss: 1.0776, Dev Loss: 1.1018, Dev Loss confidence interval: 1.0956, 1.1080, LR: 0.001000
# Step 350, Train Loss: 1.0774, Dev Loss: 1.1016, Dev Loss confidence interval: 1.0954, 1.1078, LR: 0.001000
# Step 360, Train Loss: 1.0771, Dev Loss: 1.1014, Dev Loss confidence interval: 1.0951, 1.1076, LR: 0.001000
# Step 370, Train Loss: 1.0773, Dev Loss: 1.1016, Dev Loss confidence interval: 1.0954, 1.1077, LR: 0.001000
# Step 380, Train Loss: 1.0770, Dev Loss: 1.1014, Dev Loss confidence interval: 1.0952, 1.1076, LR: 0.001000
# Step 390, Train Loss: 1.0767, Dev Loss: 1.1011, Dev Loss confidence interval: 1.0948, 1.1074, LR: 0.001000
# Step 400, Train Loss: 1.0766, Dev Loss: 1.1010, Dev Loss confidence interval: 1.0948, 1.1072, LR: 0.000500
# Best epoch: 400
# Final Train Loss: 1.0766, Final Train Loss confidence interval: 1.0729, 1.0802
# Final Dev Loss: 1.1010, Final Dev Loss confidence interval: 1.0947, 1.1074
# Test Loss: 1.0488, Test Loss confidence interval: 1.0423, 1.0553

# %%
import matplotlib.pyplot as plt
import numpy as np

steps = np.arange(0, len(train_losses) * 10, 10)  # Since you log every 10 steps

plt.figure(figsize=(10, 6))
plt.plot(steps, train_losses, label='Train Loss', linewidth=2)
plt.plot(steps, dev_losses, label='Dev Loss', linewidth=2)
plt.xlabel('Training Step')
plt.ylabel('Loss (Negative Log-Likelihood)')
plt.title(f"Training and Validation Loss of {dist_type}_NoReg_RV")
plt.legend()
plt.grid(True, alpha=0.3)
plt.axhline(y=0, color='r', linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()
