# %%
import pandas as pd
import glob
import datetime
from zoneinfo import ZoneInfo
import exchange_calendars as ec
import torch
import os
import numpy as np

# %%
def is_full_nyse_day(date):
    nyse = ec.get_calendar("XNYS")
    date = pd.Timestamp(date).normalize()

    if not nyse.is_session(date):
        return False

    open_time   = nyse.session_open(date)
    close_time  = nyse.session_close(date)
    full_length = pd.Timedelta(hours=6.5)
    return (close_time - open_time) >= full_length


def get_full_sequence_data_by_day():

    folder_path      = r"../../../MarketData/historical_data"
    files            = glob.glob(os.path.join(folder_path, "spy_1min_*.csv"))

    xs = []

    for file in files:

        date_str = file.split("_")[-1].split(".")[0]
        print(date_str)
        date_str = date_str[:4] + "-" + date_str[4:6] + "-" + date_str[6:]

        if not is_full_nyse_day(date_str):
            print("skipping", date_str)
            continue

        df = pd.read_csv(file)

        open_time = datetime.datetime.strptime(date_str + " 09:31:00", "%Y-%m-%d %H:%M:%S").replace(tzinfo= ZoneInfo("America/New_York"))
        close_time = datetime.datetime.strptime(date_str + " 16:00:00", "%Y-%m-%d %H:%M:%S").replace(tzinfo= ZoneInfo("America/New_York"))

        df["ts_recv"] = pd.to_datetime(df["ts_recv"])
        df['ts_recv_est'] = df['ts_recv'].dt.tz_convert('America/New_York')
        df = df[(df["ts_recv_est"] >= open_time) & (df["ts_recv_est"] <= close_time)]
        df["seconds_since_open"] = (df["ts_recv_est"] - open_time).dt.total_seconds()
        data = df[["ret_60s"]] #, "rv_60s", "seconds_since_open"]].values

        data = np.array(data)
        xs.append(data)

    xs = np.array(xs)
    return  xs

# %%
returns = get_full_sequence_data_by_day()
returns = torch.from_numpy(returns)   # shape (1246, 390)
print(returns.shape)
# Out:
# 20201005
# 20201006
# 20201007
# 20201008
# 20201009
# 20201012
# 20201013
# 20201014
# 20201015
# 20201016
# 20201019
# 20201020
# 20201021
# 20201022
# 20201023
# 20201026
# 20201027
# 20201028
# 20201029
# 20201030
# 20201102
# 20201103
# 20201104
# 20201105
# 20201106
# 20201109
# 20201110
# 20201111
# 20201112
# 20201113
# 20201116
# 20201117
# 20201118
# 20201119
# 20201120
# 20201123
# 20201124
# 20201125
# 20201127
# skipping 2020-11-27
# 20201130
# 20201201
# 20201202
# 20201203
# 20201204
# 20201207
# 20201208
# 20201209
# 20201210
# 20201211
# 20201214
# 20201215
# 20201216
# 20201217
# 20201218
# 20201221
# 20201222
# 20201223
# 20201224
# skipping 2020-12-24
# 20201228
# 20201229
# 20201230
# 20201231
# 20210104
# 20210105
# 20210106
# 20210107
# 20210108
# 20210111
# 20210112
# 20210113
# 20210114
# 20210115
# 20210119
# 20210120
# 20210121
# 20210122
# 20210125
# 20210126
# 20210127
# 20210128
# 20210129
# 20210201
# 20210202
# 20210203
# 20210204
# 20210205
# 20210208
# 20210209
# 20210210
# 20210211
# 20210212
# 20210216
# 20210217
# 20210218
# 20210219
# 20210222
# 20210223
# 20210224
# 20210225
# 20210226
# 20210301
# 20210302
# 20210303
# 20210304
# 20210305
# 20210308
# 20210309
# 20210310
# 20210311
# 20210312
# 20210315
# 20210316
# 20210317
# 20210318
# 20210319
# 20210322
# 20210323
# 20210324
# 20210325
# 20210326
# 20210329
# 20210330
# 20210331
# 20210401
# 20210405
# 20210406
# 20210407
# 20210408
# 20210409
# 20210412
# 20210413
# 20210414
# 20210415
# 20210416
# 20210419
# 20210420
# 20210421
# 20210422
# 20210423
# 20210426
# 20210427
# 20210428
# 20210429
# 20210430
# 20210503
# 20210504
# 20210505
# 20210506
# 20210507
# 20210510
# 20210511
# 20210512
# 20210513
# 20210514
# 20210517
# 20210518
# 20210519
# 20210520
# 20210521
# 20210524
# 20210525
# 20210526
# 20210527
# 20210528
# 20210601
# 20210602
# 20210603
# 20250717
# 20250718
# 20250721
# 20250722
# 20250723
# 20250724
# 20250725
# 20250728
# 20250729
# 20250730
# 20250731
# 20250801
# 20250804
# 20250805
# 20250806
# 20250807
# 20250808
# 20250811
# 20250812
# 20250813
# 20250814
# 20250815
# 20250818
# 20250819
# 20250820
# 20250821
# 20250822
# 20250825
# 20250826
# 20250827
# 20250828
# 20250829
# 20250902
# 20250903
# 20250904
# 20250905
# 20250908
# 20250909
# 20250910
# 20250911
# 20250912
# 20250915
# 20250916
# 20250917
# 20250918
# 20250919
# 20250922
# 20250923
# 20250924
# 20250925
# 20250926
# 20250929
# 20250930
# 20251001
# 20251002
# 20251003
# torch.Size([1246, 390, 1])

# %%
import torch

num_days, num_minutes, _ = returns.shape
context = 60
horizon = 60

Xs = []
ys = []

for d in range(num_days):
    day = returns[d]                      # shape (390,)
    for t in range(context, num_minutes-horizon):
        Xs.append(day[t-context:t])       # (60,)
        ys.append(day[t: t+ horizon])     # (60,)

Xs = torch.stack(Xs)     # (1246*(390-60), 60, 1)
ys = torch.stack(ys)     # (1246*(390-60), 60, 1)
print(Xs.shape, ys.shape)
# Out:
# torch.Size([336420, 60, 1]) torch.Size([336420, 60, 1])

# %%
N = Xs.shape[0]

train_end = int(0.6 * N)
val_end   = int(0.8 * N)

Xs_train_raw = Xs[:train_end]
ys_train_raw = ys[:train_end]

Xs_val_raw = Xs[train_end:val_end]
ys_val_raw = ys[train_end:val_end]

Xs_test_raw = Xs[val_end:]
ys_test_raw = ys[val_end:]

mean_train = Xs_train_raw.mean()
std_train  = Xs_train_raw.std()

Xs_train = (Xs_train_raw - mean_train) / std_train
Xs_val   = (Xs_val_raw   - mean_train) / std_train
Xs_test  = (Xs_test_raw  - mean_train) / std_train

ys_train = (ys_train_raw - mean_train) / std_train
ys_val   = (ys_val_raw   - mean_train) / std_train
ys_test  = (ys_test_raw  - mean_train) / std_train

print(Xs_train.shape, ys_train.shape)
print(ys_train.shape, ys_val.shape)

print(Xs_val.shape, Xs_val.shape)
print(ys_val.shape, ys_val.shape)

print(Xs_test.shape, Xs_test.shape)
print(ys_test.shape, ys_test.shape)
# Out:
# torch.Size([201852, 60, 1]) torch.Size([201852, 60, 1])
# torch.Size([201852, 60, 1]) torch.Size([67284, 60, 1])
# torch.Size([67284, 60, 1]) torch.Size([67284, 60, 1])
# torch.Size([67284, 60, 1]) torch.Size([67284, 60, 1])
# torch.Size([67284, 60, 1]) torch.Size([67284, 60, 1])
# torch.Size([67284, 60, 1]) torch.Size([67284, 60, 1])

# %%
import torch.nn as nn
import torch.nn.functional as F

class LSTMNormal_M2M_Standard(nn.Module):
    def __init__(self, hidden=64):
        super().__init__()
        self.lstm = nn.LSTM(
            input_size=1,
            hidden_size=hidden,
            num_layers=1,
            batch_first=True
        )
        self.mu_head = nn.Linear(hidden, 1)
        self.sigma_head = nn.Linear(hidden, 60)

    def forward(self, x):

        out, _ = self.lstm(x)
        h =  out[:, -1, :]  # use all 60 predictions
        sigma  = F.softplus(self.sigma_head(h)) + 1e-6
        sigma  = sigma.unsqueeze(-1)
        mu = torch.zeros_like(sigma)
        return mu, sigma

def nll_normal_m2m(y, mu, sigma):
    return (
        0.5 * torch.log(2 * torch.pi * sigma**2) +
        (y - mu)**2 / (2 * sigma**2)
    ).mean()

# %%
from torch.utils.data import Dataset, DataLoader

class ReturnDataset(Dataset):
    def __init__(self, X, y):
        self.X = X   # (N, 60, 1)
        self.y = y   # (N, 60, 1)
    def __len__(self):
        return self.X.shape[0]
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

train_ds = ReturnDataset(Xs_train, ys_train)
val_ds   = ReturnDataset(Xs_val,   ys_val)
test_ds  = ReturnDataset(Xs_test,  ys_test)
train_loader = DataLoader(train_ds, batch_size=512, shuffle=True)
val_loader   = DataLoader(val_ds,   batch_size=512, shuffle=False)
test_loader  = DataLoader(test_ds,  batch_size=512, shuffle=False)

# %%
import numpy as np

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

loss_history      = []
sigma_history     = []

val_loss_history  = []
val_sigma_history = []

model = LSTMNormal_M2M_Standard().to(device).double()
opt = torch.optim.Adam(model.parameters(), lr=1e-3)

for epoch in range(300):

    model.train()
    epoch_losses = []
    epoch_sigmas = []

    for xb, yb in train_loader:
        xb, yb = xb.to(device).double(), yb.to(device).double()

        mu, sigma = model(xb)
        loss = nll_normal_m2m(yb, mu, sigma)

        epoch_losses.append(loss.item())

        sigma_step_means = sigma.mean(dim=0).squeeze(-1)  # (60,)
        epoch_sigmas.append(sigma_step_means.detach().cpu().numpy())

        opt.zero_grad()
        loss.backward()
        opt.step()

    loss_history.append(np.mean(epoch_losses))
    sigma_history.append(np.mean(epoch_sigmas, axis=0))

    model.eval()
    val_losses = []
    val_sigmas = []

    with torch.no_grad():
        for xb, yb in val_loader:
            xb = xb.to(device).double()
            yb = yb.to(device).double()

            mu, sigma = model(xb)
            val_loss = nll_normal_m2m(yb, mu, sigma)

            val_losses.append(val_loss.item())
            sigma_step_means = sigma.mean(dim=0).squeeze(-1)  # (60,)
            val_sigmas.append(sigma_step_means.detach().cpu().numpy())

    val_loss_history.append(np.mean(val_losses))
    val_sigma_history.append( np.mean(val_sigmas, axis=0))

    print(f"Epoch {epoch}: train loss={loss_history[-1]:.4f}, val loss={val_loss_history[-1]:.4f}")
# Out:
# Epoch 0: train loss=1.2758, val loss=0.9482
# Epoch 1: train loss=1.1782, val loss=0.9506
# Epoch 2: train loss=1.1754, val loss=0.9548
# Epoch 3: train loss=1.1743, val loss=0.9463
# Epoch 4: train loss=1.1731, val loss=0.9485
# Epoch 5: train loss=1.1719, val loss=0.9460
# Epoch 6: train loss=1.1708, val loss=0.9519
# Epoch 7: train loss=1.1704, val loss=0.9450
# Epoch 8: train loss=1.1696, val loss=0.9466
# Epoch 9: train loss=1.1686, val loss=0.9425
# Epoch 10: train loss=1.1688, val loss=0.9442
# Epoch 11: train loss=1.1679, val loss=0.9455
# Epoch 12: train loss=1.1667, val loss=0.9493
# Epoch 13: train loss=1.1644, val loss=0.9491
# Epoch 14: train loss=1.1619, val loss=0.9519
# Epoch 15: train loss=1.1600, val loss=0.9489
# Epoch 16: train loss=1.1581, val loss=0.9497
# Epoch 17: train loss=1.1581, val loss=0.9524
# Epoch 18: train loss=1.1559, val loss=0.9468
# Epoch 19: train loss=1.1567, val loss=0.9548
# Epoch 20: train loss=1.1548, val loss=0.9482
# Epoch 21: train loss=1.1534, val loss=0.9481
# Epoch 22: train loss=1.1545, val loss=0.9576
# Epoch 23: train loss=1.1546, val loss=0.9541
# Epoch 24: train loss=1.1516, val loss=0.9532
# Epoch 25: train loss=1.1525, val loss=0.9549
# Epoch 26: train loss=1.1489, val loss=0.9582
# Epoch 27: train loss=1.1554, val loss=0.9611
# Epoch 28: train loss=1.1467, val loss=0.9576
# Epoch 29: train loss=1.1433, val loss=0.9603
# Epoch 30: train loss=1.1419, val loss=0.9619
# Epoch 31: train loss=1.1393, val loss=0.9619
# Epoch 32: train loss=1.1392, val loss=0.9510
# Epoch 33: train loss=1.1377, val loss=0.9662
# Epoch 34: train loss=1.1369, val loss=0.9488
# Epoch 35: train loss=1.1355, val loss=0.9691
# Epoch 36: train loss=1.1340, val loss=0.9529
# Epoch 37: train loss=1.1534, val loss=0.9544
# Epoch 38: train loss=1.1379, val loss=0.9494
# Epoch 39: train loss=1.1337, val loss=0.9497
# Epoch 40: train loss=1.1316, val loss=0.9551
# Epoch 41: train loss=1.1298, val loss=0.9475
# Epoch 42: train loss=1.1330, val loss=0.9537
# Epoch 43: train loss=1.1303, val loss=0.9484
# Epoch 44: train loss=1.1357, val loss=0.9527
# Epoch 45: train loss=1.1309, val loss=0.9540
# Epoch 46: train loss=1.1267, val loss=0.9498
# Epoch 47: train loss=1.1261, val loss=0.9525
# Epoch 48: train loss=1.1345, val loss=0.9514
# Epoch 49: train loss=1.1271, val loss=0.9554
# Epoch 50: train loss=1.1243, val loss=0.9548
# Epoch 51: train loss=1.1233, val loss=0.9511
# Epoch 52: train loss=1.1237, val loss=0.9577
# Epoch 53: train loss=1.1220, val loss=0.9504
# Epoch 54: train loss=1.1225, val loss=0.9510
# Epoch 55: train loss=1.1205, val loss=0.9520
# Epoch 56: train loss=1.1200, val loss=0.9546
# Epoch 57: train loss=1.1181, val loss=0.9542
# Epoch 58: train loss=1.1207, val loss=0.9587
# Epoch 59: train loss=1.1180, val loss=0.9541
# Epoch 60: train loss=1.1155, val loss=0.9582
# Epoch 61: train loss=1.1143, val loss=0.9628
# Epoch 62: train loss=1.1149, val loss=0.9558
# Epoch 63: train loss=1.1181, val loss=0.9585
# Epoch 64: train loss=1.1125, val loss=0.9606
# Epoch 65: train loss=1.1151, val loss=0.9595
# Epoch 66: train loss=1.1106, val loss=0.9620
# Epoch 67: train loss=1.1098, val loss=0.9587
# Epoch 68: train loss=1.1082, val loss=0.9642
# Epoch 69: train loss=1.1075, val loss=0.9607
# Epoch 70: train loss=1.1169, val loss=0.9526
# Epoch 71: train loss=1.1096, val loss=0.9609
# Epoch 72: train loss=1.1062, val loss=0.9637
# Epoch 73: train loss=1.1056, val loss=0.9618
# Epoch 74: train loss=1.1047, val loss=0.9671
# Epoch 75: train loss=1.1040, val loss=0.9714
# Epoch 76: train loss=1.1028, val loss=0.9667
# Epoch 77: train loss=1.1017, val loss=0.9663
# Epoch 78: train loss=1.1142, val loss=0.9605
# Epoch 79: train loss=1.1041, val loss=0.9671
# Epoch 80: train loss=1.1015, val loss=0.9662
# Epoch 81: train loss=1.0999, val loss=0.9642
# Epoch 82: train loss=1.0987, val loss=0.9696
# Epoch 83: train loss=1.0985, val loss=0.9674
# Epoch 84: train loss=1.0977, val loss=0.9692
# Epoch 85: train loss=1.0972, val loss=0.9855
# Epoch 86: train loss=1.1012, val loss=0.9827
# Epoch 87: train loss=1.0957, val loss=0.9735
# Epoch 88: train loss=1.0947, val loss=0.9723
# Epoch 89: train loss=1.0941, val loss=0.9732
# Epoch 90: train loss=1.0956, val loss=0.9754
# Epoch 91: train loss=1.0950, val loss=0.9659
# Epoch 92: train loss=1.0933, val loss=0.9757
# Epoch 93: train loss=1.0917, val loss=0.9815
# Epoch 94: train loss=1.0904, val loss=0.9838
# Epoch 95: train loss=1.0904, val loss=0.9793
# Epoch 96: train loss=1.0906, val loss=0.9770
# Epoch 97: train loss=1.0893, val loss=0.9819
# Epoch 98: train loss=1.0883, val loss=0.9793
# Epoch 99: train loss=1.0884, val loss=0.9801
# Epoch 100: train loss=1.0880, val loss=0.9807
# Epoch 101: train loss=1.0870, val loss=0.9927
# Epoch 102: train loss=1.0859, val loss=0.9891
# Epoch 103: train loss=1.0863, val loss=0.9851
# Epoch 104: train loss=1.0868, val loss=0.9975
# Epoch 105: train loss=1.0896, val loss=0.9910
# Epoch 106: train loss=1.0843, val loss=0.9901
# Epoch 107: train loss=1.0849, val loss=0.9897
# Epoch 108: train loss=1.0830, val loss=0.9938
# Epoch 109: train loss=1.0828, val loss=0.9878
# Epoch 110: train loss=1.0825, val loss=0.9964
# Epoch 111: train loss=1.0823, val loss=0.9993
# Epoch 112: train loss=1.0840, val loss=0.9918
# Epoch 113: train loss=1.0840, val loss=0.9843
# Epoch 114: train loss=1.0826, val loss=0.9967
# Epoch 115: train loss=1.0803, val loss=0.9969
# Epoch 116: train loss=1.0800, val loss=1.0039
# Epoch 117: train loss=1.0802, val loss=0.9856
# Epoch 118: train loss=1.0842, val loss=0.9649
# Epoch 119: train loss=1.0928, val loss=0.9836
# Epoch 120: train loss=1.0809, val loss=0.9927
# Epoch 121: train loss=1.0800, val loss=0.9889
# Epoch 122: train loss=1.0819, val loss=0.9908
# Epoch 123: train loss=1.0781, val loss=0.9948
# Epoch 124: train loss=1.0774, val loss=0.9898
# Epoch 125: train loss=1.0781, val loss=0.9916
# Epoch 126: train loss=1.0775, val loss=1.0000
# Epoch 127: train loss=1.0770, val loss=1.0025
# Epoch 128: train loss=1.0770, val loss=0.9985
# Epoch 129: train loss=1.0765, val loss=0.9931
# Epoch 130: train loss=1.0772, val loss=0.9934
# Epoch 131: train loss=1.0762, val loss=0.9917
# Epoch 132: train loss=1.0836, val loss=0.9891
# Epoch 133: train loss=1.0801, val loss=0.9937
# Epoch 134: train loss=1.0759, val loss=0.9991
# Epoch 135: train loss=1.0763, val loss=0.9936
# Epoch 136: train loss=1.0744, val loss=0.9989
# Epoch 137: train loss=1.0748, val loss=0.9961
# Epoch 138: train loss=1.0806, val loss=0.9839
# Epoch 139: train loss=1.0781, val loss=1.0002
# Epoch 140: train loss=1.0741, val loss=1.0018
# Epoch 141: train loss=1.0734, val loss=0.9912
# Epoch 142: train loss=1.0750, val loss=0.9910
# Epoch 143: train loss=1.0739, val loss=0.9948
# Epoch 144: train loss=1.0755, val loss=1.0025
# Epoch 145: train loss=1.0741, val loss=0.9988
# Epoch 146: train loss=1.0727, val loss=0.9937
# Epoch 147: train loss=1.0734, val loss=1.0006
# Epoch 148: train loss=1.0761, val loss=0.9864
# Epoch 149: train loss=1.0748, val loss=0.9992
# Epoch 150: train loss=1.0721, val loss=0.9978
# Epoch 151: train loss=1.0721, val loss=1.0074
# Epoch 152: train loss=1.0735, val loss=1.0089
# Epoch 153: train loss=1.0726, val loss=1.0044
# Epoch 154: train loss=1.0716, val loss=0.9932
# Epoch 155: train loss=1.0716, val loss=0.9983
# Epoch 156: train loss=1.0711, val loss=1.0076
# Epoch 157: train loss=1.0713, val loss=0.9996
# Epoch 158: train loss=1.0715, val loss=1.0026
# Epoch 159: train loss=1.0724, val loss=1.0016
# Epoch 160: train loss=1.0711, val loss=1.0062
# Epoch 161: train loss=1.0710, val loss=0.9979
# Epoch 162: train loss=1.0801, val loss=1.0022
# Epoch 163: train loss=1.0715, val loss=1.0025
# Epoch 164: train loss=1.0702, val loss=1.0065
# Epoch 165: train loss=1.0709, val loss=0.9991
# Epoch 166: train loss=1.0699, val loss=1.0020
# Epoch 167: train loss=1.0704, val loss=1.0001
# Epoch 168: train loss=1.0699, val loss=1.0033
# Epoch 169: train loss=1.0696, val loss=1.0032
# Epoch 170: train loss=1.0695, val loss=1.0040
# Epoch 171: train loss=1.0725, val loss=0.9864
# Epoch 172: train loss=1.0712, val loss=1.0026
# Epoch 173: train loss=1.0765, val loss=0.9973
# Epoch 174: train loss=1.0700, val loss=1.0072
# Epoch 175: train loss=1.0749, val loss=1.0065
# Epoch 176: train loss=1.0695, val loss=1.0013
# Epoch 177: train loss=1.0688, val loss=1.0074
# Epoch 178: train loss=1.0708, val loss=0.9995
# Epoch 179: train loss=1.0693, val loss=1.0040
# Epoch 180: train loss=1.0686, val loss=1.0111
# Epoch 181: train loss=1.0688, val loss=0.9998
# Epoch 182: train loss=1.0684, val loss=1.0026
# Epoch 183: train loss=1.0684, val loss=1.0036
# Epoch 184: train loss=1.0686, val loss=1.0004
# Epoch 185: train loss=1.0683, val loss=1.0044
# Epoch 186: train loss=1.0695, val loss=1.0078
# Epoch 187: train loss=1.0685, val loss=1.0029
# Epoch 188: train loss=1.0720, val loss=1.0091
# Epoch 189: train loss=1.0682, val loss=0.9982
# Epoch 190: train loss=1.0680, val loss=1.0083
# Epoch 191: train loss=1.0675, val loss=1.0069
# Epoch 192: train loss=1.0676, val loss=1.0099
# Epoch 193: train loss=1.0676, val loss=1.0148
# Epoch 194: train loss=1.0679, val loss=1.0028
# Epoch 195: train loss=1.0676, val loss=1.0125
# Epoch 196: train loss=1.0677, val loss=1.0017
# Epoch 197: train loss=1.0671, val loss=1.0227
# Epoch 198: train loss=1.0687, val loss=1.0060
# Epoch 199: train loss=1.0678, val loss=1.0102
# Epoch 200: train loss=1.0684, val loss=1.0050
# Epoch 201: train loss=1.0667, val loss=0.9987
# Epoch 202: train loss=1.0664, val loss=1.0059
# Epoch 203: train loss=1.0664, val loss=1.0043
# Epoch 204: train loss=1.0672, val loss=1.0149
# Epoch 205: train loss=1.0769, val loss=1.0096
# Epoch 206: train loss=1.0671, val loss=0.9998
# Epoch 207: train loss=1.0662, val loss=1.0064
# Epoch 208: train loss=1.0666, val loss=0.9999
# Epoch 209: train loss=1.0668, val loss=1.0130
# Epoch 210: train loss=1.0662, val loss=1.0134
# Epoch 211: train loss=1.0661, val loss=1.0072
# Epoch 212: train loss=1.0668, val loss=1.0063
# Epoch 213: train loss=1.0660, val loss=1.0119
# Epoch 214: train loss=1.0662, val loss=1.0118
# Epoch 215: train loss=1.0659, val loss=1.0083
# Epoch 216: train loss=1.0661, val loss=1.0110
# Epoch 217: train loss=1.0674, val loss=1.0153
# Epoch 218: train loss=1.0661, val loss=1.0079
# Epoch 219: train loss=1.0669, val loss=1.0078
# Epoch 220: train loss=1.0659, val loss=1.0177
# Epoch 221: train loss=1.0653, val loss=1.0102
# Epoch 222: train loss=1.0654, val loss=1.0066
# Epoch 223: train loss=1.0690, val loss=1.0175
# Epoch 224: train loss=1.0656, val loss=1.0041
# Epoch 225: train loss=1.0656, val loss=1.0014
# Epoch 226: train loss=1.0658, val loss=1.0118
# Epoch 227: train loss=1.0695, val loss=1.0102
# Epoch 228: train loss=1.0655, val loss=1.0110
# Epoch 229: train loss=1.0667, val loss=1.0203
# Epoch 230: train loss=1.0668, val loss=1.0084
# Epoch 231: train loss=1.0670, val loss=1.0026
# Epoch 232: train loss=1.0679, val loss=1.0111
# Epoch 233: train loss=1.0649, val loss=1.0102
# Epoch 234: train loss=1.0651, val loss=1.0161
# Epoch 235: train loss=1.0652, val loss=1.0102
# Epoch 236: train loss=1.0648, val loss=1.0135
# Epoch 237: train loss=1.0648, val loss=1.0106
# Epoch 238: train loss=1.0684, val loss=1.0103
# Epoch 239: train loss=1.0647, val loss=1.0229
# Epoch 240: train loss=1.0644, val loss=1.0174
# Epoch 241: train loss=1.0654, val loss=1.0081
# Epoch 242: train loss=1.0663, val loss=0.9983
# Epoch 243: train loss=1.0645, val loss=1.0123
# Epoch 244: train loss=1.0646, val loss=1.0118
# Epoch 245: train loss=1.0662, val loss=1.0106
# Epoch 246: train loss=1.0652, val loss=1.0049
# Epoch 247: train loss=1.0645, val loss=1.0069
# Epoch 248: train loss=1.0648, val loss=1.0152
# Epoch 249: train loss=1.0640, val loss=1.0041
# Epoch 250: train loss=1.0674, val loss=1.0130
# Epoch 251: train loss=1.0637, val loss=1.0101
# Epoch 252: train loss=1.0644, val loss=1.0105
# Epoch 253: train loss=1.0651, val loss=1.0040
# Epoch 254: train loss=1.0641, val loss=1.0105
# Epoch 255: train loss=1.0645, val loss=1.0081
# Epoch 256: train loss=1.0640, val loss=1.0214
# Epoch 257: train loss=1.0640, val loss=1.0134
# Epoch 258: train loss=1.0652, val loss=1.0159
# Epoch 259: train loss=1.0669, val loss=1.0109
# Epoch 260: train loss=1.0644, val loss=1.0083
# Epoch 261: train loss=1.0659, val loss=1.0096
# Epoch 262: train loss=1.0653, val loss=1.0126
# Epoch 263: train loss=1.0634, val loss=1.0071
# Epoch 264: train loss=1.0635, val loss=1.0141
# Epoch 265: train loss=1.0635, val loss=1.0145
# Epoch 266: train loss=1.0636, val loss=1.0093
# Epoch 267: train loss=1.0645, val loss=1.0057
# Epoch 268: train loss=1.0643, val loss=1.0183
# Epoch 269: train loss=1.0633, val loss=1.0041
# Epoch 270: train loss=1.0636, val loss=1.0046
# Epoch 271: train loss=1.0658, val loss=1.0128
# Epoch 272: train loss=1.0639, val loss=1.0121
# Epoch 273: train loss=1.0634, val loss=1.0116
# Epoch 274: train loss=1.0628, val loss=1.0132
# Epoch 275: train loss=1.0641, val loss=1.0106
# Epoch 276: train loss=1.0635, val loss=1.0087
# Epoch 277: train loss=1.0657, val loss=1.0213
# Epoch 278: train loss=1.0631, val loss=1.0156
# Epoch 279: train loss=1.0634, val loss=1.0182
# Epoch 280: train loss=1.0638, val loss=1.0168
# Epoch 281: train loss=1.0628, val loss=1.0137
# Epoch 282: train loss=1.0628, val loss=1.0208
# Epoch 283: train loss=1.0682, val loss=1.0122
# Epoch 284: train loss=1.0640, val loss=1.0148
# Epoch 285: train loss=1.0629, val loss=1.0107
# Epoch 286: train loss=1.0628, val loss=1.0145
# Epoch 287: train loss=1.0624, val loss=1.0121
# Epoch 288: train loss=1.0630, val loss=1.0131
# Epoch 289: train loss=1.0658, val loss=1.0060
# Epoch 290: train loss=1.0628, val loss=1.0198
# Epoch 291: train loss=1.0621, val loss=1.0123
# Epoch 292: train loss=1.0628, val loss=1.0087
# Epoch 293: train loss=1.0632, val loss=1.0231
# Epoch 294: train loss=1.0631, val loss=1.0080
# Epoch 295: train loss=1.0624, val loss=1.0155
# Epoch 296: train loss=1.0625, val loss=1.0194
# Epoch 297: train loss=1.0631, val loss=1.0090
# Epoch 298: train loss=1.0623, val loss=1.0106
# Epoch 299: train loss=1.0623, val loss=1.0159

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(12,5))
plt.plot(loss_history, label="Train Loss", linewidth=2)
plt.plot(val_loss_history, label="Validation Loss", linewidth=2)
plt.xlabel("Epoch")
plt.ylabel("Loss (NLL)")
plt.title("Train vs Validation Loss - LSTM + Normal (60→60)")
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %%
sigma_hist     = np.array(sigma_history)      # (epochs, 60)
val_sigma_hist = np.array(val_sigma_history)  # (epochs, 60)

# %%
import matplotlib.pyplot as plt
import numpy as np

sigma_hist = np.array(sigma_history)   # shape: (epochs, 60)

plt.figure(figsize=(14, 7))

for h in range(60):
    plt.plot(
        sigma_hist[:, h],
        linewidth=1,
        alpha=0.6
    )

plt.xlabel("Epoch")
plt.ylabel("Sigma")
plt.title("Train Sigma  (average cross samples) — 60 Horizons")
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14, 7))

for h in range(60):
    plt.plot(
        val_sigma_hist[:, h],
        linewidth=1,
        alpha=0.6
    )

plt.xlabel("Epoch")
plt.ylabel("Sigma")
plt.title("Validation Sigma (average cross samples) — All 60 Future Horizons (LSTM Normal 60→60)")
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# Model:
# : $$x_{t+1}, x_{t+2}, \cdots, x_{t+60}|{x_{t-59}, x_{t-58},\cdots, x_t} \sim  \mathcal{N}(0, Diag((\sigma_{t}^{(1)})^2, (\sigma_{t}^{(2)})^2, \cdots, (\sigma_{t}^{(60)})^2)$$
