# %%
import pandas as pd
import glob
import datetime
from zoneinfo import ZoneInfo
import exchange_calendars as ec
import torch
import os
import numpy as np

# %%
def is_full_nyse_day(date):
    nyse = ec.get_calendar("XNYS")
    date = pd.Timestamp(date).normalize()

    if not nyse.is_session(date):
        return False

    open_time   = nyse.session_open(date)
    close_time  = nyse.session_close(date)
    full_length = pd.Timedelta(hours=6.5)
    return (close_time - open_time) >= full_length


def get_full_sequence_data_by_day():

    folder_path      = r"/MarketData/historical_data"
    files            = glob.glob(os.path.join(folder_path, "spy_1min_*.csv"))

    xs = []

    for file in files:

        date_str = file.split("_")[-1].split(".")[0]
        print(date_str)
        date_str = date_str[:4] + "-" + date_str[4:6] + "-" + date_str[6:]

        if not is_full_nyse_day(date_str):
            print("skipping", date_str)
            continue

        df = pd.read_csv(file)

        open_time = datetime.datetime.strptime(date_str + " 09:31:00", "%Y-%m-%d %H:%M:%S").replace(tzinfo= ZoneInfo("America/New_York"))
        close_time = datetime.datetime.strptime(date_str + " 16:00:00", "%Y-%m-%d %H:%M:%S").replace(tzinfo= ZoneInfo("America/New_York"))

        df["ts_recv"] = pd.to_datetime(df["ts_recv"])
        df['ts_recv_est'] = df['ts_recv'].dt.tz_convert('America/New_York')
        df = df[(df["ts_recv_est"] >= open_time) & (df["ts_recv_est"] <= close_time)]
        df["seconds_since_open"] = (df["ts_recv_est"] - open_time).dt.total_seconds()
        data = df[["ret_60s"]] #, "rv_60s", "seconds_since_open"]].values

        data = np.array(data)
        xs.append(data)

    xs = np.array(xs)
    return  xs

# %%
returns = get_full_sequence_data_by_day()
returns = torch.from_numpy(returns)   # shape (1246, 390)
print(returns.shape)
# Out:
# 20201005
# 20201006
# 20201007
# 20201008
# 20201009
# 20201012
# 20201013
# 20201014
# 20201015
# 20201016
# 20201019
# 20201020
# 20201021
# 20201022
# 20201023
# 20201026
# 20201027
# 20201028
# 20201029
# 20201030
# 20201102
# 20201103
# 20201104
# 20201105
# 20201106
# 20201109
# 20201110
# 20201111
# 20201112
# 20201113
# 20201116
# 20201117
# 20201118
# 20201119
# 20201120
# 20201123
# 20201124
# 20201125
# 20201127
# skipping 2020-11-27
# 20201130
# 20201201
# 20201202
# 20201203
# 20201204
# 20201207
# 20201208
# 20201209
# 20201210
# 20201211
# 20201214
# 20201215
# 20201216
# 20201217
# 20201218
# 20201221
# 20201222
# 20201223
# 20201224
# skipping 2020-12-24
# 20201228
# 20201229
# 20201230
# 20201231
# 20210104
# 20210105
# 20210106
# 20210107
# 20210108
# 20210111
# 20210112
# 20210113
# 20210114
# 20210115
# 20210119
# 20210120
# 20210121
# 20210122
# 20210125
# 20210126
# 20210127
# 20210128
# 20210129
# 20210201
# 20210202
# 20210203
# 20210204
# 20210205
# 20210208
# 20210209
# 20210210
# 20210211
# 20210212
# 20210216
# 20210217
# 20210218
# 20210219
# 20210222
# 20210223
# 20210224
# 20210225
# 20210226
# 20210301
# 20210302
# 20210303
# 20210304
# 20210305
# 20210308
# 20210309
# 20210310
# 20210311
# 20210312
# 20210315
# 20210316
# 20210317
# 20210318
# 20210319
# 20210322
# 20210323
# 20210324
# 20210325
# 20210326
# 20210329
# 20210330
# 20210331
# 20210401
# 20210405
# 20210406
# 20210407
# 20210408
# 20210409
# 20210412
# 20210413
# 20210414
# 20210415
# 20210416
# 20210419
# 20210420
# 20210421
# 20210422
# 20210423
# 20210426
# 20210427
# 20210428
# 20210429
# 20210430
# 20210503
# 20210504
# 20210505
# 20210506
# 20210507
# 20210510
# 20210511
# 20210512
# 20210513
# 20210514
# 20210517
# 20210518
# 20210519
# 20210520
# 20210521
# 20210524
# 20210525
# 20210526
# 20250606
# 20250609
# 20250610
# 20250611
# 20250612
# 20250613
# 20250616
# 20250617
# 20250618
# 20250620
# 20250623
# 20250624
# 20250625
# 20250626
# 20250627
# 20250630
# 20250701
# 20250702
# 20250703
# skipping 2025-07-03
# 20250707
# 20250708
# 20250709
# 20250710
# 20250711
# 20250714
# 20250715
# 20250716
# 20250717
# 20250718
# 20250721
# 20250722
# 20250723
# 20250724
# 20250725
# 20250728
# 20250729
# 20250730
# 20250731
# 20250801
# 20250804
# 20250805
# 20250806
# 20250807
# 20250808
# 20250811
# 20250812
# 20250813
# 20250814
# 20250815
# 20250818
# 20250819
# 20250820
# 20250821
# 20250822
# 20250825
# 20250826
# 20250827
# 20250828
# 20250829
# 20250902
# 20250903
# 20250904
# 20250905
# 20250908
# 20250909
# 20250910
# 20250911
# 20250912
# 20250915
# 20250916
# 20250917
# 20250918
# 20250919
# 20250922
# 20250923
# 20250924
# 20250925
# 20250926
# 20250929
# 20250930
# 20251001
# 20251002
# 20251003
# torch.Size([1246, 390, 1])

# %%
import torch

num_days, num_minutes, _ = returns.shape
context = 60

Xs = []
ys = []

for d in range(num_days):
    day = returns[d]                      # shape (390,)
    for t in range(context, num_minutes):
        Xs.append(day[t-context:t])       # (60,)
        ys.append(day[t])                 # scalar

Xs = torch.stack(Xs)     # (1246*(390-60), 60, 1)
ys = torch.stack(ys)     # (1246*(390-60), 1)
print(Xs.shape, ys.shape)
# Out:
# torch.Size([411180, 60, 1]) torch.Size([411180, 1])

# %%
N = Xs.shape[0]

train_end = int(0.6 * N)
val_end   = int(0.8 * N)

Xs_train_raw = Xs[:train_end]
ys_train_raw = ys[:train_end]

Xs_val_raw = Xs[train_end:val_end]
ys_val_raw = ys[train_end:val_end]

Xs_test_raw = Xs[val_end:]
ys_test_raw = ys[val_end:]

mean_train = Xs_train_raw.mean()
std_train  = Xs_train_raw.std()

Xs_train = (Xs_train_raw - mean_train) / std_train
Xs_val   = (Xs_val_raw   - mean_train) / std_train
Xs_test  = (Xs_test_raw  - mean_train) / std_train

ys_train = (ys_train_raw - mean_train) / std_train
ys_val   = (ys_val_raw   - mean_train) / std_train
ys_test  = (ys_test_raw  - mean_train) / std_train

print(Xs_train.shape, ys_train.shape)
print(ys_train.shape, ys_val.shape)

print(Xs_val.shape, Xs_val.shape)
print(ys_val.shape, ys_val.shape)

print(Xs_test.shape, Xs_test.shape)
print(ys_test.shape, ys_test.shape)
# Out:
# torch.Size([246708, 60, 1]) torch.Size([246708, 1])
# torch.Size([246708, 1]) torch.Size([82236, 1])
# torch.Size([82236, 60, 1]) torch.Size([82236, 60, 1])
# torch.Size([82236, 1]) torch.Size([82236, 1])
# torch.Size([82236, 60, 1]) torch.Size([82236, 60, 1])
# torch.Size([82236, 1]) torch.Size([82236, 1])

# %%
import torch.nn as nn
import torch.nn.functional as F

class LSTMNormal(nn.Module):
    def __init__(self, hidden=64):
        super().__init__()
        self.lstm = nn.LSTM(
            input_size=1,
            hidden_size=hidden,
            num_layers=1,
            batch_first=True
        )
        self.mu_head = nn.Linear(hidden, 1)
        self.sigma_head = nn.Linear(hidden, 1)

    def forward(self, x):
        out, _ = self.lstm(x)
        h      = out[:, -1, :]  # last hidden state
        mu     = torch.zeros((h.size(0), 1), device=h.device)
        sigma  = F.softplus(self.sigma_head(h)) + 1e-6
        return mu, sigma

def nll_normal(y, mu, sigma):
    return (
        0.5 * torch.log(2 * torch.pi * sigma**2) +
        (y - mu)**2 / (2 * sigma**2)
    ).mean()

# %%
from torch.utils.data import Dataset, DataLoader

class ReturnDataset(Dataset):
    def __init__(self, X, y):
        self.X = X   # (N, 60, 1)
        self.y = y   # (N, 1)
    def __len__(self):
        return self.X.shape[0]
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

train_ds = ReturnDataset(Xs_train, ys_train)
val_ds   = ReturnDataset(Xs_val,   ys_val)
test_ds  = ReturnDataset(Xs_test,  ys_test)

train_loader = DataLoader(train_ds, batch_size=512, shuffle=True)
val_loader   = DataLoader(val_ds,   batch_size=512, shuffle=False)
test_loader  = DataLoader(test_ds,  batch_size=512, shuffle=False)

# %%
import numpy as np

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

loss_history      = []
sigma_history     = []

val_loss_history  = []
val_sigma_history = []

model = LSTMNormal().to(device).double()
opt = torch.optim.Adam(model.parameters(), lr=1e-3)

for epoch in range(300):

    model.train()
    epoch_losses = []
    epoch_sigmas = []

    for xb, yb in train_loader:
        xb, yb = xb.to(device), yb.to(device)

        mu, sigma = model(xb)
        loss = nll_normal(yb, mu, sigma)

        epoch_losses.append(loss.item())
        epoch_sigmas.append(sigma.mean().item())

        opt.zero_grad()
        loss.backward()
        opt.step()

    loss_history.append(np.mean(epoch_losses))
    sigma_history.append(np.mean(epoch_sigmas))

    model.eval()
    val_losses = []
    val_sigmas = []

    with torch.no_grad():
        for xb, yb in val_loader:
            xb = xb.to(device).double()
            yb = yb.to(device).double()

            mu, sigma = model(xb)
            val_loss = nll_normal(yb, mu, sigma)

            val_losses.append(val_loss.item())
            val_sigmas.append(sigma.mean().item())

    val_loss_history.append(np.mean(val_losses))
    val_sigma_history.append(np.mean(val_sigmas))

    print(f"Epoch {epoch}: train loss={loss_history[-1]:.4f}, train sigma={sigma_history[-1]:.4f}, val loss={val_loss_history[-1]:.4f}, val sigma={val_sigma_history[-1]:.4f}")
# Out:
# Epoch 0: train loss=1.2303, train sigma=0.8940, val loss=0.9801, val sigma=0.7794
# Epoch 1: train loss=1.1640, train sigma=0.8793, val loss=0.9331, val sigma=0.6811
# Epoch 2: train loss=1.1459, train sigma=0.8653, val loss=0.9104, val sigma=0.6602
# Epoch 3: train loss=1.1428, train sigma=0.8644, val loss=0.9151, val sigma=0.6953
# Epoch 4: train loss=1.1446, train sigma=0.8662, val loss=0.9099, val sigma=0.6779
# Epoch 5: train loss=1.1415, train sigma=0.8644, val loss=0.9100, val sigma=0.6613
# Epoch 6: train loss=1.1414, train sigma=0.8656, val loss=0.9154, val sigma=0.6742
# Epoch 7: train loss=1.1395, train sigma=0.8621, val loss=0.9129, val sigma=0.6922
# Epoch 8: train loss=1.1366, train sigma=0.8617, val loss=0.9069, val sigma=0.6745
# Epoch 9: train loss=1.1370, train sigma=0.8612, val loss=0.9086, val sigma=0.6401
# Epoch 10: train loss=1.1358, train sigma=0.8599, val loss=0.9070, val sigma=0.6416
# Epoch 11: train loss=1.1367, train sigma=0.8611, val loss=0.9090, val sigma=0.6533
# Epoch 12: train loss=1.1357, train sigma=0.8606, val loss=0.9139, val sigma=0.6928
# Epoch 13: train loss=1.1356, train sigma=0.8600, val loss=0.9056, val sigma=0.6478
# Epoch 14: train loss=1.1345, train sigma=0.8595, val loss=0.9087, val sigma=0.6392
# Epoch 15: train loss=1.1342, train sigma=0.8603, val loss=0.9073, val sigma=0.6411
# Epoch 16: train loss=1.1339, train sigma=0.8588, val loss=0.9114, val sigma=0.6938
# Epoch 17: train loss=1.1330, train sigma=0.8587, val loss=0.9079, val sigma=0.6664
# Epoch 18: train loss=1.1333, train sigma=0.8592, val loss=0.9056, val sigma=0.6485
# Epoch 19: train loss=1.1331, train sigma=0.8584, val loss=0.9067, val sigma=0.6621
# Epoch 20: train loss=1.1327, train sigma=0.8591, val loss=0.9106, val sigma=0.6519
# Epoch 21: train loss=1.1320, train sigma=0.8583, val loss=0.9091, val sigma=0.6313
# Epoch 22: train loss=1.1327, train sigma=0.8574, val loss=0.9116, val sigma=0.6353
# Epoch 23: train loss=1.1319, train sigma=0.8582, val loss=0.9072, val sigma=0.6634
# Epoch 24: train loss=1.1316, train sigma=0.8584, val loss=0.9098, val sigma=0.6610
# Epoch 25: train loss=1.1314, train sigma=0.8577, val loss=0.9066, val sigma=0.6630
# Epoch 26: train loss=1.1309, train sigma=0.8565, val loss=0.9071, val sigma=0.6562
# Epoch 27: train loss=1.1306, train sigma=0.8578, val loss=0.9060, val sigma=0.6586
# Epoch 28: train loss=1.1303, train sigma=0.8569, val loss=0.9072, val sigma=0.6720
# Epoch 29: train loss=1.1299, train sigma=0.8570, val loss=0.9116, val sigma=0.6312
# Epoch 30: train loss=1.1294, train sigma=0.8561, val loss=0.9080, val sigma=0.6427
# Epoch 31: train loss=1.1292, train sigma=0.8561, val loss=0.9135, val sigma=0.6859
# Epoch 32: train loss=1.1288, train sigma=0.8570, val loss=0.9123, val sigma=0.6346
# Epoch 33: train loss=1.1288, train sigma=0.8561, val loss=0.9097, val sigma=0.6829
# Epoch 34: train loss=1.1286, train sigma=0.8557, val loss=0.9076, val sigma=0.6576
# Epoch 35: train loss=1.1281, train sigma=0.8562, val loss=0.9060, val sigma=0.6467
# Epoch 36: train loss=1.1274, train sigma=0.8545, val loss=0.9079, val sigma=0.6477
# Epoch 37: train loss=1.1270, train sigma=0.8556, val loss=0.9066, val sigma=0.6473
# Epoch 38: train loss=1.1267, train sigma=0.8549, val loss=0.9067, val sigma=0.6456
# Epoch 39: train loss=1.1263, train sigma=0.8546, val loss=0.9092, val sigma=0.6588
# Epoch 40: train loss=1.1259, train sigma=0.8544, val loss=0.9108, val sigma=0.6394
# Epoch 41: train loss=1.1257, train sigma=0.8541, val loss=0.9082, val sigma=0.6488
# Epoch 42: train loss=1.1249, train sigma=0.8538, val loss=0.9085, val sigma=0.6259
# Epoch 43: train loss=1.1247, train sigma=0.8533, val loss=0.9117, val sigma=0.6505
# Epoch 44: train loss=1.1243, train sigma=0.8532, val loss=0.9106, val sigma=0.6730
# Epoch 45: train loss=1.1241, train sigma=0.8530, val loss=0.9084, val sigma=0.6675
# Epoch 46: train loss=1.1238, train sigma=0.8532, val loss=0.9157, val sigma=0.6307
# Epoch 47: train loss=1.1233, train sigma=0.8529, val loss=0.9085, val sigma=0.6612
# Epoch 48: train loss=1.1229, train sigma=0.8525, val loss=0.9108, val sigma=0.6478
# Epoch 49: train loss=1.1223, train sigma=0.8520, val loss=0.9118, val sigma=0.6393
# Epoch 50: train loss=1.1221, train sigma=0.8518, val loss=0.9088, val sigma=0.6529
# Epoch 51: train loss=1.1221, train sigma=0.8513, val loss=0.9123, val sigma=0.6715
# Epoch 52: train loss=1.1216, train sigma=0.8512, val loss=0.9142, val sigma=0.6802
# Epoch 53: train loss=1.1210, train sigma=0.8513, val loss=0.9111, val sigma=0.6781
# Epoch 54: train loss=1.1207, train sigma=0.8513, val loss=0.9108, val sigma=0.6512
# Epoch 55: train loss=1.1201, train sigma=0.8509, val loss=0.9175, val sigma=0.6351
# Epoch 56: train loss=1.1194, train sigma=0.8502, val loss=0.9151, val sigma=0.6436
# Epoch 57: train loss=1.1199, train sigma=0.8501, val loss=0.9126, val sigma=0.6447
# Epoch 58: train loss=1.1187, train sigma=0.8496, val loss=0.9114, val sigma=0.6579
# Epoch 59: train loss=1.1183, train sigma=0.8498, val loss=0.9151, val sigma=0.6273
# Epoch 60: train loss=1.1182, train sigma=0.8492, val loss=0.9167, val sigma=0.6430
# Epoch 61: train loss=1.1176, train sigma=0.8493, val loss=0.9158, val sigma=0.6622
# Epoch 62: train loss=1.1166, train sigma=0.8481, val loss=0.9147, val sigma=0.6610
# Epoch 63: train loss=1.1161, train sigma=0.8482, val loss=0.9141, val sigma=0.6568
# Epoch 64: train loss=1.1160, train sigma=0.8484, val loss=0.9142, val sigma=0.6358
# Epoch 65: train loss=1.1151, train sigma=0.8474, val loss=0.9152, val sigma=0.6452
# Epoch 66: train loss=1.1144, train sigma=0.8471, val loss=0.9170, val sigma=0.6481
# Epoch 67: train loss=1.1137, train sigma=0.8464, val loss=0.9138, val sigma=0.6421
# Epoch 68: train loss=1.1134, train sigma=0.8474, val loss=0.9174, val sigma=0.6486
# Epoch 69: train loss=1.1141, train sigma=0.8467, val loss=0.9141, val sigma=0.6508
# Epoch 70: train loss=1.1139, train sigma=0.8466, val loss=0.9168, val sigma=0.6715
# Epoch 71: train loss=1.1117, train sigma=0.8457, val loss=0.9177, val sigma=0.6527
# Epoch 72: train loss=1.1112, train sigma=0.8451, val loss=0.9170, val sigma=0.6516
# Epoch 73: train loss=1.1106, train sigma=0.8450, val loss=0.9169, val sigma=0.6638
# Epoch 74: train loss=1.1100, train sigma=0.8446, val loss=0.9204, val sigma=0.6536
# Epoch 75: train loss=1.1097, train sigma=0.8439, val loss=0.9198, val sigma=0.6488
# Epoch 76: train loss=1.1093, train sigma=0.8449, val loss=0.9173, val sigma=0.6534
# Epoch 77: train loss=1.1090, train sigma=0.8445, val loss=0.9191, val sigma=0.6534
# Epoch 78: train loss=1.1082, train sigma=0.8435, val loss=0.9195, val sigma=0.6445
# Epoch 79: train loss=1.1071, train sigma=0.8430, val loss=0.9192, val sigma=0.6527
# Epoch 80: train loss=1.1068, train sigma=0.8430, val loss=0.9218, val sigma=0.6551
# Epoch 81: train loss=1.1103, train sigma=0.8449, val loss=0.9197, val sigma=0.6580
# Epoch 82: train loss=1.1072, train sigma=0.8430, val loss=0.9213, val sigma=0.6684
# Epoch 83: train loss=1.1088, train sigma=0.8448, val loss=0.9231, val sigma=0.6522
# Epoch 84: train loss=1.1062, train sigma=0.8420, val loss=0.9205, val sigma=0.6583
# Epoch 85: train loss=1.1051, train sigma=0.8424, val loss=0.9200, val sigma=0.6401
# Epoch 86: train loss=1.1042, train sigma=0.8411, val loss=0.9196, val sigma=0.6553
# Epoch 87: train loss=1.1039, train sigma=0.8414, val loss=0.9251, val sigma=0.6450
# Epoch 88: train loss=1.1030, train sigma=0.8408, val loss=0.9239, val sigma=0.6462
# Epoch 89: train loss=1.1030, train sigma=0.8411, val loss=0.9245, val sigma=0.6409
# Epoch 90: train loss=1.1024, train sigma=0.8406, val loss=0.9224, val sigma=0.6635
# Epoch 91: train loss=1.1022, train sigma=0.8410, val loss=0.9250, val sigma=0.6455
# Epoch 92: train loss=1.1012, train sigma=0.8395, val loss=0.9264, val sigma=0.6375
# Epoch 93: train loss=1.1005, train sigma=0.8400, val loss=0.9244, val sigma=0.6540
# Epoch 94: train loss=1.1001, train sigma=0.8394, val loss=0.9265, val sigma=0.6539
# Epoch 95: train loss=1.0997, train sigma=0.8389, val loss=0.9279, val sigma=0.6548
# Epoch 96: train loss=1.0989, train sigma=0.8385, val loss=0.9308, val sigma=0.6639
# Epoch 97: train loss=1.0995, train sigma=0.8394, val loss=0.9243, val sigma=0.6657
# Epoch 98: train loss=1.0982, train sigma=0.8393, val loss=0.9248, val sigma=0.6534
# Epoch 99: train loss=1.0975, train sigma=0.8384, val loss=0.9285, val sigma=0.6499
# Epoch 100: train loss=1.0980, train sigma=0.8387, val loss=0.9268, val sigma=0.6382
# Epoch 101: train loss=1.0973, train sigma=0.8388, val loss=0.9288, val sigma=0.6667
# Epoch 102: train loss=1.0963, train sigma=0.8381, val loss=0.9299, val sigma=0.6420
# Epoch 103: train loss=1.0953, train sigma=0.8372, val loss=0.9325, val sigma=0.6333
# Epoch 104: train loss=1.0945, train sigma=0.8367, val loss=0.9294, val sigma=0.6566
# Epoch 105: train loss=1.0943, train sigma=0.8372, val loss=0.9356, val sigma=0.6407
# Epoch 106: train loss=1.0957, train sigma=0.8382, val loss=0.9373, val sigma=0.6515
# Epoch 107: train loss=1.0942, train sigma=0.8368, val loss=0.9303, val sigma=0.6460
# Epoch 108: train loss=1.0932, train sigma=0.8360, val loss=0.9330, val sigma=0.6496
# Epoch 109: train loss=1.0925, train sigma=0.8354, val loss=0.9322, val sigma=0.6760
# Epoch 110: train loss=1.0935, train sigma=0.8372, val loss=0.9357, val sigma=0.6486
# Epoch 111: train loss=1.0914, train sigma=0.8355, val loss=0.9377, val sigma=0.6523
# Epoch 112: train loss=1.0910, train sigma=0.8348, val loss=0.9314, val sigma=0.6476
# Epoch 113: train loss=1.0908, train sigma=0.8352, val loss=0.9346, val sigma=0.6441
# Epoch 114: train loss=1.0897, train sigma=0.8348, val loss=0.9324, val sigma=0.6496
# Epoch 115: train loss=1.0893, train sigma=0.8346, val loss=0.9402, val sigma=0.6467
# Epoch 116: train loss=1.0898, train sigma=0.8350, val loss=0.9386, val sigma=0.6478
# Epoch 117: train loss=1.0889, train sigma=0.8341, val loss=0.9384, val sigma=0.6569
# Epoch 118: train loss=1.0887, train sigma=0.8347, val loss=0.9384, val sigma=0.6475
# Epoch 119: train loss=1.0878, train sigma=0.8335, val loss=0.9373, val sigma=0.6433
# Epoch 120: train loss=1.0868, train sigma=0.8330, val loss=0.9403, val sigma=0.6481
# Epoch 121: train loss=1.0879, train sigma=0.8340, val loss=0.9350, val sigma=0.6503
# Epoch 122: train loss=1.0872, train sigma=0.8336, val loss=0.9373, val sigma=0.6557
# Epoch 123: train loss=1.0869, train sigma=0.8330, val loss=0.9403, val sigma=0.6481
# Epoch 124: train loss=1.0853, train sigma=0.8326, val loss=0.9392, val sigma=0.6464
# Epoch 125: train loss=1.0858, train sigma=0.8330, val loss=0.9402, val sigma=0.6551
# Epoch 126: train loss=1.0845, train sigma=0.8323, val loss=0.9391, val sigma=0.6485
# Epoch 127: train loss=1.0850, train sigma=0.8329, val loss=0.9431, val sigma=0.6498
# Epoch 128: train loss=1.0903, train sigma=0.8376, val loss=0.9408, val sigma=0.6477
# Epoch 129: train loss=1.0846, train sigma=0.8331, val loss=0.9390, val sigma=0.6445
# Epoch 130: train loss=1.0828, train sigma=0.8309, val loss=0.9410, val sigma=0.6461
# Epoch 131: train loss=1.0830, train sigma=0.8319, val loss=0.9459, val sigma=0.6318
# Epoch 132: train loss=1.0831, train sigma=0.8315, val loss=0.9442, val sigma=0.6481
# Epoch 133: train loss=1.0831, train sigma=0.8316, val loss=0.9428, val sigma=0.6552
# Epoch 134: train loss=1.0812, train sigma=0.8305, val loss=0.9454, val sigma=0.6434
# Epoch 135: train loss=1.0820, train sigma=0.8316, val loss=0.9497, val sigma=0.6483
# Epoch 136: train loss=1.0837, train sigma=0.8326, val loss=0.9464, val sigma=0.6561
# Epoch 137: train loss=1.0808, train sigma=0.8311, val loss=0.9505, val sigma=0.6373
# Epoch 138: train loss=1.0806, train sigma=0.8305, val loss=0.9452, val sigma=0.6435
# Epoch 139: train loss=1.0815, train sigma=0.8313, val loss=0.9486, val sigma=0.6571
# Epoch 140: train loss=1.0802, train sigma=0.8303, val loss=0.9444, val sigma=0.6667
# Epoch 141: train loss=1.0798, train sigma=0.8307, val loss=0.9440, val sigma=0.6473
# Epoch 142: train loss=1.0798, train sigma=0.8299, val loss=0.9482, val sigma=0.6491
# Epoch 143: train loss=1.0796, train sigma=0.8305, val loss=0.9491, val sigma=0.6458
# Epoch 144: train loss=1.0783, train sigma=0.8293, val loss=0.9515, val sigma=0.6535
# Epoch 145: train loss=1.0792, train sigma=0.8306, val loss=0.9588, val sigma=0.6483
# Epoch 146: train loss=1.0787, train sigma=0.8300, val loss=0.9532, val sigma=0.6448
# Epoch 147: train loss=1.1041, train sigma=0.8494, val loss=0.9310, val sigma=0.7037
# Epoch 148: train loss=1.1065, train sigma=0.8469, val loss=0.9337, val sigma=0.6537
# Epoch 149: train loss=1.0896, train sigma=0.8346, val loss=0.9393, val sigma=0.6485
# Epoch 150: train loss=1.0811, train sigma=0.8296, val loss=0.9450, val sigma=0.6417
# Epoch 151: train loss=1.0779, train sigma=0.8282, val loss=0.9462, val sigma=0.6550
# Epoch 152: train loss=1.0767, train sigma=0.8277, val loss=0.9481, val sigma=0.6445
# Epoch 153: train loss=1.0804, train sigma=0.8299, val loss=0.9500, val sigma=0.6347
# Epoch 154: train loss=1.0760, train sigma=0.8279, val loss=0.9516, val sigma=0.6341
# Epoch 155: train loss=1.0762, train sigma=0.8277, val loss=0.9508, val sigma=0.6436
# Epoch 156: train loss=1.0765, train sigma=0.8284, val loss=0.9539, val sigma=0.6370
# Epoch 157: train loss=1.0754, train sigma=0.8278, val loss=0.9509, val sigma=0.6416
# Epoch 158: train loss=1.0756, train sigma=0.8293, val loss=0.9499, val sigma=0.6473
# Epoch 159: train loss=1.0762, train sigma=0.8287, val loss=0.9555, val sigma=0.6408
# Epoch 160: train loss=1.0747, train sigma=0.8281, val loss=0.9589, val sigma=0.6416
# Epoch 161: train loss=1.0772, train sigma=0.8294, val loss=0.9536, val sigma=0.6411
# Epoch 162: train loss=1.0750, train sigma=0.8281, val loss=0.9534, val sigma=0.6485
# Epoch 163: train loss=1.0754, train sigma=0.8288, val loss=0.9496, val sigma=0.6484
# Epoch 164: train loss=1.0766, train sigma=0.8305, val loss=0.9503, val sigma=0.6499
# Epoch 165: train loss=1.0762, train sigma=0.8292, val loss=0.9604, val sigma=0.6386
# Epoch 166: train loss=1.0743, train sigma=0.8276, val loss=0.9570, val sigma=0.6371
# Epoch 167: train loss=1.0720, train sigma=0.8270, val loss=0.9640, val sigma=0.6415
# Epoch 168: train loss=1.0723, train sigma=0.8268, val loss=0.9548, val sigma=0.6522
# Epoch 169: train loss=1.0730, train sigma=0.8281, val loss=0.9557, val sigma=0.6490
# Epoch 170: train loss=1.0737, train sigma=0.8286, val loss=0.9590, val sigma=0.6432
# Epoch 171: train loss=1.0786, train sigma=0.8313, val loss=0.9508, val sigma=0.6497
# Epoch 172: train loss=1.0738, train sigma=0.8274, val loss=0.9542, val sigma=0.6580
# Epoch 173: train loss=1.0720, train sigma=0.8269, val loss=0.9579, val sigma=0.6454
# Epoch 174: train loss=1.0724, train sigma=0.8278, val loss=0.9576, val sigma=0.6336
# Epoch 175: train loss=1.0741, train sigma=0.8274, val loss=0.9619, val sigma=0.6493
# Epoch 176: train loss=1.0734, train sigma=0.8278, val loss=0.9564, val sigma=0.6570
# Epoch 177: train loss=1.0704, train sigma=0.8257, val loss=0.9577, val sigma=0.6425
# Epoch 178: train loss=1.0711, train sigma=0.8266, val loss=0.9609, val sigma=0.6416
# Epoch 179: train loss=1.0706, train sigma=0.8273, val loss=0.9576, val sigma=0.6310
# Epoch 180: train loss=1.0720, train sigma=0.8266, val loss=0.9543, val sigma=0.6601
# Epoch 181: train loss=1.0716, train sigma=0.8270, val loss=0.9548, val sigma=0.6552
# Epoch 182: train loss=1.0701, train sigma=0.8264, val loss=0.9538, val sigma=0.6571
# Epoch 183: train loss=1.0724, train sigma=0.8286, val loss=0.9603, val sigma=0.6443
# Epoch 184: train loss=1.0692, train sigma=0.8257, val loss=0.9608, val sigma=0.6444
# Epoch 185: train loss=1.0703, train sigma=0.8261, val loss=0.9614, val sigma=0.6301
# Epoch 186: train loss=1.0694, train sigma=0.8261, val loss=0.9571, val sigma=0.6516
# Epoch 187: train loss=1.0742, train sigma=0.8294, val loss=0.9535, val sigma=0.6650
# Epoch 188: train loss=1.0704, train sigma=0.8268, val loss=0.9631, val sigma=0.6321
# Epoch 189: train loss=1.0693, train sigma=0.8256, val loss=0.9594, val sigma=0.6555
# Epoch 190: train loss=1.0697, train sigma=0.8265, val loss=0.9616, val sigma=0.6374
# Epoch 191: train loss=1.0675, train sigma=0.8251, val loss=0.9584, val sigma=0.6435
# Epoch 192: train loss=1.0680, train sigma=0.8261, val loss=0.9609, val sigma=0.6376
# Epoch 193: train loss=1.0693, train sigma=0.8263, val loss=0.9564, val sigma=0.6511
# Epoch 194: train loss=1.0720, train sigma=0.8276, val loss=0.9606, val sigma=0.6415
# Epoch 195: train loss=1.0690, train sigma=0.8264, val loss=0.9609, val sigma=0.6465
# Epoch 196: train loss=1.0681, train sigma=0.8253, val loss=0.9592, val sigma=0.6447
# Epoch 197: train loss=1.0695, train sigma=0.8274, val loss=0.9668, val sigma=0.6489
# Epoch 198: train loss=1.0675, train sigma=0.8251, val loss=0.9606, val sigma=0.6477
# Epoch 199: train loss=1.0698, train sigma=0.8274, val loss=0.9670, val sigma=0.6379
# Epoch 200: train loss=1.0689, train sigma=0.8258, val loss=0.9596, val sigma=0.6525
# Epoch 201: train loss=1.0661, train sigma=0.8250, val loss=0.9626, val sigma=0.6414
# Epoch 202: train loss=1.0682, train sigma=0.8254, val loss=0.9556, val sigma=0.6533
# Epoch 203: train loss=1.0907, train sigma=0.8427, val loss=0.9473, val sigma=0.6531
# Epoch 204: train loss=1.0840, train sigma=0.8372, val loss=0.9543, val sigma=0.6441
# Epoch 205: train loss=1.0752, train sigma=0.8303, val loss=0.9581, val sigma=0.6415
# Epoch 206: train loss=1.0741, train sigma=0.8299, val loss=0.9486, val sigma=0.6503
# Epoch 207: train loss=1.0688, train sigma=0.8265, val loss=0.9607, val sigma=0.6341
# Epoch 208: train loss=1.0663, train sigma=0.8239, val loss=0.9611, val sigma=0.6510
# Epoch 209: train loss=1.0654, train sigma=0.8235, val loss=0.9601, val sigma=0.6487
# Epoch 210: train loss=1.0653, train sigma=0.8244, val loss=0.9601, val sigma=0.6424
# Epoch 211: train loss=1.0663, train sigma=0.8251, val loss=0.9646, val sigma=0.6518
# Epoch 212: train loss=1.0645, train sigma=0.8238, val loss=0.9636, val sigma=0.6458
# Epoch 213: train loss=1.0723, train sigma=0.8302, val loss=0.9655, val sigma=0.6419
# Epoch 214: train loss=1.0664, train sigma=0.8252, val loss=0.9614, val sigma=0.6510
# Epoch 215: train loss=1.0668, train sigma=0.8252, val loss=0.9671, val sigma=0.6440
# Epoch 216: train loss=1.0644, train sigma=0.8234, val loss=0.9655, val sigma=0.6509
# Epoch 217: train loss=1.0646, train sigma=0.8244, val loss=0.9651, val sigma=0.6404
# Epoch 218: train loss=1.0646, train sigma=0.8238, val loss=0.9722, val sigma=0.6359
# Epoch 219: train loss=1.0661, train sigma=0.8252, val loss=0.9619, val sigma=0.6451
# Epoch 220: train loss=1.0645, train sigma=0.8247, val loss=0.9655, val sigma=0.6566
# Epoch 221: train loss=1.0646, train sigma=0.8242, val loss=0.9644, val sigma=0.6472
# Epoch 222: train loss=1.0663, train sigma=0.8257, val loss=0.9642, val sigma=0.6470
# Epoch 223: train loss=1.0666, train sigma=0.8257, val loss=0.9573, val sigma=0.6511
# Epoch 224: train loss=1.0658, train sigma=0.8257, val loss=0.9763, val sigma=0.6379
# Epoch 225: train loss=1.0657, train sigma=0.8253, val loss=0.9710, val sigma=0.6402
# Epoch 226: train loss=1.0662, train sigma=0.8250, val loss=0.9670, val sigma=0.6499
# Epoch 227: train loss=1.0630, train sigma=0.8231, val loss=0.9733, val sigma=0.6433
# Epoch 228: train loss=1.0628, train sigma=0.8234, val loss=0.9696, val sigma=0.6411
# Epoch 229: train loss=1.0628, train sigma=0.8238, val loss=0.9757, val sigma=0.6404
# Epoch 230: train loss=1.0628, train sigma=0.8229, val loss=0.9690, val sigma=0.6387
# Epoch 231: train loss=1.0640, train sigma=0.8250, val loss=0.9741, val sigma=0.6432
# Epoch 232: train loss=1.0633, train sigma=0.8240, val loss=0.9659, val sigma=0.6384
# Epoch 233: train loss=1.0738, train sigma=0.8312, val loss=0.9610, val sigma=0.6531
# Epoch 234: train loss=1.0655, train sigma=0.8250, val loss=0.9651, val sigma=0.6414
# Epoch 235: train loss=1.0633, train sigma=0.8235, val loss=0.9727, val sigma=0.6444
# Epoch 236: train loss=1.0636, train sigma=0.8242, val loss=0.9766, val sigma=0.6477
# Epoch 237: train loss=1.0621, train sigma=0.8231, val loss=0.9781, val sigma=0.6326
# Epoch 238: train loss=1.0613, train sigma=0.8221, val loss=0.9721, val sigma=0.6414
# Epoch 239: train loss=1.0636, train sigma=0.8246, val loss=0.9834, val sigma=0.6347
# Epoch 240: train loss=1.0637, train sigma=0.8244, val loss=0.9732, val sigma=0.6397
# Epoch 241: train loss=1.0610, train sigma=0.8225, val loss=0.9707, val sigma=0.6504
# Epoch 242: train loss=1.0620, train sigma=0.8233, val loss=0.9765, val sigma=0.6497
# Epoch 243: train loss=1.0638, train sigma=0.8258, val loss=0.9696, val sigma=0.6443
# Epoch 244: train loss=1.0602, train sigma=0.8216, val loss=0.9708, val sigma=0.6429
# Epoch 245: train loss=1.0618, train sigma=0.8237, val loss=0.9694, val sigma=0.6434
# Epoch 246: train loss=1.0616, train sigma=0.8230, val loss=0.9702, val sigma=0.6539
# Epoch 247: train loss=1.0608, train sigma=0.8231, val loss=0.9765, val sigma=0.6407
# Epoch 248: train loss=1.0618, train sigma=0.8235, val loss=0.9749, val sigma=0.6386
# Epoch 249: train loss=1.0619, train sigma=0.8242, val loss=0.9711, val sigma=0.6445
# Epoch 250: train loss=1.0613, train sigma=0.8228, val loss=0.9771, val sigma=0.6424
# Epoch 251: train loss=1.0613, train sigma=0.8230, val loss=0.9749, val sigma=0.6456
# Epoch 252: train loss=1.0608, train sigma=0.8222, val loss=0.9724, val sigma=0.6499
# Epoch 253: train loss=1.0610, train sigma=0.8239, val loss=0.9734, val sigma=0.6370
# Epoch 254: train loss=1.0609, train sigma=0.8229, val loss=0.9687, val sigma=0.6547
# Epoch 255: train loss=1.0588, train sigma=0.8214, val loss=0.9771, val sigma=0.6360
# Epoch 256: train loss=1.0606, train sigma=0.8234, val loss=0.9698, val sigma=0.6476
# Epoch 257: train loss=1.0606, train sigma=0.8228, val loss=0.9714, val sigma=0.6387
# Epoch 258: train loss=1.0619, train sigma=0.8241, val loss=0.9682, val sigma=0.6468
# Epoch 259: train loss=1.0625, train sigma=0.8242, val loss=0.9763, val sigma=0.6457
# Epoch 260: train loss=1.0596, train sigma=0.8225, val loss=0.9792, val sigma=0.6311
# Epoch 261: train loss=1.0594, train sigma=0.8216, val loss=0.9826, val sigma=0.6396
# Epoch 262: train loss=1.0599, train sigma=0.8226, val loss=0.9732, val sigma=0.6530
# Epoch 263: train loss=1.0595, train sigma=0.8217, val loss=0.9840, val sigma=0.6488
# Epoch 264: train loss=1.0590, train sigma=0.8221, val loss=0.9797, val sigma=0.6404
# Epoch 265: train loss=1.0584, train sigma=0.8217, val loss=0.9809, val sigma=0.6360
# Epoch 266: train loss=1.0592, train sigma=0.8228, val loss=0.9831, val sigma=0.6323
# Epoch 267: train loss=1.0603, train sigma=0.8224, val loss=0.9829, val sigma=0.6337
# Epoch 268: train loss=1.0608, train sigma=0.8237, val loss=0.9732, val sigma=0.6413
# Epoch 269: train loss=1.0582, train sigma=0.8214, val loss=0.9809, val sigma=0.6508
# Epoch 270: train loss=1.0586, train sigma=0.8224, val loss=0.9766, val sigma=0.6499
# Epoch 271: train loss=1.0614, train sigma=0.8245, val loss=0.9777, val sigma=0.6499
# Epoch 272: train loss=1.0603, train sigma=0.8220, val loss=0.9721, val sigma=0.6484
# Epoch 273: train loss=1.0573, train sigma=0.8211, val loss=0.9746, val sigma=0.6395
# Epoch 274: train loss=1.0622, train sigma=0.8253, val loss=0.9744, val sigma=0.6425
# Epoch 275: train loss=1.0582, train sigma=0.8214, val loss=0.9771, val sigma=0.6393
# Epoch 276: train loss=1.0580, train sigma=0.8214, val loss=0.9814, val sigma=0.6510
# Epoch 277: train loss=1.0591, train sigma=0.8234, val loss=0.9728, val sigma=0.6412
# Epoch 278: train loss=1.0589, train sigma=0.8224, val loss=0.9806, val sigma=0.6423
# Epoch 279: train loss=1.0570, train sigma=0.8205, val loss=0.9859, val sigma=0.6367
# Epoch 280: train loss=1.0591, train sigma=0.8232, val loss=0.9822, val sigma=0.6369
# Epoch 281: train loss=1.0619, train sigma=0.8249, val loss=0.9733, val sigma=0.6410
# Epoch 282: train loss=1.0589, train sigma=0.8219, val loss=0.9781, val sigma=0.6393
# Epoch 283: train loss=1.0587, train sigma=0.8222, val loss=0.9760, val sigma=0.6379
# Epoch 284: train loss=1.0627, train sigma=0.8261, val loss=0.9751, val sigma=0.6429
# Epoch 285: train loss=1.0570, train sigma=0.8211, val loss=0.9771, val sigma=0.6427
# Epoch 286: train loss=1.0564, train sigma=0.8201, val loss=0.9774, val sigma=0.6464
# Epoch 287: train loss=1.0601, train sigma=0.8238, val loss=0.9703, val sigma=0.6468
# Epoch 288: train loss=1.0578, train sigma=0.8216, val loss=0.9805, val sigma=0.6452
# Epoch 289: train loss=1.0568, train sigma=0.8200, val loss=0.9747, val sigma=0.6475
# Epoch 290: train loss=1.0605, train sigma=0.8237, val loss=0.9787, val sigma=0.6404
# Epoch 291: train loss=1.0693, train sigma=0.8289, val loss=0.9860, val sigma=0.6280
# Epoch 292: train loss=1.0616, train sigma=0.8244, val loss=0.9797, val sigma=0.6396
# Epoch 293: train loss=1.0586, train sigma=0.8215, val loss=0.9784, val sigma=0.6452
# Epoch 294: train loss=1.0605, train sigma=0.8242, val loss=0.9704, val sigma=0.6400
# Epoch 295: train loss=1.0593, train sigma=0.8221, val loss=0.9758, val sigma=0.6416
# Epoch 296: train loss=1.0607, train sigma=0.8234, val loss=0.9683, val sigma=0.6402
# Epoch 297: train loss=1.0589, train sigma=0.8226, val loss=0.9793, val sigma=0.6347
# Epoch 298: train loss=1.0572, train sigma=0.8209, val loss=0.9791, val sigma=0.6371
# Epoch 299: train loss=1.0594, train sigma=0.8237, val loss=0.9887, val sigma=0.6304

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,5))
plt.plot(loss_history, label="Train Loss", linewidth=2)
plt.plot(val_loss_history, label="Validation Loss", linewidth=2)
plt.xlabel("Epoch")
plt.ylabel("Loss (NLL)")
plt.title("Train vs Validation Loss - Model: Simple LSTM + Normal Distribution + 60-to-1")
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

plt.figure(figsize=(12,5))
plt.plot(sigma_history, label="Train Sigma", linewidth=2)
plt.plot(val_sigma_history, label="Validation Sigma", linewidth=2)
plt.xlabel("Epoch")
plt.ylabel("Sigma")
plt.title("Train vs Validation Sigma (averaged cross sample) - Model: Simple LSTM + Normal Distribution + 60-to-1")
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# Model:
# $$x_{t+1}|{x_{t-60}, x_{t-59},\cdots, x_t} \sim  \mathcal{N}(0, \sigma_t)$$
#
# By looking at the analysis above:
# - There is a problem of overfitting.
#     - Add early stopping or other regulation methods.
#     - As X is highly overlapping, ($X_{t1}$ and $X_{t2}$ may share 59 common data), try select one $X_t$ for a fixed window?
# - The vol learned is during training (for the first 60% of data) is much higher than the vol learned during validation (60%-80% of the data), why? The training period is post Covid and Fed cuts and hikes (2020/10-2023/9). The validation period is almost the period when Fed on hold, (2023/10-2024/9). Does this mean we should randomize the days in creating the train/validation/test data?
