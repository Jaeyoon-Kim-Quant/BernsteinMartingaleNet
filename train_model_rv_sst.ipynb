# %%
# output folder, dist type, optional parameter for dist type

import sys
import os
import torch

cwd = os.getcwd()
root = cwd.split("BernsteinMartingaleNet")[0] + "BernsteinMartingaleNet"
if root not in sys.path:
    sys.path.append(root)

from lib.utils import train_model, get_full_sequence_data_by_day
from lib.BLogistic import BLogistic, MixedBLogistic
from lib.DistHead import NormalHead, StudentTHead, SkewedStudentTHead
from lib.Michenkow import MichenkowManytoMany
assert torch.cuda.is_available()
device = torch.device('cuda')

# %%
dist_type  = "SkewedStudentT"
dist_param = ""
output_folder =  root + f"/MichenkowResults/{dist_type}NoReg_RV/"

# %%
dist_head = None
if dist_type == "Normal":
    dist_head = NormalHead(device)
elif dist_type == "StudentT":
    dist_head = StudentTHead(device)
elif dist_type == "SkewedStudentT":
    dist_head = SkewedStudentTHead(device)
elif dist_type == "BLogistic":
    if dist_param == "":
        raise ValueError("BLogistic dist type requires a degree parameter")
    dof = int(dist_param)
    dist_head = BLogistic(dof - 2, device)
elif dist_type == "MixedBLogistic":
    if dist_param == "":
        raise ValueError("MixedBLogistic dist type requires a degree parameter")
    dof = int(dist_param)
    dist_head = MixedBLogistic(dof, device)
else:
    raise ValueError(f"Invalid dist type: {dist_type}")

folder_path = root + "/MarketData/historical_data"

# %%
train, dev, test = get_full_sequence_data_by_day(folder_path, 0.2, 0.2, force_recompute=True)
print("train", train.shape)
print("dev", dev.shape)
print("test", test.shape)
# Out:
# skipping 2020-11-27
# skipping 2020-12-24
# skipping 2021-11-26
# skipping 2022-11-25
# skipping 2023-07-03
# skipping 2023-11-24
# skipping 2024-07-03
# skipping 2024-11-29
# skipping 2024-12-24
# skipping 2025-07-03
# train (748, 391, 3)
# dev (249, 391, 3)
# test (249, 391, 3)

# %%
train = torch.tensor(train, device=device)
dev = torch.tensor(dev, device=device)
test = torch.tensor(test, device=device)

train_xs = train[:, :-1, 0:2]
dev_xs = dev[:, :-1, 0:2]
test_xs = test[:, :-1, 0:2]

train_ys = train[:, 1:, 0]
dev_ys = dev[:, 1:, 0]
test_ys = test[:, 1:, 0]

std_x = torch.sqrt((train_xs**2).mean(dim=(0, 1)))  # Shape: (2,)
mean_x = train_xs.mean(dim=(0, 1))

print("std x:", std_x)
print("mean_x:", mean_x)

std_y = torch.sqrt((train_ys**2).mean(dim=(0, 1)))  # Shape: (2,)
mean_y = train_ys.mean(dim=(0, 1))

print("std y:", std_y)
print("mean y:", mean_y)

train_xs = (train_xs-mean_x) / std_x
dev_xs = (dev_xs-mean_x) / std_x
test_xs = (test_xs-mean_x) / std_x
train_ys = (train_ys-mean_y) / std_y
dev_ys = (dev_ys-mean_y) / std_y
test_ys = (test_ys-mean_y) / std_y

print("X train:", train_xs.shape, "y train", train_ys.shape)
print("X dev:", dev_xs.shape, "y dev", dev_ys.shape)
print("X test:", test_xs.shape, "y test", test_ys.shape)
# Out:
# std x: tensor([4.2369e-04, 5.0592e-07], device='cuda:0')
# mean_x: tensor([-2.3330e-07,  1.7856e-07], device='cuda:0')
# std y: tensor(0.0004, device='cuda:0')
# mean y: tensor(-2.1644e-07, device='cuda:0')
# X train: torch.Size([748, 390, 2]) y train torch.Size([748, 390])
# X dev: torch.Size([249, 390, 2]) y dev torch.Size([249, 390])
# X test: torch.Size([249, 390, 2]) y test torch.Size([249, 390])

# %%
lr = 0.002
decay_step = 200
decay_gamma = 0.5
weight_decay = 0
weight_decay = 0.000
num_steps = 400 + 1
batch_size = 1024

# %%
m2m_model = MichenkowManytoMany(dist_head, device, feature_size=2)

model, train_losses, dev_losses = train_model(m2m_model,
                                              train_xs, train_ys, dev_xs, dev_ys, test_xs,test_ys, lr, weight_decay, num_steps, batch_size=batch_size, device=device, output_folder=output_folder, lr_decay_step=decay_step, lr_decay_gamma=decay_gamma)
# Out:
# Initializing LSTM with dist=SkewedStudentTHead, dof=3
# num batches 0
# Init, Train Loss: 1.5367, Dev Loss: 1.5398, Dev Loss confidence interval: 1.5350, 1.5446
# Step 0, Train Loss: 1.5276, Dev Loss: 1.5310, Dev Loss confidence interval: 1.5262, 1.5358, LR: 0.002000
# Step 10, Train Loss: 1.2536, Dev Loss: 1.2736, Dev Loss confidence interval: 1.2667, 1.2804, LR: 0.002000
# Step 20, Train Loss: 1.2456, Dev Loss: 1.2687, Dev Loss confidence interval: 1.2615, 1.2758, LR: 0.002000
# Step 30, Train Loss: 1.2286, Dev Loss: 1.2514, Dev Loss confidence interval: 1.2447, 1.2582, LR: 0.002000
# Step 40, Train Loss: 1.2202, Dev Loss: 1.2458, Dev Loss confidence interval: 1.2387, 1.2529, LR: 0.002000
# Step 50, Train Loss: 1.2099, Dev Loss: 1.2353, Dev Loss confidence interval: 1.2282, 1.2425, LR: 0.002000
# Step 60, Train Loss: 1.1880, Dev Loss: 1.2098, Dev Loss confidence interval: 1.2031, 1.2165, LR: 0.002000
# Step 70, Train Loss: 1.1672, Dev Loss: 1.1842, Dev Loss confidence interval: 1.1775, 1.1910, LR: 0.002000
# Step 80, Train Loss: 1.1520, Dev Loss: 1.1701, Dev Loss confidence interval: 1.1632, 1.1770, LR: 0.002000
# Step 90, Train Loss: 1.1493, Dev Loss: 1.1697, Dev Loss confidence interval: 1.1628, 1.1766, LR: 0.002000
# Step 100, Train Loss: 1.1269, Dev Loss: 1.1470, Dev Loss confidence interval: 1.1409, 1.1531, LR: 0.002000
# Step 110, Train Loss: 1.1407, Dev Loss: 1.1634, Dev Loss confidence interval: 1.1570, 1.1698, LR: 0.002000
# Step 120, Train Loss: 1.1384, Dev Loss: 1.1598, Dev Loss confidence interval: 1.1534, 1.1661, LR: 0.002000
# Step 130, Train Loss: 1.1205, Dev Loss: 1.1420, Dev Loss confidence interval: 1.1358, 1.1482, LR: 0.002000
# Step 140, Train Loss: 1.1223, Dev Loss: 1.1449, Dev Loss confidence interval: 1.1391, 1.1508, LR: 0.002000
# Step 150, Train Loss: 1.1938, Dev Loss: 1.2148, Dev Loss confidence interval: 1.2080, 1.2216, LR: 0.002000
# Step 160, Train Loss: 1.1392, Dev Loss: 1.1609, Dev Loss confidence interval: 1.1546, 1.1672, LR: 0.002000
# Step 170, Train Loss: 1.1149, Dev Loss: 1.1384, Dev Loss confidence interval: 1.1320, 1.1449, LR: 0.002000
# Step 180, Train Loss: 1.1023, Dev Loss: 1.1240, Dev Loss confidence interval: 1.1178, 1.1302, LR: 0.002000
# Step 190, Train Loss: 1.0971, Dev Loss: 1.1194, Dev Loss confidence interval: 1.1133, 1.1255, LR: 0.002000
# Step 200, Train Loss: 1.0919, Dev Loss: 1.1142, Dev Loss confidence interval: 1.1080, 1.1203, LR: 0.001000
# Step 210, Train Loss: 1.0904, Dev Loss: 1.1127, Dev Loss confidence interval: 1.1066, 1.1189, LR: 0.001000
# Step 220, Train Loss: 1.0897, Dev Loss: 1.1120, Dev Loss confidence interval: 1.1059, 1.1181, LR: 0.001000
# Step 230, Train Loss: 1.0885, Dev Loss: 1.1108, Dev Loss confidence interval: 1.1046, 1.1169, LR: 0.001000
# Step 240, Train Loss: 1.0877, Dev Loss: 1.1100, Dev Loss confidence interval: 1.1038, 1.1162, LR: 0.001000
# Step 250, Train Loss: 1.0874, Dev Loss: 1.1098, Dev Loss confidence interval: 1.1035, 1.1160, LR: 0.001000
# Step 260, Train Loss: 1.0868, Dev Loss: 1.1091, Dev Loss confidence interval: 1.1029, 1.1154, LR: 0.001000
# Step 270, Train Loss: 1.0863, Dev Loss: 1.1087, Dev Loss confidence interval: 1.1025, 1.1149, LR: 0.001000
# Step 280, Train Loss: 1.0860, Dev Loss: 1.1083, Dev Loss confidence interval: 1.1021, 1.1145, LR: 0.001000
# Step 290, Train Loss: 1.0856, Dev Loss: 1.1080, Dev Loss confidence interval: 1.1018, 1.1142, LR: 0.001000
# Step 300, Train Loss: 1.0853, Dev Loss: 1.1077, Dev Loss confidence interval: 1.1015, 1.1139, LR: 0.001000
# Step 310, Train Loss: 1.0850, Dev Loss: 1.1074, Dev Loss confidence interval: 1.1012, 1.1136, LR: 0.001000
# Step 320, Train Loss: 1.0847, Dev Loss: 1.1072, Dev Loss confidence interval: 1.1010, 1.1133, LR: 0.001000
# Step 330, Train Loss: 1.0844, Dev Loss: 1.1069, Dev Loss confidence interval: 1.1006, 1.1131, LR: 0.001000
# Step 340, Train Loss: 1.0841, Dev Loss: 1.1066, Dev Loss confidence interval: 1.1004, 1.1128, LR: 0.001000
# Step 350, Train Loss: 1.0838, Dev Loss: 1.1063, Dev Loss confidence interval: 1.1001, 1.1126, LR: 0.001000
# Step 360, Train Loss: 1.0836, Dev Loss: 1.1061, Dev Loss confidence interval: 1.0999, 1.1123, LR: 0.001000
# Step 370, Train Loss: 1.0836, Dev Loss: 1.1061, Dev Loss confidence interval: 1.0999, 1.1122, LR: 0.001000
# Step 380, Train Loss: 1.0831, Dev Loss: 1.1057, Dev Loss confidence interval: 1.0995, 1.1119, LR: 0.001000
# Step 390, Train Loss: 1.0829, Dev Loss: 1.1055, Dev Loss confidence interval: 1.0992, 1.1117, LR: 0.001000
# Step 400, Train Loss: 1.0827, Dev Loss: 1.1053, Dev Loss confidence interval: 1.0991, 1.1115, LR: 0.000500
# Best epoch: 400
# Final Train Loss: 1.0827, Final Train Loss confidence interval: 1.0790, 1.0863
# Final Dev Loss: 1.1053, Final Dev Loss confidence interval: 1.0990, 1.1116
# Test Loss: 1.0548, Test Loss confidence interval: 1.0484, 1.0613

# %%
import matplotlib.pyplot as plt
import numpy as np

steps = np.arange(0, len(train_losses) * 10, 10)  # Since you log every 10 steps

plt.figure(figsize=(10, 6))
plt.plot(steps, train_losses, label='Train Loss', linewidth=2)
plt.plot(steps, dev_losses, label='Dev Loss', linewidth=2)
plt.xlabel('Training Step')
plt.ylabel('Loss (Negative Log-Likelihood)')
plt.title(f"Training and Validation Loss of {dist_type}_NoReg_RV")
plt.legend()
plt.grid(True, alpha=0.3)
plt.axhline(y=0, color='r', linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()
