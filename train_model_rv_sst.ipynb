# %%
# output folder, dist type, optional parameter for dist type

import sys
import os
import torch

cwd = os.getcwd()
root = cwd.split("BernsteinMartingaleNet")[0] + "BernsteinMartingaleNet"
if root not in sys.path:
    sys.path.append(root)

from lib.utils import train_model, get_full_sequence_data_by_day
from lib.BLogistic import BLogistic, MixedBLogistic
from lib.DistHead import NormalHead, StudentTHead, SkewedStudentTHead
from lib.Michenkow import MichenkowManytoMany
assert torch.cuda.is_available()
device = torch.device('cuda')

# %%
dist_type  = "SkewedStudentT"
dist_param = ""
output_folder =  root + f"/MichenkowResults/{dist_type}NoReg_RV/"

# %%
dist_head = None
if dist_type == "Normal":
    dist_head = NormalHead(device)
elif dist_type == "StudentT":
    dist_head = StudentTHead(device)
elif dist_type == "SkewedStudentT":
    dist_head = SkewedStudentTHead(device)
elif dist_type == "BLogistic":
    if dist_param == "":
        raise ValueError("BLogistic dist type requires a degree parameter")
    dof = int(dist_param)
    dist_head = BLogistic(dof - 2, device)
elif dist_type == "MixedBLogistic":
    if dist_param == "":
        raise ValueError("MixedBLogistic dist type requires a degree parameter")
    dof = int(dist_param)
    dist_head = MixedBLogistic(dof, device)
else:
    raise ValueError(f"Invalid dist type: {dist_type}")

folder_path = root + "/MarketData/historical_data"

# %%
train, dev, test = get_full_sequence_data_by_day(folder_path, 0.2, 0.2, force_recompute=True)
print("train", train.shape)
print("dev", dev.shape)
print("test", test.shape)
# Out:
# skipping 2020-11-27
# skipping 2020-12-24
# skipping 2021-11-26
# skipping 2022-11-25
# skipping 2023-07-03
# skipping 2023-11-24
# skipping 2024-07-03
# skipping 2024-11-29
# skipping 2024-12-24
# skipping 2025-07-03
# 1246
# train (748, 391, 3)
# dev (249, 391, 3)
# test (249, 391, 3)

# %%
train = torch.tensor(train, device=device)
dev = torch.tensor(dev, device=device)
test = torch.tensor(test, device=device)

train_xs = train[:, :-1, 0:2]
dev_xs = dev[:, :-1, 0:2]
test_xs = test[:, :-1, 0:2]

train_ys = train[:, 1:, 0]
dev_ys = dev[:, 1:, 0]
test_ys = test[:, 1:, 0]

std_x = torch.sqrt((train_xs**2).mean(dim=(0, 1)))  # Shape: (2,)
mean_x = train_xs.mean(dim=(0, 1))

print("std x:", std_x)
print("mean_x:", mean_x)

std_y = torch.sqrt((train_ys**2).mean(dim=(0, 1)))  # Shape: (2,)
mean_y = train_ys.mean(dim=(0, 1))

print("std y:", std_y)
print("mean y:", mean_y)

train_xs = (train_xs-mean_x) / std_x
dev_xs = (dev_xs-mean_x) / std_x
test_xs = (test_xs-mean_x) / std_x
train_ys = (train_ys-mean_y) / std_y
dev_ys = (dev_ys-mean_y) / std_y
test_ys = (test_ys-mean_y) / std_y

print("X train:", train_xs.shape, "y train", train_ys.shape)
print("X dev:", dev_xs.shape, "y dev", dev_ys.shape)
print("X test:", test_xs.shape, "y test", test_ys.shape)
# Out:
# std x: tensor([4.2369e-04, 5.0592e-07], device='cuda:0')
# mean_x: tensor([-2.3330e-07,  1.7856e-07], device='cuda:0')
# std y: tensor(5.1853e-07, device='cuda:0')
# mean y: tensor(1.7846e-07, device='cuda:0')
# X train: torch.Size([748, 390, 2]) y train torch.Size([748, 390])
# X dev: torch.Size([249, 390, 2]) y dev torch.Size([249, 390])
# X test: torch.Size([249, 390, 2]) y test torch.Size([249, 390])

# %%
lr = 0.002
decay_step = 200
decay_gamma = 0.5
weight_decay = 0
weight_decay = 0.000
num_steps = 400 + 1
batch_size = 1024

# %%
m2m_model = MichenkowManytoMany(dist_head, device, feature_size=2)

model, train_losses, dev_losses = train_model(m2m_model,
                                              train_xs, train_ys, dev_xs, dev_ys, test_xs,test_ys, lr, weight_decay, num_steps, batch_size=batch_size, device=device, output_folder=output_folder, lr_decay_step=decay_step, lr_decay_gamma=decay_gamma)
# Out:
# Initializing LSTM with dist=SkewedStudentTHead, dof=3
# num batches 0
# Init, Train Loss: 1.4273, Dev Loss: 1.4044, Dev Loss confidence interval: 1.4018, 1.4070
# Step 0, Train Loss: 1.4108, Dev Loss: 1.3880, Dev Loss confidence interval: 1.3854, 1.3906, LR: 0.002000
# Step 10, Train Loss: 0.6716, Dev Loss: 0.6639, Dev Loss confidence interval: 0.6599, 0.6679, LR: 0.002000
# Step 20, Train Loss: 0.1705, Dev Loss: 0.1933, Dev Loss confidence interval: 0.1871, 0.1995, LR: 0.002000
# Step 30, Train Loss: -0.0673, Dev Loss: -0.0426, Dev Loss confidence interval: -0.0490, -0.0363, LR: 0.002000
# Step 40, Train Loss: -0.1509, Dev Loss: -0.1237, Dev Loss confidence interval: -0.1300, -0.1175, LR: 0.002000
# Step 50, Train Loss: -0.1912, Dev Loss: -0.1562, Dev Loss confidence interval: -0.1624, -0.1499, LR: 0.002000
# Step 60, Train Loss: -0.2394, Dev Loss: -0.2062, Dev Loss confidence interval: -0.2121, -0.2003, LR: 0.002000
# Step 70, Train Loss: -0.3020, Dev Loss: -0.2622, Dev Loss confidence interval: -0.2688, -0.2556, LR: 0.002000
# Step 80, Train Loss: -0.3730, Dev Loss: -0.3297, Dev Loss confidence interval: -0.3367, -0.3228, LR: 0.002000
# Step 90, Train Loss: -0.4558, Dev Loss: -0.4236, Dev Loss confidence interval: -0.4308, -0.4163, LR: 0.002000
# Step 100, Train Loss: -0.6727, Dev Loss: -0.6454, Dev Loss confidence interval: -0.6527, -0.6381, LR: 0.002000
# Step 110, Train Loss: -0.7447, Dev Loss: -0.7077, Dev Loss confidence interval: -0.7158, -0.6997, LR: 0.002000
# Step 120, Train Loss: -0.6981, Dev Loss: -0.6553, Dev Loss confidence interval: -0.6635, -0.6472, LR: 0.002000
# Step 130, Train Loss: -0.7502, Dev Loss: -0.7140, Dev Loss confidence interval: -0.7216, -0.7064, LR: 0.002000
# Step 140, Train Loss: -0.7872, Dev Loss: -0.7492, Dev Loss confidence interval: -0.7568, -0.7417, LR: 0.002000
# Step 150, Train Loss: -0.8730, Dev Loss: -0.8323, Dev Loss confidence interval: -0.8403, -0.8243, LR: 0.002000
# Step 160, Train Loss: -0.9051, Dev Loss: -0.8649, Dev Loss confidence interval: -0.8733, -0.8566, LR: 0.002000
# Step 170, Train Loss: -0.9405, Dev Loss: -0.9010, Dev Loss confidence interval: -0.9091, -0.8928, LR: 0.002000
# Step 180, Train Loss: -0.9466, Dev Loss: -0.9079, Dev Loss confidence interval: -0.9160, -0.8997, LR: 0.002000
# Step 190, Train Loss: -0.9578, Dev Loss: -0.9186, Dev Loss confidence interval: -0.9269, -0.9104, LR: 0.002000
# Step 200, Train Loss: -0.9921, Dev Loss: -0.9500, Dev Loss confidence interval: -0.9585, -0.9415, LR: 0.001000
# Step 210, Train Loss: -1.0000, Dev Loss: -0.9574, Dev Loss confidence interval: -0.9660, -0.9489, LR: 0.001000
# Step 220, Train Loss: -1.0066, Dev Loss: -0.9632, Dev Loss confidence interval: -0.9718, -0.9547, LR: 0.001000
# Step 230, Train Loss: -1.0113, Dev Loss: -0.9675, Dev Loss confidence interval: -0.9761, -0.9588, LR: 0.001000
# Step 240, Train Loss: -1.0188, Dev Loss: -0.9747, Dev Loss confidence interval: -0.9834, -0.9661, LR: 0.001000
# Step 250, Train Loss: -1.0234, Dev Loss: -0.9789, Dev Loss confidence interval: -0.9876, -0.9702, LR: 0.001000
# Step 260, Train Loss: -1.0292, Dev Loss: -0.9846, Dev Loss confidence interval: -0.9933, -0.9759, LR: 0.001000
# Step 270, Train Loss: -1.0346, Dev Loss: -0.9899, Dev Loss confidence interval: -0.9986, -0.9811, LR: 0.001000
# Step 280, Train Loss: -1.0393, Dev Loss: -0.9943, Dev Loss confidence interval: -1.0031, -0.9856, LR: 0.001000
# Step 290, Train Loss: -1.0436, Dev Loss: -0.9984, Dev Loss confidence interval: -1.0072, -0.9896, LR: 0.001000
# Step 300, Train Loss: -1.0490, Dev Loss: -1.0038, Dev Loss confidence interval: -1.0126, -0.9950, LR: 0.001000
# Step 310, Train Loss: -1.0522, Dev Loss: -1.0066, Dev Loss confidence interval: -1.0155, -0.9978, LR: 0.001000
# Step 320, Train Loss: -1.0571, Dev Loss: -1.0115, Dev Loss confidence interval: -1.0204, -1.0027, LR: 0.001000
# Step 330, Train Loss: -1.0587, Dev Loss: -1.0128, Dev Loss confidence interval: -1.0217, -1.0040, LR: 0.001000
# Step 340, Train Loss: -1.0638, Dev Loss: -1.0179, Dev Loss confidence interval: -1.0268, -1.0090, LR: 0.001000
# Step 350, Train Loss: -1.0666, Dev Loss: -1.0206, Dev Loss confidence interval: -1.0295, -1.0117, LR: 0.001000
# Step 360, Train Loss: -1.0717, Dev Loss: -1.0256, Dev Loss confidence interval: -1.0345, -1.0167, LR: 0.001000
# Step 370, Train Loss: -1.0743, Dev Loss: -1.0281, Dev Loss confidence interval: -1.0370, -1.0191, LR: 0.001000
# Step 380, Train Loss: -1.0747, Dev Loss: -1.0281, Dev Loss confidence interval: -1.0371, -1.0192, LR: 0.001000
# Step 390, Train Loss: -1.0797, Dev Loss: -1.0332, Dev Loss confidence interval: -1.0422, -1.0242, LR: 0.001000
# Step 400, Train Loss: -1.0815, Dev Loss: -1.0347, Dev Loss confidence interval: -1.0437, -1.0257, LR: 0.000500
# Best epoch: 400
# Final Train Loss: -1.0815, Final Train Loss confidence interval: -1.0868, -1.0762
# Final Dev Loss: -1.0347, Final Dev Loss confidence interval: -1.0439, -1.0255
# Test Loss: -1.1307, Test Loss confidence interval: -1.1402, -1.1211

# %%
import matplotlib.pyplot as plt
import numpy as np

steps = np.arange(0, len(train_losses) * 10, 10)  # Since you log every 10 steps

plt.figure(figsize=(10, 6))
plt.plot(steps, train_losses, label='Train Loss', linewidth=2)
plt.plot(steps, dev_losses, label='Dev Loss', linewidth=2)
plt.xlabel('Training Step')
plt.ylabel('Loss (Negative Log-Likelihood)')
plt.title(f"Training and Validation Loss of {dist_type}_NoReg_RV")
plt.legend()
plt.grid(True, alpha=0.3)
plt.axhline(y=0, color='r', linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()
