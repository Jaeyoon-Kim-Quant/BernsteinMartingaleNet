# %%
# output folder, dist type, optional parameter for dist type

import sys
import os
import torch

cwd = os.getcwd()
root = cwd.split("BernsteinMartingaleNet")[0] + "BernsteinMartingaleNet"
if root not in sys.path:
    sys.path.append(root)

from lib.utils import train_model, get_full_sequence_data_by_day
from lib.BLogistic import BLogistic, MixedBLogistic
from lib.DistHead import NormalHead, StudentTHead, SkewedStudentTHead
from lib.Michenkow import MichenkowManytoMany
assert torch.cuda.is_available()
device = torch.device('cuda')

# %%
dist_type  = "BLogistic"
dist_param = "16"
output_folder =  root + f"/MichenkowResults/{dist_type}NoReg_RV_Decay/"

# %%
dist_head = None
if dist_type == "Normal":
    dist_head = NormalHead(device)
elif dist_type == "StudentT":
    dist_head = StudentTHead(device)
elif dist_type == "SkewedStudentT":
    dist_head = SkewedStudentTHead(device)
elif dist_type == "BLogistic":
    if dist_param == "":
        raise ValueError("BLogistic dist type requires a degree parameter")
    dof = int(dist_param)
    dist_head = BLogistic(dof - 2, device)
elif dist_type == "MixedBLogistic":
    if dist_param == "":
        raise ValueError("MixedBLogistic dist type requires a degree parameter")
    dof = int(dist_param)
    dist_head = MixedBLogistic(dof, device)
else:
    raise ValueError(f"Invalid dist type: {dist_type}")

folder_path = root + "/MarketData/historical_data"

# %%
train, dev, test = get_full_sequence_data_by_day(folder_path, 0.2, 0.2, force_recompute=True)
print("train", train.shape)
print("dev", dev.shape)
print("test", test.shape)
# Out:
# skipping 2020-11-27
# skipping 2020-12-24
# skipping 2021-11-26
# skipping 2022-11-25
# skipping 2023-07-03
# skipping 2023-11-24
# skipping 2024-07-03
# skipping 2024-11-29
# skipping 2024-12-24
# skipping 2025-07-03
# train (748, 391, 3)
# dev (249, 391, 3)
# test (249, 391, 3)

# %%
train = torch.tensor(train, device=device)
dev = torch.tensor(dev, device=device)
test = torch.tensor(test, device=device)

train_xs = train[:, :-1, 0:3]
dev_xs = dev[:, :-1, 0:3]
test_xs = test[:, :-1, 0:3]

train_ys = train[:, 1:, 0]
dev_ys = dev[:, 1:, 0]
test_ys = test[:, 1:, 0]

std_x = torch.sqrt((train_xs**2).mean(dim=(0, 1)))  # Shape: (2,)
mean_x = train_xs.mean(dim=(0, 1))

print("std x:", std_x)
print("mean_x:", mean_x)

std_y = torch.sqrt((train_ys**2).mean(dim=(0, 1)))  # Shape: (2,)
mean_y = train_ys.mean(dim=(0, 1))

print("std y:", std_y)
print("mean y:", mean_y)

train_xs = (train_xs-mean_x) / std_x
dev_xs = (dev_xs-mean_x) / std_x
test_xs = (test_xs-mean_x) / std_x
train_ys = (train_ys-mean_y) / std_y
dev_ys = (dev_ys-mean_y) / std_y
test_ys = (test_ys-mean_y) / std_y

print("X train:", train_xs.shape, "y train", train_ys.shape)
print("X dev:", dev_xs.shape, "y dev", dev_ys.shape)
print("X test:", test_xs.shape, "y test", test_ys.shape)
# Out:
# std x: tensor([4.2369e-04, 5.0592e-07, 1.3484e+04], device='cuda:0')
# mean_x: tensor([-2.3330e-07,  1.7856e-07,  1.1670e+04], device='cuda:0')
# std y: tensor(0.0004, device='cuda:0')
# mean y: tensor(-2.1644e-07, device='cuda:0')
# X train: torch.Size([748, 390, 3]) y train torch.Size([748, 390])
# X dev: torch.Size([249, 390, 3]) y dev torch.Size([249, 390])
# X test: torch.Size([249, 390, 3]) y test torch.Size([249, 390])

# %%
lr = 0.002
decay_step = 200
decay_gamma = 0.5
weight_decay = 0
weight_decay = 0.000
num_steps = 400 + 1
batch_size = 1024

# %%
m2m_model = MichenkowManytoMany(dist_head, device, feature_size=train_xs.shape[2])

model, train_losses, dev_losses = train_model(m2m_model,
                                              train_xs, train_ys, dev_xs, dev_ys, test_xs,test_ys, lr, weight_decay, num_steps, batch_size=batch_size, device=device, output_folder=output_folder, lr_decay_step=decay_step, lr_decay_gamma=decay_gamma)
# Out:
# Initializing LSTM with dist=BLogistic, dof=16
# num batches 0
# Init, Train Loss: 1.3772, Dev Loss: 1.3803, Dev Loss confidence interval: 1.3757, 1.3849
# Step 0, Train Loss: 1.3717, Dev Loss: 1.3750, Dev Loss confidence interval: 1.3703, 1.3797, LR: 0.002000
# Step 10, Train Loss: 1.2535, Dev Loss: 1.2763, Dev Loss confidence interval: 1.2680, 1.2846, LR: 0.002000
# Step 20, Train Loss: 1.1679, Dev Loss: 1.1834, Dev Loss confidence interval: 1.1773, 1.1895, LR: 0.002000
# Step 30, Train Loss: 1.1242, Dev Loss: 1.1441, Dev Loss confidence interval: 1.1375, 1.1508, LR: 0.002000
# Step 40, Train Loss: 1.0983, Dev Loss: 1.1195, Dev Loss confidence interval: 1.1130, 1.1260, LR: 0.002000
# Step 50, Train Loss: 1.0918, Dev Loss: 1.1139, Dev Loss confidence interval: 1.1074, 1.1204, LR: 0.002000
# Step 60, Train Loss: 1.0868, Dev Loss: 1.1091, Dev Loss confidence interval: 1.1028, 1.1154, LR: 0.002000
# Step 70, Train Loss: 1.0856, Dev Loss: 1.1083, Dev Loss confidence interval: 1.1019, 1.1147, LR: 0.002000
# Step 80, Train Loss: 1.0843, Dev Loss: 1.1073, Dev Loss confidence interval: 1.1011, 1.1136, LR: 0.002000
# Step 90, Train Loss: 1.0828, Dev Loss: 1.1058, Dev Loss confidence interval: 1.0994, 1.1122, LR: 0.002000
# Step 100, Train Loss: 1.0818, Dev Loss: 1.1048, Dev Loss confidence interval: 1.0986, 1.1111, LR: 0.002000
# Step 110, Train Loss: 1.0813, Dev Loss: 1.1043, Dev Loss confidence interval: 1.0981, 1.1105, LR: 0.002000
# Step 120, Train Loss: 1.0803, Dev Loss: 1.1034, Dev Loss confidence interval: 1.0972, 1.1096, LR: 0.002000
# Step 130, Train Loss: 1.0797, Dev Loss: 1.1027, Dev Loss confidence interval: 1.0963, 1.1091, LR: 0.002000
# Step 140, Train Loss: 1.0791, Dev Loss: 1.1024, Dev Loss confidence interval: 1.0963, 1.1085, LR: 0.002000
# Step 150, Train Loss: 1.0781, Dev Loss: 1.1014, Dev Loss confidence interval: 1.0951, 1.1076, LR: 0.002000
# Step 160, Train Loss: 1.0777, Dev Loss: 1.1011, Dev Loss confidence interval: 1.0948, 1.1075, LR: 0.002000
# Step 170, Train Loss: 1.0771, Dev Loss: 1.1004, Dev Loss confidence interval: 1.0941, 1.1068, LR: 0.002000
# Step 180, Train Loss: 1.0767, Dev Loss: 1.1001, Dev Loss confidence interval: 1.0938, 1.1064, LR: 0.002000
# Step 190, Train Loss: 1.0763, Dev Loss: 1.1000, Dev Loss confidence interval: 1.0938, 1.1062, LR: 0.002000
# Step 200, Train Loss: 1.0758, Dev Loss: 1.0996, Dev Loss confidence interval: 1.0933, 1.1058, LR: 0.001000
# Step 210, Train Loss: 1.0757, Dev Loss: 1.0995, Dev Loss confidence interval: 1.0932, 1.1057, LR: 0.001000
# Step 220, Train Loss: 1.0754, Dev Loss: 1.0993, Dev Loss confidence interval: 1.0930, 1.1056, LR: 0.001000
# Step 230, Train Loss: 1.0752, Dev Loss: 1.0991, Dev Loss confidence interval: 1.0929, 1.1054, LR: 0.001000
# Step 240, Train Loss: 1.0750, Dev Loss: 1.0990, Dev Loss confidence interval: 1.0928, 1.1053, LR: 0.001000
# Step 250, Train Loss: 1.0748, Dev Loss: 1.0989, Dev Loss confidence interval: 1.0926, 1.1051, LR: 0.001000
# Step 260, Train Loss: 1.0746, Dev Loss: 1.0988, Dev Loss confidence interval: 1.0925, 1.1050, LR: 0.001000
# Step 270, Train Loss: 1.0745, Dev Loss: 1.0987, Dev Loss confidence interval: 1.0924, 1.1049, LR: 0.001000
# Step 280, Train Loss: 1.0743, Dev Loss: 1.0985, Dev Loss confidence interval: 1.0923, 1.1047, LR: 0.001000
# Step 290, Train Loss: 1.0741, Dev Loss: 1.0984, Dev Loss confidence interval: 1.0921, 1.1046, LR: 0.001000
# Step 300, Train Loss: 1.0744, Dev Loss: 1.0988, Dev Loss confidence interval: 1.0926, 1.1049, LR: 0.001000
# Step 310, Train Loss: 1.0744, Dev Loss: 1.0985, Dev Loss confidence interval: 1.0922, 1.1049, LR: 0.001000
# Step 320, Train Loss: 1.0739, Dev Loss: 1.0982, Dev Loss confidence interval: 1.0918, 1.1045, LR: 0.001000
# Step 330, Train Loss: 1.0741, Dev Loss: 1.0985, Dev Loss confidence interval: 1.0924, 1.1046, LR: 0.001000
# Step 340, Train Loss: 1.0736, Dev Loss: 1.0980, Dev Loss confidence interval: 1.0918, 1.1042, LR: 0.001000
# Step 350, Train Loss: 1.0732, Dev Loss: 1.0977, Dev Loss confidence interval: 1.0915, 1.1040, LR: 0.001000
# Step 360, Train Loss: 1.0731, Dev Loss: 1.0977, Dev Loss confidence interval: 1.0915, 1.1040, LR: 0.001000
# Step 370, Train Loss: 1.0729, Dev Loss: 1.0975, Dev Loss confidence interval: 1.0912, 1.1038, LR: 0.001000
# Step 380, Train Loss: 1.0731, Dev Loss: 1.0977, Dev Loss confidence interval: 1.0915, 1.1039, LR: 0.001000
# Step 390, Train Loss: 1.0727, Dev Loss: 1.0974, Dev Loss confidence interval: 1.0912, 1.1037, LR: 0.001000
# Step 400, Train Loss: 1.0725, Dev Loss: 1.0973, Dev Loss confidence interval: 1.0911, 1.1036, LR: 0.000500
# Best epoch: 400
# Final Train Loss: 1.0725, Final Train Loss confidence interval: 1.0688, 1.0763
# Final Dev Loss: 1.0973, Final Dev Loss confidence interval: 1.0909, 1.1037
# Test Loss: 1.0458, Test Loss confidence interval: 1.0392, 1.0524

# %%
import matplotlib.pyplot as plt
import numpy as np

steps = np.arange(0, len(train_losses) * 10, 10)  # Since you log every 10 steps

plt.figure(figsize=(10, 6))
plt.plot(steps, train_losses, label='Train Loss', linewidth=2)
plt.plot(steps, dev_losses, label='Dev Loss', linewidth=2)
plt.xlabel('Training Step')
plt.ylabel('Loss (Negative Log-Likelihood)')
plt.title(f"Training and Validation Loss of {dist_type}_NoReg_RV_Decay")
plt.legend()
plt.grid(True, alpha=0.3)
plt.axhline(y=0, color='r', linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()
