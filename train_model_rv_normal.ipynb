# %%
# output folder, dist type, optional parameter for dist type

import sys
import os
import torch

cwd = os.getcwd()
root = cwd.split("BernsteinMartingaleNet")[0] + "BernsteinMartingaleNet"
if root not in sys.path:
    sys.path.append(root)

from lib.utils import train_model, get_full_sequence_data_by_day
from lib.BLogistic import BLogistic, MixedBLogistic
from lib.DistHead import NormalHead, StudentTHead, SkewedStudentTHead
from lib.Michenkow import MichenkowManytoMany
assert torch.cuda.is_available()
device = torch.device('cuda')

# %%
dist_type  = "Normal"
dist_param = ""
output_folder =  root + f"/MichenkowResults/{dist_type}NoReg_RV/"

# %%
dist_head = None
if dist_type == "Normal":
    dist_head = NormalHead(device)
elif dist_type == "StudentT":
    dist_head = StudentTHead(device)
elif dist_type == "SkewedStudentT":
    dist_head = SkewedStudentTHead(device)
elif dist_type == "BLogistic":
    if dist_param == "":
        raise ValueError("BLogistic dist type requires a degree parameter")
    dof = int(dist_param)
    dist_head = BLogistic(dof - 2, device)
elif dist_type == "MixedBLogistic":
    if dist_param == "":
        raise ValueError("MixedBLogistic dist type requires a degree parameter")
    dof = int(dist_param)
    dist_head = MixedBLogistic(dof, device)
else:
    raise ValueError(f"Invalid dist type: {dist_type}")

folder_path = root + "/MarketData/historical_data"

# %%
train, dev, test = get_full_sequence_data_by_day(folder_path, 0.2, 0.2, force_recompute=True)
print("train", train.shape)
print("dev", dev.shape)
print("test", test.shape)
# Out:
# skipping 2020-11-27
# skipping 2020-12-24
# skipping 2021-11-26
# skipping 2022-11-25
# skipping 2023-07-03
# skipping 2023-11-24
# skipping 2024-07-03
# skipping 2024-11-29
# skipping 2024-12-24
# skipping 2025-07-03
# train (748, 391, 3)
# dev (249, 391, 3)
# test (249, 391, 3)

# %%
train = torch.tensor(train, device=device)
dev = torch.tensor(dev, device=device)
test = torch.tensor(test, device=device)

train_xs = train[:, :-1, 0:2]
dev_xs = dev[:, :-1, 0:2]
test_xs = test[:, :-1, 0:2]

train_ys = train[:, 1:, 0]
dev_ys = dev[:, 1:, 0]
test_ys = test[:, 1:, 0]

std_x = torch.sqrt((train_xs**2).mean(dim=(0, 1)))  # Shape: (2,)
mean_x = train_xs.mean(dim=(0, 1))

print("std x:", std_x)
print("mean_x:", mean_x)

std_y = torch.sqrt((train_ys**2).mean(dim=(0, 1)))  # Shape: (2,)
mean_y = train_ys.mean(dim=(0, 1))

print("std y:", std_y)
print("mean y:", mean_y)

train_xs = (train_xs-mean_x) / std_x
dev_xs = (dev_xs-mean_x) / std_x
test_xs = (test_xs-mean_x) / std_x
train_ys = (train_ys-mean_y) / std_y
dev_ys = (dev_ys-mean_y) / std_y
test_ys = (test_ys-mean_y) / std_y

print("X train:", train_xs.shape, "y train", train_ys.shape)
print("X dev:", dev_xs.shape, "y dev", dev_ys.shape)
print("X test:", test_xs.shape, "y test", test_ys.shape)
# Out:
# std x: tensor([4.2369e-04, 5.0592e-07], device='cuda:0')
# mean_x: tensor([-2.3330e-07,  1.7856e-07], device='cuda:0')
# std y: tensor(0.0004, device='cuda:0')
# mean y: tensor(-2.1644e-07, device='cuda:0')
# X train: torch.Size([748, 390, 2]) y train torch.Size([748, 390])
# X dev: torch.Size([249, 390, 2]) y dev torch.Size([249, 390])
# X test: torch.Size([249, 390, 2]) y test torch.Size([249, 390])

# %%
lr = 0.002
decay_step = 200
decay_gamma = 0.5
weight_decay = 0
weight_decay = 0.000
num_steps = 400 + 1
batch_size = 1024

# %%
m2m_model = MichenkowManytoMany(dist_head, device, feature_size=2)

model, train_losses, dev_losses = train_model(m2m_model,
                                              train_xs, train_ys, dev_xs, dev_ys, test_xs,test_ys, lr, weight_decay, num_steps, batch_size=batch_size, device=device, output_folder=output_folder, lr_decay_step=decay_step, lr_decay_gamma=decay_gamma)
# Out:
# Initializing LSTM with dist=NormalHead, dof=1
# num batches 0
# Init, Train Loss: 1.5929, Dev Loss: 1.5400, Dev Loss confidence interval: 1.5211, 1.5589
# Step 0, Train Loss: 1.5855, Dev Loss: 1.5337, Dev Loss confidence interval: 1.5150, 1.5523, LR: 0.002000
# Step 10, Train Loss: 1.4191, Dev Loss: 1.3900, Dev Loss confidence interval: 1.3789, 1.4012, LR: 0.002000
# Step 20, Train Loss: 1.2461, Dev Loss: 1.2482, Dev Loss confidence interval: 1.2397, 1.2567, LR: 0.002000
# Step 30, Train Loss: 1.2157, Dev Loss: 1.2310, Dev Loss confidence interval: 1.2211, 1.2409, LR: 0.002000
# Step 40, Train Loss: 1.1718, Dev Loss: 1.1874, Dev Loss confidence interval: 1.1784, 1.1964, LR: 0.002000
# Step 50, Train Loss: 1.1375, Dev Loss: 1.1525, Dev Loss confidence interval: 1.1427, 1.1623, LR: 0.002000
# Step 60, Train Loss: 1.1214, Dev Loss: 1.1385, Dev Loss confidence interval: 1.1287, 1.1484, LR: 0.002000
# Step 70, Train Loss: 1.1160, Dev Loss: 1.1334, Dev Loss confidence interval: 1.1250, 1.1418, LR: 0.002000
# Step 80, Train Loss: 1.1144, Dev Loss: 1.1324, Dev Loss confidence interval: 1.1243, 1.1404, LR: 0.002000
# Step 90, Train Loss: 1.1116, Dev Loss: 1.1298, Dev Loss confidence interval: 1.1206, 1.1390, LR: 0.002000
# Step 100, Train Loss: 1.1096, Dev Loss: 1.1281, Dev Loss confidence interval: 1.1200, 1.1362, LR: 0.002000
# Step 110, Train Loss: 1.1075, Dev Loss: 1.1262, Dev Loss confidence interval: 1.1180, 1.1345, LR: 0.002000
# Step 120, Train Loss: 1.1065, Dev Loss: 1.1257, Dev Loss confidence interval: 1.1175, 1.1339, LR: 0.002000
# Step 130, Train Loss: 1.1074, Dev Loss: 1.1271, Dev Loss confidence interval: 1.1192, 1.1350, LR: 0.002000
# Step 140, Train Loss: 1.1048, Dev Loss: 1.1242, Dev Loss confidence interval: 1.1160, 1.1324, LR: 0.002000
# Step 150, Train Loss: 1.1042, Dev Loss: 1.1240, Dev Loss confidence interval: 1.1159, 1.1321, LR: 0.002000
# Step 160, Train Loss: 1.1038, Dev Loss: 1.1238, Dev Loss confidence interval: 1.1158, 1.1318, LR: 0.002000
# Step 170, Train Loss: 1.1030, Dev Loss: 1.1230, Dev Loss confidence interval: 1.1150, 1.1310, LR: 0.002000
# Step 180, Train Loss: 1.1024, Dev Loss: 1.1227, Dev Loss confidence interval: 1.1147, 1.1306, LR: 0.002000
# Step 190, Train Loss: 1.1022, Dev Loss: 1.1226, Dev Loss confidence interval: 1.1146, 1.1305, LR: 0.002000
# Step 200, Train Loss: 1.1014, Dev Loss: 1.1217, Dev Loss confidence interval: 1.1138, 1.1296, LR: 0.001000
# Step 210, Train Loss: 1.1012, Dev Loss: 1.1217, Dev Loss confidence interval: 1.1137, 1.1296, LR: 0.001000
# Step 220, Train Loss: 1.1009, Dev Loss: 1.1214, Dev Loss confidence interval: 1.1134, 1.1293, LR: 0.001000
# Step 230, Train Loss: 1.1006, Dev Loss: 1.1210, Dev Loss confidence interval: 1.1131, 1.1290, LR: 0.001000
# Step 240, Train Loss: 1.1004, Dev Loss: 1.1209, Dev Loss confidence interval: 1.1130, 1.1289, LR: 0.001000
# Step 250, Train Loss: 1.1003, Dev Loss: 1.1209, Dev Loss confidence interval: 1.1130, 1.1288, LR: 0.001000
# Step 260, Train Loss: 1.1000, Dev Loss: 1.1206, Dev Loss confidence interval: 1.1127, 1.1286, LR: 0.001000
# Step 270, Train Loss: 1.0998, Dev Loss: 1.1204, Dev Loss confidence interval: 1.1124, 1.1284, LR: 0.001000
# Step 280, Train Loss: 1.0997, Dev Loss: 1.1204, Dev Loss confidence interval: 1.1125, 1.1283, LR: 0.001000
# Step 290, Train Loss: 1.0998, Dev Loss: 1.1207, Dev Loss confidence interval: 1.1129, 1.1285, LR: 0.001000
# Step 300, Train Loss: 1.0996, Dev Loss: 1.1205, Dev Loss confidence interval: 1.1126, 1.1283, LR: 0.001000
# Step 310, Train Loss: 1.0991, Dev Loss: 1.1200, Dev Loss confidence interval: 1.1121, 1.1279, LR: 0.001000
# Step 320, Train Loss: 1.0990, Dev Loss: 1.1199, Dev Loss confidence interval: 1.1120, 1.1278, LR: 0.001000
# Step 330, Train Loss: 1.0990, Dev Loss: 1.1201, Dev Loss confidence interval: 1.1122, 1.1279, LR: 0.001000
# Step 340, Train Loss: 1.0986, Dev Loss: 1.1197, Dev Loss confidence interval: 1.1117, 1.1276, LR: 0.001000
# Step 350, Train Loss: 1.0985, Dev Loss: 1.1195, Dev Loss confidence interval: 1.1116, 1.1274, LR: 0.001000
# Step 360, Train Loss: 1.0984, Dev Loss: 1.1196, Dev Loss confidence interval: 1.1117, 1.1275, LR: 0.001000
# Step 370, Train Loss: 1.0984, Dev Loss: 1.1196, Dev Loss confidence interval: 1.1118, 1.1274, LR: 0.001000
# Step 380, Train Loss: 1.0980, Dev Loss: 1.1192, Dev Loss confidence interval: 1.1113, 1.1272, LR: 0.001000
# Step 390, Train Loss: 1.0981, Dev Loss: 1.1195, Dev Loss confidence interval: 1.1117, 1.1274, LR: 0.001000
# Step 400, Train Loss: 1.0978, Dev Loss: 1.1191, Dev Loss confidence interval: 1.1113, 1.1270, LR: 0.000500
# Best epoch: 400
# Final Train Loss: 1.0978, Final Train Loss confidence interval: 1.0923, 1.1033
# Final Dev Loss: 1.1191, Final Dev Loss confidence interval: 1.1111, 1.1272
# Test Loss: 1.0739, Test Loss confidence interval: 1.0644, 1.0835

# %%
import matplotlib.pyplot as plt
import numpy as np

steps = np.arange(0, len(train_losses) * 10, 10)  # Since you log every 10 steps

plt.figure(figsize=(10, 6))
plt.plot(steps, train_losses, label='Train Loss', linewidth=2)
plt.plot(steps, dev_losses, label='Dev Loss', linewidth=2)
plt.xlabel('Training Step')
plt.ylabel('Loss (Negative Log-Likelihood)')
plt.title(f"Training and Validation Loss of {dist_type}_NoReg_RV")
plt.legend()
plt.grid(True, alpha=0.3)
plt.axhline(y=0, color='r', linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()
