# %%
# output folder, dist type, optional parameter for dist type

import sys
import os
import torch

cwd = os.getcwd()
root = cwd.split("BernsteinMartingaleNet")[0] + "BernsteinMartingaleNet"
if root not in sys.path:
    sys.path.append(root)

from lib.utils import train_model, get_full_sequence_data_by_day
from lib.BLogistic import BLogistic, MixedBLogistic
from lib.DistHead import NormalHead, StudentTHead, SkewedStudentTHead
from lib.Michenkow import MichenkowManytoMany
assert torch.cuda.is_available()
device = torch.device('cuda')

# %%
dist_type  = "Normal"
dist_param = ""
output_folder =  root + f"/MichenkowResults/{dist_type}NoReg_RV/"

# %%
dist_head = None
if dist_type == "Normal":
    dist_head = NormalHead(device)
elif dist_type == "StudentT":
    dist_head = StudentTHead(device)
elif dist_type == "SkewedStudentT":
    dist_head = SkewedStudentTHead(device)
elif dist_type == "BLogistic":
    if dist_param == "":
        raise ValueError("BLogistic dist type requires a degree parameter")
    dof = int(dist_param)
    dist_head = BLogistic(dof - 2, device)
elif dist_type == "MixedBLogistic":
    if dist_param == "":
        raise ValueError("MixedBLogistic dist type requires a degree parameter")
    dof = int(dist_param)
    dist_head = MixedBLogistic(dof, device)
else:
    raise ValueError(f"Invalid dist type: {dist_type}")

folder_path = root + "/MarketData/historical_data"

# %%
train, dev, test = get_full_sequence_data_by_day(folder_path, 0.2, 0.2, force_recompute=True)
print("train", train.shape)
print("dev", dev.shape)
print("test", test.shape)
# Out:
# skipping 2020-11-27
# skipping 2020-12-24
# skipping 2021-11-26
# skipping 2022-11-25
# skipping 2023-07-03
# skipping 2023-11-24
# skipping 2024-07-03
# skipping 2024-11-29
# skipping 2024-12-24
# skipping 2025-07-03
# 1246
# train (748, 391, 3)
# dev (249, 391, 3)
# test (249, 391, 3)

# %%
train = torch.tensor(train, device=device)
dev = torch.tensor(dev, device=device)
test = torch.tensor(test, device=device)

train_xs = train[:, :-1, 0:2]
dev_xs = dev[:, :-1, 0:2]
test_xs = test[:, :-1, 0:2]

train_ys = train[:, :-1, 1]
dev_ys = dev[:, :-1, 1]
test_ys = test[:, :-1, 1]

std_x = torch.sqrt((train_xs**2).mean(dim=(0, 1)))  # Shape: (2,)
mean_x = train_xs.mean(dim=(0, 1))

print("std x:", std_x)
print("mean_x:", mean_x)

std_y = torch.sqrt((train_ys**2).mean(dim=(0, 1)))  # Shape: (2,)
mean_y = train_ys.mean(dim=(0, 1))

print("std y:", std_y)
print("mean y:", mean_y)

train_xs = (train_xs-mean_x) / std_x
dev_xs = (dev_xs-mean_x) / std_x
test_xs = (test_xs-mean_x) / std_x
train_ys = (train_ys-mean_y) / std_y
dev_ys = (dev_ys-mean_y) / std_y
test_ys = (test_ys-mean_y) / std_y

print("X train:", train_xs.shape, "y train", train_ys.shape)
print("X dev:", dev_xs.shape, "y dev", dev_ys.shape)
print("X test:", test_xs.shape, "y test", test_ys.shape)
# Out:
# std x: tensor([4.2369e-04, 5.0592e-07], device='cuda:0')
# mean_x: tensor([-2.3330e-07,  1.7856e-07], device='cuda:0')
# std y: tensor(5.0592e-07, device='cuda:0')
# mean y: tensor(1.7856e-07, device='cuda:0')
# X train: torch.Size([748, 390, 2]) y train torch.Size([748, 390])
# X dev: torch.Size([249, 390, 2]) y dev torch.Size([249, 390])
# X test: torch.Size([249, 390, 2]) y test torch.Size([249, 390])

# %%
lr = 0.002
decay_step = 200
decay_gamma = 0.5
weight_decay = 0
weight_decay = 0.000
num_steps = 400 + 1
batch_size = 1024

# %%
m2m_model = MichenkowManytoMany(dist_head, device, feature_size=2)

model, train_losses, dev_losses = train_model(m2m_model,
                                              train_xs, train_ys, dev_xs, dev_ys, test_xs,test_ys, lr, weight_decay, num_steps, batch_size=batch_size, device=device, output_folder=output_folder, lr_decay_step=decay_step, lr_decay_gamma=decay_gamma)
# Out:
# Initializing LSTM with dist=NormalHead, dof=1
# num batches 0
# Init, Train Loss: 1.4633, Dev Loss: 0.9293, Dev Loss confidence interval: 0.8856, 0.9729
# Step 0, Train Loss: 1.4551, Dev Loss: 0.9298, Dev Loss confidence interval: 0.8867, 0.9730, LR: 0.002000
# Step 10, Train Loss: 1.1122, Dev Loss: 0.8451, Dev Loss confidence interval: 0.8125, 0.8776, LR: 0.002000
# Step 20, Train Loss: 0.8163, Dev Loss: 0.7103, Dev Loss confidence interval: 0.6724, 0.7481, LR: 0.002000
# Step 30, Train Loss: 0.5643, Dev Loss: 0.5164, Dev Loss confidence interval: 0.4857, 0.5472, LR: 0.002000
# Step 40, Train Loss: 0.2979, Dev Loss: 0.2630, Dev Loss confidence interval: 0.2442, 0.2818, LR: 0.002000
# Step 50, Train Loss: 0.2246, Dev Loss: 0.1964, Dev Loss confidence interval: 0.1889, 0.2039, LR: 0.002000
# Step 60, Train Loss: 0.1802, Dev Loss: 0.1548, Dev Loss confidence interval: 0.1488, 0.1608, LR: 0.002000
# Step 70, Train Loss: 0.2055, Dev Loss: 0.1843, Dev Loss confidence interval: 0.1788, 0.1899, LR: 0.002000
# Step 80, Train Loss: 0.1835, Dev Loss: 0.1610, Dev Loss confidence interval: 0.1552, 0.1668, LR: 0.002000
# Step 90, Train Loss: 0.1650, Dev Loss: 0.1430, Dev Loss confidence interval: 0.1377, 0.1483, LR: 0.002000
# Step 100, Train Loss: 0.1551, Dev Loss: 0.1323, Dev Loss confidence interval: 0.1271, 0.1374, LR: 0.002000
# Step 110, Train Loss: 0.1454, Dev Loss: 0.1236, Dev Loss confidence interval: 0.1186, 0.1286, LR: 0.002000
# Step 120, Train Loss: 0.1347, Dev Loss: 0.1138, Dev Loss confidence interval: 0.1089, 0.1187, LR: 0.002000
# Step 130, Train Loss: 0.0904, Dev Loss: 0.0691, Dev Loss confidence interval: 0.0641, 0.0740, LR: 0.002000
# Step 140, Train Loss: 0.0509, Dev Loss: 0.0286, Dev Loss confidence interval: 0.0234, 0.0337, LR: 0.002000
# Step 150, Train Loss: 0.0327, Dev Loss: 0.0093, Dev Loss confidence interval: 0.0041, 0.0145, LR: 0.002000
# Step 160, Train Loss: 0.0224, Dev Loss: -0.0007, Dev Loss confidence interval: -0.0059, 0.0045, LR: 0.002000
# Step 170, Train Loss: 0.0087, Dev Loss: -0.0145, Dev Loss confidence interval: -0.0198, -0.0092, LR: 0.002000
# Step 180, Train Loss: -0.0043, Dev Loss: -0.0276, Dev Loss confidence interval: -0.0329, -0.0223, LR: 0.002000
# Step 190, Train Loss: -0.0196, Dev Loss: -0.0427, Dev Loss confidence interval: -0.0480, -0.0373, LR: 0.002000
# Step 200, Train Loss: -0.0341, Dev Loss: -0.0569, Dev Loss confidence interval: -0.0623, -0.0516, LR: 0.001000
# Step 210, Train Loss: -0.0451, Dev Loss: -0.0678, Dev Loss confidence interval: -0.0733, -0.0624, LR: 0.001000
# Step 220, Train Loss: -0.0553, Dev Loss: -0.0779, Dev Loss confidence interval: -0.0833, -0.0724, LR: 0.001000
# Step 230, Train Loss: -0.0658, Dev Loss: -0.0883, Dev Loss confidence interval: -0.0939, -0.0828, LR: 0.001000
# Step 240, Train Loss: -0.0742, Dev Loss: -0.0967, Dev Loss confidence interval: -0.1023, -0.0910, LR: 0.001000
# Step 250, Train Loss: -0.0827, Dev Loss: -0.1051, Dev Loss confidence interval: -0.1107, -0.0994, LR: 0.001000
# Step 260, Train Loss: -0.0885, Dev Loss: -0.1108, Dev Loss confidence interval: -0.1165, -0.1051, LR: 0.001000
# Step 270, Train Loss: -0.0933, Dev Loss: -0.1157, Dev Loss confidence interval: -0.1214, -0.1100, LR: 0.001000
# Step 280, Train Loss: -0.0966, Dev Loss: -0.1189, Dev Loss confidence interval: -0.1246, -0.1131, LR: 0.001000
# Step 290, Train Loss: -0.0989, Dev Loss: -0.1212, Dev Loss confidence interval: -0.1270, -0.1155, LR: 0.001000
# Step 300, Train Loss: -0.1028, Dev Loss: -0.1251, Dev Loss confidence interval: -0.1309, -0.1193, LR: 0.001000
# Step 310, Train Loss: -0.1051, Dev Loss: -0.1274, Dev Loss confidence interval: -0.1332, -0.1216, LR: 0.001000
# Step 320, Train Loss: -0.1067, Dev Loss: -0.1289, Dev Loss confidence interval: -0.1347, -0.1231, LR: 0.001000
# Step 330, Train Loss: -0.1089, Dev Loss: -0.1310, Dev Loss confidence interval: -0.1368, -0.1252, LR: 0.001000
# Step 340, Train Loss: -0.1096, Dev Loss: -0.1318, Dev Loss confidence interval: -0.1376, -0.1260, LR: 0.001000
# Step 350, Train Loss: -0.1120, Dev Loss: -0.1340, Dev Loss confidence interval: -0.1398, -0.1282, LR: 0.001000
# Step 360, Train Loss: -0.1134, Dev Loss: -0.1354, Dev Loss confidence interval: -0.1413, -0.1296, LR: 0.001000
# Step 370, Train Loss: -0.1147, Dev Loss: -0.1366, Dev Loss confidence interval: -0.1425, -0.1308, LR: 0.001000
# Step 380, Train Loss: -0.1161, Dev Loss: -0.1381, Dev Loss confidence interval: -0.1439, -0.1322, LR: 0.001000
# Step 390, Train Loss: -0.1171, Dev Loss: -0.1390, Dev Loss confidence interval: -0.1448, -0.1331, LR: 0.001000
# Step 400, Train Loss: -0.1180, Dev Loss: -0.1399, Dev Loss confidence interval: -0.1458, -0.1340, LR: 0.000500
# Best epoch: 400
# Final Train Loss: -0.1180, Final Train Loss confidence interval: -0.1260, -0.1100
# Final Dev Loss: -0.1399, Final Dev Loss confidence interval: -0.1459, -0.1339
# Test Loss: -0.0767, Test Loss confidence interval: -0.0860, -0.0674

# %%
import matplotlib.pyplot as plt
import numpy as np

steps = np.arange(0, len(train_losses) * 10, 10)  # Since you log every 10 steps

plt.figure(figsize=(10, 6))
plt.plot(steps, train_losses, label='Train Loss', linewidth=2)
plt.plot(steps, dev_losses, label='Dev Loss', linewidth=2)
plt.xlabel('Training Step')
plt.ylabel('Loss (Negative Log-Likelihood)')
plt.title(f"Training and Validation Loss of {dist_type}_Reg_NoRV")
plt.legend()
plt.grid(True, alpha=0.3)
plt.axhline(y=0, color='r', linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()
