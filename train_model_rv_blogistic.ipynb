# %%
# output folder, dist type, optional parameter for dist type

import sys
import os
import torch

cwd = os.getcwd()
root = cwd.split("BernsteinMartingaleNet")[0] + "BernsteinMartingaleNet"
if root not in sys.path:
    sys.path.append(root)

from lib.utils import train_model, get_full_sequence_data_by_day
from lib.BLogistic import BLogistic, MixedBLogistic
from lib.DistHead import NormalHead, StudentTHead, SkewedStudentTHead
from lib.Michenkow import MichenkowManytoMany
assert torch.cuda.is_available()
device = torch.device('cuda')

# %%
dist_type  = "BLogistic"
dist_param = "16"
output_folder =  root + f"/MichenkowResults/{dist_type}NoReg_RV/"

# %%
dist_head = None
if dist_type == "Normal":
    dist_head = NormalHead(device)
elif dist_type == "StudentT":
    dist_head = StudentTHead(device)
elif dist_type == "SkewedStudentT":
    dist_head = SkewedStudentTHead(device)
elif dist_type == "BLogistic":
    if dist_param == "":
        raise ValueError("BLogistic dist type requires a degree parameter")
    dof = int(dist_param)
    dist_head = BLogistic(dof - 2, device)
elif dist_type == "MixedBLogistic":
    if dist_param == "":
        raise ValueError("MixedBLogistic dist type requires a degree parameter")
    dof = int(dist_param)
    dist_head = MixedBLogistic(dof, device)
else:
    raise ValueError(f"Invalid dist type: {dist_type}")

folder_path = root + "/MarketData/historical_data"

# %%
train, dev, test = get_full_sequence_data_by_day(folder_path, 0.2, 0.2, force_recompute=True)
print("train", train.shape)
print("dev", dev.shape)
print("test", test.shape)
# Out:
# skipping 2020-11-27
# skipping 2020-12-24
# skipping 2021-11-26
# skipping 2022-11-25
# skipping 2023-07-03
# skipping 2023-11-24
# skipping 2024-07-03
# skipping 2024-11-29
# skipping 2024-12-24
# skipping 2025-07-03
# 1246
# train (748, 391, 3)
# dev (249, 391, 3)
# test (249, 391, 3)

# %%
train = torch.tensor(train, device=device)
dev = torch.tensor(dev, device=device)
test = torch.tensor(test, device=device)

train_xs = train[:, :-1, 0:2]
dev_xs = dev[:, :-1, 0:2]
test_xs = test[:, :-1, 0:2]

train_ys = train[:, 1:, 0]
dev_ys = dev[:, 1:, 0]
test_ys = test[:, 1:, 0]

std_x = torch.sqrt((train_xs**2).mean(dim=(0, 1)))  # Shape: (2,)
mean_x = train_xs.mean(dim=(0, 1))

print("std x:", std_x)
print("mean_x:", mean_x)

std_y = torch.sqrt((train_ys**2).mean(dim=(0, 1)))  # Shape: (2,)
mean_y = train_ys.mean(dim=(0, 1))

print("std y:", std_y)
print("mean y:", mean_y)

train_xs = (train_xs-mean_x) / std_x
dev_xs = (dev_xs-mean_x) / std_x
test_xs = (test_xs-mean_x) / std_x
train_ys = (train_ys-mean_y) / std_y
dev_ys = (dev_ys-mean_y) / std_y
test_ys = (test_ys-mean_y) / std_y

print("X train:", train_xs.shape, "y train", train_ys.shape)
print("X dev:", dev_xs.shape, "y dev", dev_ys.shape)
print("X test:", test_xs.shape, "y test", test_ys.shape)
# Out:
# std x: tensor([4.2369e-04, 5.0592e-07], device='cuda:0')
# mean_x: tensor([-2.3330e-07,  1.7856e-07], device='cuda:0')
# std y: tensor(5.1853e-07, device='cuda:0')
# mean y: tensor(1.7846e-07, device='cuda:0')
# X train: torch.Size([748, 390, 2]) y train torch.Size([748, 390])
# X dev: torch.Size([249, 390, 2]) y dev torch.Size([249, 390])
# X test: torch.Size([249, 390, 2]) y test torch.Size([249, 390])

# %%
lr = 0.002
decay_step = 200
decay_gamma = 0.5
weight_decay = 0
weight_decay = 0.000
num_steps = 400 + 1
batch_size = 1024

# %%
m2m_model = MichenkowManytoMany(dist_head, device, feature_size=2)

model, train_losses, dev_losses = train_model(m2m_model,
                                              train_xs, train_ys, dev_xs, dev_ys, test_xs,test_ys, lr, weight_decay, num_steps, batch_size=batch_size, device=device, output_folder=output_folder, lr_decay_step=decay_step, lr_decay_gamma=decay_gamma)
# Out:
# Initializing LSTM with dist=BLogistic, dof=16
# num batches 0
# Init, Train Loss: 1.1499, Dev Loss: 1.1272, Dev Loss confidence interval: 1.1236, 1.1307
# Step 0, Train Loss: 1.1416, Dev Loss: 1.1188, Dev Loss confidence interval: 1.1152, 1.1224, LR: 0.002000
# Step 10, Train Loss: 0.7133, Dev Loss: 0.6969, Dev Loss confidence interval: 0.6916, 0.7022, LR: 0.002000
# Step 20, Train Loss: 0.2465, Dev Loss: 0.2499, Dev Loss confidence interval: 0.2406, 0.2592, LR: 0.002000
# Step 30, Train Loss: 0.1052, Dev Loss: 0.1224, Dev Loss confidence interval: 0.1130, 0.1317, LR: 0.002000
# Step 40, Train Loss: 0.0346, Dev Loss: 0.0583, Dev Loss confidence interval: 0.0490, 0.0675, LR: 0.002000
# Step 50, Train Loss: -0.0077, Dev Loss: 0.0274, Dev Loss confidence interval: 0.0175, 0.0374, LR: 0.002000
# Step 60, Train Loss: -0.0238, Dev Loss: 0.0219, Dev Loss confidence interval: 0.0102, 0.0335, LR: 0.002000
# Step 70, Train Loss: -0.0260, Dev Loss: 0.0272, Dev Loss confidence interval: 0.0144, 0.0399, LR: 0.002000
# Step 80, Train Loss: -0.0301, Dev Loss: 0.0196, Dev Loss confidence interval: 0.0075, 0.0317, LR: 0.002000
# Step 90, Train Loss: -0.0349, Dev Loss: 0.0156, Dev Loss confidence interval: 0.0039, 0.0274, LR: 0.002000
# Step 100, Train Loss: -0.0396, Dev Loss: 0.0112, Dev Loss confidence interval: -0.0006, 0.0229, LR: 0.002000
# Step 110, Train Loss: -0.0449, Dev Loss: 0.0077, Dev Loss confidence interval: -0.0042, 0.0195, LR: 0.002000
# Step 120, Train Loss: -0.0513, Dev Loss: 0.0024, Dev Loss confidence interval: -0.0095, 0.0144, LR: 0.002000
# Step 130, Train Loss: -0.0595, Dev Loss: -0.0053, Dev Loss confidence interval: -0.0171, 0.0066, LR: 0.002000
# Step 140, Train Loss: -0.0713, Dev Loss: -0.0206, Dev Loss confidence interval: -0.0323, -0.0089, LR: 0.002000
# Step 150, Train Loss: -0.0821, Dev Loss: -0.0351, Dev Loss confidence interval: -0.0467, -0.0234, LR: 0.002000
# Step 160, Train Loss: -0.0961, Dev Loss: -0.0500, Dev Loss confidence interval: -0.0615, -0.0384, LR: 0.002000
# Step 170, Train Loss: -0.1231, Dev Loss: -0.0758, Dev Loss confidence interval: -0.0873, -0.0642, LR: 0.002000
# Step 180, Train Loss: -0.1602, Dev Loss: -0.1123, Dev Loss confidence interval: -0.1244, -0.1001, LR: 0.002000
# Step 190, Train Loss: -0.1870, Dev Loss: -0.1368, Dev Loss confidence interval: -0.1492, -0.1245, LR: 0.002000
# Step 200, Train Loss: -0.2086, Dev Loss: -0.1627, Dev Loss confidence interval: -0.1747, -0.1506, LR: 0.001000
# Step 210, Train Loss: -0.2155, Dev Loss: -0.1687, Dev Loss confidence interval: -0.1810, -0.1565, LR: 0.001000
# Step 220, Train Loss: -0.2201, Dev Loss: -0.1728, Dev Loss confidence interval: -0.1850, -0.1605, LR: 0.001000
# Step 230, Train Loss: -0.2267, Dev Loss: -0.1798, Dev Loss confidence interval: -0.1920, -0.1675, LR: 0.001000
# Step 240, Train Loss: -0.2284, Dev Loss: -0.1812, Dev Loss confidence interval: -0.1933, -0.1690, LR: 0.001000
# Step 250, Train Loss: -0.2326, Dev Loss: -0.1863, Dev Loss confidence interval: -0.1985, -0.1742, LR: 0.001000
# Step 260, Train Loss: -0.2354, Dev Loss: -0.1913, Dev Loss confidence interval: -0.2034, -0.1793, LR: 0.001000
# Step 270, Train Loss: -0.2421, Dev Loss: -0.1993, Dev Loss confidence interval: -0.2114, -0.1873, LR: 0.001000
# Step 280, Train Loss: -0.2460, Dev Loss: -0.2063, Dev Loss confidence interval: -0.2183, -0.1944, LR: 0.001000
# Step 290, Train Loss: -0.2543, Dev Loss: -0.2299, Dev Loss confidence interval: -0.2402, -0.2196, LR: 0.001000
# Step 300, Train Loss: -0.2595, Dev Loss: -0.2344, Dev Loss confidence interval: -0.2448, -0.2240, LR: 0.001000
# Step 310, Train Loss: -0.2608, Dev Loss: -0.2345, Dev Loss confidence interval: -0.2449, -0.2242, LR: 0.001000
# Step 320, Train Loss: -0.2616, Dev Loss: -0.2364, Dev Loss confidence interval: -0.2468, -0.2260, LR: 0.001000
# Step 330, Train Loss: -0.2632, Dev Loss: -0.2237, Dev Loss confidence interval: -0.2356, -0.2118, LR: 0.001000
# Step 340, Train Loss: -0.2671, Dev Loss: -0.2416, Dev Loss confidence interval: -0.2520, -0.2313, LR: 0.001000
# Step 350, Train Loss: -0.2661, Dev Loss: -0.2369, Dev Loss confidence interval: -0.2473, -0.2265, LR: 0.001000
# Step 360, Train Loss: -0.2714, Dev Loss: -0.2444, Dev Loss confidence interval: -0.2547, -0.2340, LR: 0.001000
# Step 370, Train Loss: -0.2745, Dev Loss: -0.2475, Dev Loss confidence interval: -0.2578, -0.2371, LR: 0.001000
# Step 380, Train Loss: -0.2732, Dev Loss: -0.2442, Dev Loss confidence interval: -0.2545, -0.2338, LR: 0.001000
# Step 390, Train Loss: -0.2788, Dev Loss: -0.2506, Dev Loss confidence interval: -0.2610, -0.2402, LR: 0.001000
# Step 400, Train Loss: -0.2741, Dev Loss: -0.2353, Dev Loss confidence interval: -0.2473, -0.2233, LR: 0.000500
# Best epoch: 390
# Final Train Loss: -0.2788, Final Train Loss confidence interval: -0.2853, -0.2723
# Final Dev Loss: -0.2506, Final Dev Loss confidence interval: -0.2612, -0.2400
# Test Loss: -0.2669, Test Loss confidence interval: -0.2825, -0.2514

# %%
import matplotlib.pyplot as plt
import numpy as np

steps = np.arange(0, len(train_losses) * 10, 10)  # Since you log every 10 steps

plt.figure(figsize=(10, 6))
plt.plot(steps, train_losses, label='Train Loss', linewidth=2)
plt.plot(steps, dev_losses, label='Dev Loss', linewidth=2)
plt.xlabel('Training Step')
plt.ylabel('Loss (Negative Log-Likelihood)')
plt.title(f"Training and Validation Loss of {dist_type}_NoReg_RV")
plt.legend()
plt.grid(True, alpha=0.3)
plt.axhline(y=0, color='r', linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()
