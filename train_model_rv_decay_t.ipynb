# %%
# output folder, dist type, optional parameter for dist type

import sys
import os
import torch

cwd = os.getcwd()
root = cwd.split("BernsteinMartingaleNet")[0] + "BernsteinMartingaleNet"
if root not in sys.path:
    sys.path.append(root)

from lib.utils import train_model, get_full_sequence_data_by_day
from lib.BLogistic import BLogistic, MixedBLogistic
from lib.DistHead import NormalHead, StudentTHead, SkewedStudentTHead
from lib.Michenkow import MichenkowManytoMany
assert torch.cuda.is_available()
device = torch.device('cuda')

# %%
dist_type  = "StudentT"
dist_param = ""
output_folder =  root + f"/MichenkowResults/{dist_type}NoReg_RV_Decay/"

# %%
dist_head = None
if dist_type == "Normal":
    dist_head = NormalHead(device)
elif dist_type == "StudentT":
    dist_head = StudentTHead(device)
elif dist_type == "SkewedStudentT":
    dist_head = SkewedStudentTHead(device)
elif dist_type == "BLogistic":
    if dist_param == "":
        raise ValueError("BLogistic dist type requires a degree parameter")
    dof = int(dist_param)
    dist_head = BLogistic(dof - 2, device)
elif dist_type == "MixedBLogistic":
    if dist_param == "":
        raise ValueError("MixedBLogistic dist type requires a degree parameter")
    dof = int(dist_param)
    dist_head = MixedBLogistic(dof, device)
else:
    raise ValueError(f"Invalid dist type: {dist_type}")

folder_path = root + "/MarketData/historical_data"

# %%
train, dev, test = get_full_sequence_data_by_day(folder_path, 0.2, 0.2, force_recompute=True)
print("train", train.shape)
print("dev", dev.shape)
print("test", test.shape)
# Out:
# skipping 2020-11-27
# skipping 2020-12-24
# skipping 2021-11-26
# skipping 2022-11-25
# skipping 2023-07-03
# skipping 2023-11-24
# skipping 2024-07-03
# skipping 2024-11-29
# skipping 2024-12-24
# skipping 2025-07-03
# train (748, 391, 3)
# dev (249, 391, 3)
# test (249, 391, 3)

# %%
train = torch.tensor(train, device=device)
dev = torch.tensor(dev, device=device)
test = torch.tensor(test, device=device)

train_xs = train[:, :-1, 0:3]
dev_xs = dev[:, :-1, 0:3]
test_xs = test[:, :-1, 0:3]

train_ys = train[:, 1:, 0]
dev_ys = dev[:, 1:, 0]
test_ys = test[:, 1:, 0]

std_x = torch.sqrt((train_xs**2).mean(dim=(0, 1)))  # Shape: (2,)
mean_x = train_xs.mean(dim=(0, 1))

print("std x:", std_x)
print("mean_x:", mean_x)

std_y = torch.sqrt((train_ys**2).mean(dim=(0, 1)))  # Shape: (2,)
mean_y = train_ys.mean(dim=(0, 1))

print("std y:", std_y)
print("mean y:", mean_y)

train_xs = (train_xs-mean_x) / std_x
dev_xs = (dev_xs-mean_x) / std_x
test_xs = (test_xs-mean_x) / std_x
train_ys = (train_ys-mean_y) / std_y
dev_ys = (dev_ys-mean_y) / std_y
test_ys = (test_ys-mean_y) / std_y

print("X train:", train_xs.shape, "y train", train_ys.shape)
print("X dev:", dev_xs.shape, "y dev", dev_ys.shape)
print("X test:", test_xs.shape, "y test", test_ys.shape)
# Out:
# std x: tensor([4.2369e-04, 5.0592e-07, 1.3484e+04], device='cuda:0')
# mean_x: tensor([-2.3330e-07,  1.7856e-07,  1.1670e+04], device='cuda:0')
# std y: tensor(0.0004, device='cuda:0')
# mean y: tensor(-2.1644e-07, device='cuda:0')
# X train: torch.Size([748, 390, 3]) y train torch.Size([748, 390])
# X dev: torch.Size([249, 390, 3]) y dev torch.Size([249, 390])
# X test: torch.Size([249, 390, 3]) y test torch.Size([249, 390])

# %%
lr = 0.002
decay_step = 200
decay_gamma = 0.5
weight_decay = 0
weight_decay = 0.000
num_steps = 400 + 1
batch_size = 1024

# %%
m2m_model = MichenkowManytoMany(dist_head, device, feature_size=train_xs.shape[2])

model, train_losses, dev_losses = train_model(m2m_model,
                                              train_xs, train_ys, dev_xs, dev_ys, test_xs,test_ys, lr, weight_decay, num_steps, batch_size=batch_size, device=device, output_folder=output_folder, lr_decay_step=decay_step, lr_decay_gamma=decay_gamma)
# Out:
# Initializing LSTM with dist=StudentTHead, dof=2
# num batches 0
# Init, Train Loss: 1.3060, Dev Loss: 1.3197, Dev Loss confidence interval: 1.3144, 1.3249
# Step 0, Train Loss: 1.3043, Dev Loss: 1.3181, Dev Loss confidence interval: 1.3128, 1.3233, LR: 0.002000
# Step 10, Train Loss: 1.2480, Dev Loss: 1.2690, Dev Loss confidence interval: 1.2624, 1.2757, LR: 0.002000
# Step 20, Train Loss: 1.2064, Dev Loss: 1.2309, Dev Loss confidence interval: 1.2239, 1.2378, LR: 0.002000
# Step 30, Train Loss: 1.1871, Dev Loss: 1.2082, Dev Loss confidence interval: 1.2020, 1.2144, LR: 0.002000
# Step 40, Train Loss: 1.1574, Dev Loss: 1.1809, Dev Loss confidence interval: 1.1747, 1.1872, LR: 0.002000
# Step 50, Train Loss: 1.1323, Dev Loss: 1.1550, Dev Loss confidence interval: 1.1484, 1.1616, LR: 0.002000
# Step 60, Train Loss: 1.1296, Dev Loss: 1.1526, Dev Loss confidence interval: 1.1458, 1.1593, LR: 0.002000
# Step 70, Train Loss: 1.1224, Dev Loss: 1.1460, Dev Loss confidence interval: 1.1397, 1.1523, LR: 0.002000
# Step 80, Train Loss: 1.1135, Dev Loss: 1.1368, Dev Loss confidence interval: 1.1302, 1.1433, LR: 0.002000
# Step 90, Train Loss: 1.1026, Dev Loss: 1.1256, Dev Loss confidence interval: 1.1191, 1.1320, LR: 0.002000
# Step 100, Train Loss: 1.0939, Dev Loss: 1.1166, Dev Loss confidence interval: 1.1103, 1.1230, LR: 0.002000
# Step 110, Train Loss: 1.0896, Dev Loss: 1.1124, Dev Loss confidence interval: 1.1062, 1.1186, LR: 0.002000
# Step 120, Train Loss: 1.0871, Dev Loss: 1.1099, Dev Loss confidence interval: 1.1037, 1.1162, LR: 0.002000
# Step 130, Train Loss: 1.0855, Dev Loss: 1.1084, Dev Loss confidence interval: 1.1023, 1.1146, LR: 0.002000
# Step 140, Train Loss: 1.0847, Dev Loss: 1.1079, Dev Loss confidence interval: 1.1018, 1.1140, LR: 0.002000
# Step 150, Train Loss: 1.0827, Dev Loss: 1.1059, Dev Loss confidence interval: 1.0996, 1.1122, LR: 0.002000
# Step 160, Train Loss: 1.0816, Dev Loss: 1.1048, Dev Loss confidence interval: 1.0985, 1.1110, LR: 0.002000
# Step 170, Train Loss: 1.0817, Dev Loss: 1.1051, Dev Loss confidence interval: 1.0990, 1.1111, LR: 0.002000
# Step 180, Train Loss: 1.0803, Dev Loss: 1.1038, Dev Loss confidence interval: 1.0977, 1.1100, LR: 0.002000
# Step 190, Train Loss: 1.0795, Dev Loss: 1.1029, Dev Loss confidence interval: 1.0967, 1.1092, LR: 0.002000
# Step 200, Train Loss: 1.0789, Dev Loss: 1.1025, Dev Loss confidence interval: 1.0963, 1.1087, LR: 0.001000
# Step 210, Train Loss: 1.0787, Dev Loss: 1.1023, Dev Loss confidence interval: 1.0962, 1.1085, LR: 0.001000
# Step 220, Train Loss: 1.0784, Dev Loss: 1.1020, Dev Loss confidence interval: 1.0958, 1.1083, LR: 0.001000
# Step 230, Train Loss: 1.0782, Dev Loss: 1.1020, Dev Loss confidence interval: 1.0958, 1.1081, LR: 0.001000
# Step 240, Train Loss: 1.0780, Dev Loss: 1.1017, Dev Loss confidence interval: 1.0956, 1.1079, LR: 0.001000
# Step 250, Train Loss: 1.0779, Dev Loss: 1.1017, Dev Loss confidence interval: 1.0956, 1.1079, LR: 0.001000
# Step 260, Train Loss: 1.0776, Dev Loss: 1.1015, Dev Loss confidence interval: 1.0953, 1.1077, LR: 0.001000
# Step 270, Train Loss: 1.0774, Dev Loss: 1.1013, Dev Loss confidence interval: 1.0951, 1.1075, LR: 0.001000
# Step 280, Train Loss: 1.0772, Dev Loss: 1.1012, Dev Loss confidence interval: 1.0950, 1.1074, LR: 0.001000
# Step 290, Train Loss: 1.0775, Dev Loss: 1.1015, Dev Loss confidence interval: 1.0954, 1.1077, LR: 0.001000
# Step 300, Train Loss: 1.0769, Dev Loss: 1.1010, Dev Loss confidence interval: 1.0948, 1.1072, LR: 0.001000
# Step 310, Train Loss: 1.0766, Dev Loss: 1.1008, Dev Loss confidence interval: 1.0946, 1.1071, LR: 0.001000
# Step 320, Train Loss: 1.0768, Dev Loss: 1.1009, Dev Loss confidence interval: 1.0948, 1.1071, LR: 0.001000
# Step 330, Train Loss: 1.0763, Dev Loss: 1.1005, Dev Loss confidence interval: 1.0943, 1.1067, LR: 0.001000
# Step 340, Train Loss: 1.0761, Dev Loss: 1.1004, Dev Loss confidence interval: 1.0942, 1.1066, LR: 0.001000
# Step 350, Train Loss: 1.0759, Dev Loss: 1.1002, Dev Loss confidence interval: 1.0940, 1.1064, LR: 0.001000
# Step 360, Train Loss: 1.0773, Dev Loss: 1.1015, Dev Loss confidence interval: 1.0955, 1.1074, LR: 0.001000
# Step 370, Train Loss: 1.0758, Dev Loss: 1.1003, Dev Loss confidence interval: 1.0941, 1.1065, LR: 0.001000
# Step 380, Train Loss: 1.0756, Dev Loss: 1.1001, Dev Loss confidence interval: 1.0938, 1.1063, LR: 0.001000
# Step 390, Train Loss: 1.0753, Dev Loss: 1.0999, Dev Loss confidence interval: 1.0936, 1.1061, LR: 0.001000
# Step 400, Train Loss: 1.0752, Dev Loss: 1.0998, Dev Loss confidence interval: 1.0936, 1.1060, LR: 0.000500
# Best epoch: 400
# Final Train Loss: 1.0752, Final Train Loss confidence interval: 1.0716, 1.0789
# Final Dev Loss: 1.0998, Final Dev Loss confidence interval: 1.0934, 1.1062
# Test Loss: 1.0474, Test Loss confidence interval: 1.0409, 1.0539

# %%
import matplotlib.pyplot as plt
import numpy as np

steps = np.arange(0, len(train_losses) * 10, 10)  # Since you log every 10 steps

plt.figure(figsize=(10, 6))
plt.plot(steps, train_losses, label='Train Loss', linewidth=2)
plt.plot(steps, dev_losses, label='Dev Loss', linewidth=2)
plt.xlabel('Training Step')
plt.ylabel('Loss (Negative Log-Likelihood)')
plt.title(f"Training and Validation Loss of {dist_type}_NoReg_RV_Decay")
plt.legend()
plt.grid(True, alpha=0.3)
plt.axhline(y=0, color='r', linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()
