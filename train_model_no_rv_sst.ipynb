# %%
# output folder, dist type, optional parameter for dist type

import sys
import os
import torch

cwd = os.getcwd()
root = cwd.split("BernsteinMartingaleNet")[0] + "BernsteinMartingaleNet"
if root not in sys.path:
    sys.path.append(root)

from lib.utils import train_model, get_full_sequence_data_by_day
from lib.BLogistic import BLogistic, MixedBLogistic
from lib.DistHead import NormalHead, StudentTHead, SkewedStudentTHead
from lib.Michenkow import MichenkowManytoMany
assert torch.cuda.is_available()
device = torch.device('cuda')

# %%
dist_type  = "SkewedStudentT"
dist_param = ""
output_folder =  root + f"/MichenkowResults/{dist_type}NoReg_NoRV/"

# %%
dist_head = None
if dist_type == "Normal":
    dist_head = NormalHead(device)
elif dist_type == "StudentT":
    dist_head = StudentTHead(device)
elif dist_type == "SkewedStudentT":
    dist_head = SkewedStudentTHead(device)
elif dist_type == "BLogistic":
    if dist_param == "":
        raise ValueError("BLogistic dist type requires a degree parameter")
    dof = int(dist_param)
    dist_head = BLogistic(dof - 2, device)
elif dist_type == "MixedBLogistic":
    if dist_param == "":
        raise ValueError("MixedBLogistic dist type requires a degree parameter")
    dof = int(dist_param)
    dist_head = MixedBLogistic(dof, device)
else:
    raise ValueError(f"Invalid dist type: {dist_type}")

folder_path = root + "/MarketData/historical_data"

# %%
train, dev, test = get_full_sequence_data_by_day(folder_path, 0.2, 0.2, force_recompute=True)
print("train", train.shape)
print("dev", dev.shape)
print("test", test.shape)
# Out:
# skipping 2020-11-27
# skipping 2020-12-24
# skipping 2021-11-26
# skipping 2022-11-25
# skipping 2023-07-03
# skipping 2023-11-24
# skipping 2024-07-03
# skipping 2024-11-29
# skipping 2024-12-24
# skipping 2025-07-03
# train (748, 391, 3)
# dev (249, 391, 3)
# test (249, 391, 3)

# %%
train = torch.tensor(train, device=device)
dev = torch.tensor(dev, device=device)
test = torch.tensor(test, device=device)

train_xs = train[:, :-1, 0:1]
dev_xs = dev[:, :-1, 0:1]
test_xs = test[:, :-1, 0:1]

train_ys = train[:, 1:, 0]
dev_ys = dev[:, 1:, 0]
test_ys = test[:, 1:, 0]

std_x = torch.sqrt((train_xs**2).mean(dim=(0, 1)))  # Shape: (2,)
mean_x = train_xs.mean(dim=(0, 1))

print("std x:", std_x)
print("mean_x:", mean_x)

std_y = torch.sqrt((train_ys**2).mean(dim=(0, 1)))  # Shape: (2,)
mean_y = train_ys.mean(dim=(0, 1))

print("std y:", std_y)
print("mean y:", mean_y)

train_xs = (train_xs-mean_x) / std_x
dev_xs = (dev_xs-mean_x) / std_x
test_xs = (test_xs-mean_x) / std_x
train_ys = (train_ys-mean_y) / std_y
dev_ys = (dev_ys-mean_y) / std_y
test_ys = (test_ys-mean_y) / std_y

print("X train:", train_xs.shape, "y train", train_ys.shape)
print("X dev:", dev_xs.shape, "y dev", dev_ys.shape)
print("X test:", test_xs.shape, "y test", test_ys.shape)
# Out:
# std x: tensor([0.0004], device='cuda:0')
# mean_x: tensor([-2.3330e-07], device='cuda:0')
# std y: tensor(0.0004, device='cuda:0')
# mean y: tensor(-2.1644e-07, device='cuda:0')
# X train: torch.Size([748, 390, 1]) y train torch.Size([748, 390])
# X dev: torch.Size([249, 390, 1]) y dev torch.Size([249, 390])
# X test: torch.Size([249, 390, 1]) y test torch.Size([249, 390])

# %%
lr = 0.002
decay_step = 200
decay_gamma = 0.5
weight_decay = 0
weight_decay = 0.000
num_steps = 400 + 1
batch_size = 1024

# %%
m2m_model = MichenkowManytoMany(dist_head, device, feature_size=1)

model, train_losses, dev_losses = train_model(m2m_model,
                                              train_xs, train_ys, dev_xs, dev_ys, test_xs,test_ys, lr, weight_decay, num_steps, batch_size=batch_size, device=device, output_folder=output_folder, lr_decay_step=decay_step, lr_decay_gamma=decay_gamma)
# Out:
# Initializing LSTM with dist=SkewedStudentTHead, dof=3
# num batches 0
# Init, Train Loss: 1.5388, Dev Loss: 1.5419, Dev Loss confidence interval: 1.5371, 1.5467
# Step 0, Train Loss: 1.5295, Dev Loss: 1.5328, Dev Loss confidence interval: 1.5280, 1.5377, LR: 0.002000
# Step 10, Train Loss: 1.2672, Dev Loss: 1.2840, Dev Loss confidence interval: 1.2775, 1.2906, LR: 0.002000
# Step 20, Train Loss: 1.2612, Dev Loss: 1.2828, Dev Loss confidence interval: 1.2754, 1.2902, LR: 0.002000
# Step 30, Train Loss: 1.2544, Dev Loss: 1.2720, Dev Loss confidence interval: 1.2655, 1.2786, LR: 0.002000
# Step 40, Train Loss: 1.2511, Dev Loss: 1.2701, Dev Loss confidence interval: 1.2631, 1.2770, LR: 0.002000
# Step 50, Train Loss: 1.2507, Dev Loss: 1.2701, Dev Loss confidence interval: 1.2630, 1.2772, LR: 0.002000
# Step 60, Train Loss: 1.2497, Dev Loss: 1.2678, Dev Loss confidence interval: 1.2609, 1.2746, LR: 0.002000
# Step 70, Train Loss: 1.2481, Dev Loss: 1.2670, Dev Loss confidence interval: 1.2600, 1.2740, LR: 0.002000
# Step 80, Train Loss: 1.2493, Dev Loss: 1.2679, Dev Loss confidence interval: 1.2609, 1.2749, LR: 0.002000
# Step 90, Train Loss: 1.2494, Dev Loss: 1.2676, Dev Loss confidence interval: 1.2607, 1.2746, LR: 0.002000
# Step 100, Train Loss: 1.2492, Dev Loss: 1.2677, Dev Loss confidence interval: 1.2607, 1.2747, LR: 0.002000
# Step 110, Train Loss: 1.2491, Dev Loss: 1.2674, Dev Loss confidence interval: 1.2605, 1.2744, LR: 0.002000
# Step 120, Train Loss: 1.2489, Dev Loss: 1.2674, Dev Loss confidence interval: 1.2604, 1.2744, LR: 0.002000
# Step 130, Train Loss: 1.2486, Dev Loss: 1.2670, Dev Loss confidence interval: 1.2601, 1.2740, LR: 0.002000
# Step 140, Train Loss: 1.2479, Dev Loss: 1.2665, Dev Loss confidence interval: 1.2595, 1.2735, LR: 0.002000
# Step 150, Train Loss: 1.2428, Dev Loss: 1.2638, Dev Loss confidence interval: 1.2569, 1.2708, LR: 0.002000
# Step 160, Train Loss: 1.2282, Dev Loss: 1.2519, Dev Loss confidence interval: 1.2451, 1.2587, LR: 0.002000
# Step 170, Train Loss: 1.2370, Dev Loss: 1.2599, Dev Loss confidence interval: 1.2529, 1.2669, LR: 0.002000
# Step 180, Train Loss: 1.2415, Dev Loss: 1.2644, Dev Loss confidence interval: 1.2572, 1.2716, LR: 0.002000
# Step 190, Train Loss: 1.2444, Dev Loss: 1.2637, Dev Loss confidence interval: 1.2568, 1.2706, LR: 0.002000
# Step 200, Train Loss: 1.2394, Dev Loss: 1.2622, Dev Loss confidence interval: 1.2552, 1.2693, LR: 0.001000
# Step 210, Train Loss: 1.2372, Dev Loss: 1.2582, Dev Loss confidence interval: 1.2512, 1.2651, LR: 0.001000
# Step 220, Train Loss: 1.2282, Dev Loss: 1.2491, Dev Loss confidence interval: 1.2423, 1.2558, LR: 0.001000
# Step 230, Train Loss: 1.2047, Dev Loss: 1.2289, Dev Loss confidence interval: 1.2220, 1.2359, LR: 0.001000
# Step 240, Train Loss: 1.1888, Dev Loss: 1.2097, Dev Loss confidence interval: 1.2030, 1.2163, LR: 0.001000
# Step 250, Train Loss: 1.2003, Dev Loss: 1.2268, Dev Loss confidence interval: 1.2190, 1.2345, LR: 0.001000
# Step 260, Train Loss: 1.1762, Dev Loss: 1.2004, Dev Loss confidence interval: 1.1938, 1.2071, LR: 0.001000
# Step 270, Train Loss: 1.1679, Dev Loss: 1.1951, Dev Loss confidence interval: 1.1882, 1.2019, LR: 0.001000
# Step 280, Train Loss: 1.1796, Dev Loss: 1.2010, Dev Loss confidence interval: 1.1952, 1.2067, LR: 0.001000
# Step 290, Train Loss: 1.1671, Dev Loss: 1.1922, Dev Loss confidence interval: 1.1851, 1.1993, LR: 0.001000
# Step 300, Train Loss: 1.1649, Dev Loss: 1.1885, Dev Loss confidence interval: 1.1813, 1.1957, LR: 0.001000
# Step 310, Train Loss: 1.1576, Dev Loss: 1.1812, Dev Loss confidence interval: 1.1749, 1.1875, LR: 0.001000
# Step 320, Train Loss: 1.1523, Dev Loss: 1.1779, Dev Loss confidence interval: 1.1713, 1.1845, LR: 0.001000
# Step 330, Train Loss: 1.1522, Dev Loss: 1.1774, Dev Loss confidence interval: 1.1706, 1.1843, LR: 0.001000
# Step 340, Train Loss: 1.1484, Dev Loss: 1.1708, Dev Loss confidence interval: 1.1643, 1.1773, LR: 0.001000
# Step 350, Train Loss: 1.1553, Dev Loss: 1.1787, Dev Loss confidence interval: 1.1718, 1.1856, LR: 0.001000
# Step 360, Train Loss: 1.1362, Dev Loss: 1.1567, Dev Loss confidence interval: 1.1503, 1.1632, LR: 0.001000
# Step 370, Train Loss: 1.1260, Dev Loss: 1.1440, Dev Loss confidence interval: 1.1380, 1.1499, LR: 0.001000
# Step 380, Train Loss: 1.1241, Dev Loss: 1.1478, Dev Loss confidence interval: 1.1414, 1.1542, LR: 0.001000
# Step 390, Train Loss: 1.1173, Dev Loss: 1.1373, Dev Loss confidence interval: 1.1311, 1.1435, LR: 0.001000
# Step 400, Train Loss: 1.1121, Dev Loss: 1.1301, Dev Loss confidence interval: 1.1239, 1.1363, LR: 0.000500
# Best epoch: 400
# Final Train Loss: 1.1121, Final Train Loss confidence interval: 1.1083, 1.1158
# Final Dev Loss: 1.1301, Final Dev Loss confidence interval: 1.1238, 1.1365
# Test Loss: 1.0814, Test Loss confidence interval: 1.0749, 1.0879

# %%
import matplotlib.pyplot as plt
import numpy as np

steps = np.arange(0, len(train_losses) * 10, 10)  # Since you log every 10 steps

plt.figure(figsize=(10, 6))
plt.plot(steps, train_losses, label='Train Loss', linewidth=2)
plt.plot(steps, dev_losses, label='Dev Loss', linewidth=2)
plt.xlabel('Training Step')
plt.ylabel('Loss (Negative Log-Likelihood)')
plt.title(f"Training and Validation Loss of {dist_type}_NoReg_NoRV")
plt.legend()
plt.grid(True, alpha=0.3)
plt.axhline(y=0, color='r', linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()
