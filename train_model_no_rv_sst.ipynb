# %%
# output folder, dist type, optional parameter for dist type

import sys
import os
import torch

cwd = os.getcwd()
root = cwd.split("BernsteinMartingaleNet")[0] + "BernsteinMartingaleNet"
if root not in sys.path:
    sys.path.append(root)

from lib.utils import train_model, get_full_sequence_data_by_day
from lib.BLogistic import BLogistic, MixedBLogistic
from lib.DistHead import NormalHead, StudentTHead, SkewedStudentTHead
from lib.Michenkow import MichenkowManytoMany
assert torch.cuda.is_available()
device = torch.device('cuda')

# %%
dist_type  = "SkewedStudentT"
dist_param = ""
output_folder =  root + f"/MichenkowResults/{dist_type}NoReg_NoRV/"

# %%
dist_head = None
if dist_type == "Normal":
    dist_head = NormalHead(device)
elif dist_type == "StudentT":
    dist_head = StudentTHead(device)
elif dist_type == "SkewedStudentT":
    dist_head = SkewedStudentTHead(device)
elif dist_type == "BLogistic":
    if dist_param == "":
        raise ValueError("BLogistic dist type requires a degree parameter")
    dof = int(dist_param)
    dist_head = BLogistic(dof - 2, device)
elif dist_type == "MixedBLogistic":
    if dist_param == "":
        raise ValueError("MixedBLogistic dist type requires a degree parameter")
    dof = int(dist_param)
    dist_head = MixedBLogistic(dof, device)
else:
    raise ValueError(f"Invalid dist type: {dist_type}")

folder_path = root + "/MarketData/historical_data"

# %%
train, dev, test = get_full_sequence_data_by_day(folder_path, 0.2, 0.2, force_recompute=True)
print("train", train.shape)
print("dev", dev.shape)
print("test", test.shape)
# Out:
# skipping 2020-11-27
# skipping 2020-12-24
# skipping 2021-11-26
# skipping 2022-11-25
# skipping 2023-07-03
# skipping 2023-11-24
# skipping 2024-07-03
# skipping 2024-11-29
# skipping 2024-12-24
# skipping 2025-07-03
# 1246
# train (748, 391, 3)
# dev (249, 391, 3)
# test (249, 391, 3)

# %%
train = torch.tensor(train, device=device)
dev = torch.tensor(dev, device=device)
test = torch.tensor(test, device=device)

train_xs = train[:, :-1, 0:1]
dev_xs = dev[:, :-1, 0:1]
test_xs = test[:, :-1, 0:1]

train_ys = train[:, 1:, 1]
dev_ys = dev[:, 1:, 1]
test_ys = test[:, 1:, 1]

std_x = torch.sqrt((train_xs**2).mean(dim=(0, 1)))  # Shape: (2,)
mean_x = train_xs.mean(dim=(0, 1))

print("std x:", std_x)
print("mean_x:", mean_x)

std_y = torch.sqrt((train_ys**2).mean(dim=(0, 1)))  # Shape: (2,)
mean_y = train_ys.mean(dim=(0, 1))

print("std y:", std_y)
print("mean y:", mean_y)

train_xs = (train_xs-mean_x) / std_x
dev_xs = (dev_xs-mean_x) / std_x
test_xs = (test_xs-mean_x) / std_x
train_ys = (train_ys-mean_y) / std_y
dev_ys = (dev_ys-mean_y) / std_y
test_ys = (test_ys-mean_y) / std_y

print("X train:", train_xs.shape, "y train", train_ys.shape)
print("X dev:", dev_xs.shape, "y dev", dev_ys.shape)
print("X test:", test_xs.shape, "y test", test_ys.shape)
# Out:
# std x: tensor([0.0004], device='cuda:0')
# mean_x: tensor([-2.3330e-07], device='cuda:0')
# std y: tensor(5.1853e-07, device='cuda:0')
# mean y: tensor(1.7846e-07, device='cuda:0')
# X train: torch.Size([748, 390, 1]) y train torch.Size([748, 390])
# X dev: torch.Size([249, 390, 1]) y dev torch.Size([249, 390])
# X test: torch.Size([249, 390, 1]) y test torch.Size([249, 390])

# %%
lr = 0.002
decay_step = 200
decay_gamma = 0.5
weight_decay = 0
weight_decay = 0.000
num_steps = 400 + 1
batch_size = 1024

# %%
m2m_model = MichenkowManytoMany(dist_head, device, feature_size=1)

model, train_losses, dev_losses = train_model(m2m_model,
                                              train_xs, train_ys, dev_xs, dev_ys, test_xs,test_ys, lr, weight_decay, num_steps, batch_size=batch_size, device=device, output_folder=output_folder, lr_decay_step=decay_step, lr_decay_gamma=decay_gamma)
# Out:
# Initializing LSTM with dist=SkewedStudentTHead, dof=3
# num batches 0
# Init, Train Loss: 1.4294, Dev Loss: 1.4064, Dev Loss confidence interval: 1.4039, 1.4090
# Step 0, Train Loss: 1.4157, Dev Loss: 1.3928, Dev Loss confidence interval: 1.3902, 1.3954, LR: 0.002000
# Step 10, Train Loss: 0.8113, Dev Loss: 0.7969, Dev Loss confidence interval: 0.7932, 0.8006, LR: 0.002000
# Step 20, Train Loss: 0.2286, Dev Loss: 0.2398, Dev Loss confidence interval: 0.2337, 0.2459, LR: 0.002000
# Step 30, Train Loss: 0.0081, Dev Loss: 0.0283, Dev Loss confidence interval: 0.0205, 0.0360, LR: 0.002000
# Step 40, Train Loss: -0.0730, Dev Loss: -0.0457, Dev Loss confidence interval: -0.0535, -0.0379, LR: 0.002000
# Step 50, Train Loss: -0.1015, Dev Loss: -0.0690, Dev Loss confidence interval: -0.0769, -0.0610, LR: 0.002000
# Step 60, Train Loss: -0.1276, Dev Loss: -0.0901, Dev Loss confidence interval: -0.0983, -0.0819, LR: 0.002000
# Step 70, Train Loss: -0.1507, Dev Loss: -0.1096, Dev Loss confidence interval: -0.1180, -0.1011, LR: 0.002000
# Step 80, Train Loss: -0.1534, Dev Loss: -0.1057, Dev Loss confidence interval: -0.1146, -0.0969, LR: 0.002000
# Step 90, Train Loss: -0.1611, Dev Loss: -0.1093, Dev Loss confidence interval: -0.1185, -0.1001, LR: 0.002000
# Step 100, Train Loss: -0.1591, Dev Loss: -0.1050, Dev Loss confidence interval: -0.1145, -0.0956, LR: 0.002000
# Step 110, Train Loss: -0.1554, Dev Loss: -0.0999, Dev Loss confidence interval: -0.1095, -0.0903, LR: 0.002000
# Step 120, Train Loss: -0.1528, Dev Loss: -0.0962, Dev Loss confidence interval: -0.1058, -0.0866, LR: 0.002000
# Step 130, Train Loss: -0.1666, Dev Loss: -0.1080, Dev Loss confidence interval: -0.1174, -0.0985, LR: 0.002000
# Step 140, Train Loss: -0.2162, Dev Loss: -0.1628, Dev Loss confidence interval: -0.1717, -0.1539, LR: 0.002000
# Step 150, Train Loss: -0.2591, Dev Loss: -0.2031, Dev Loss confidence interval: -0.2118, -0.1944, LR: 0.002000
# Step 160, Train Loss: -0.3214, Dev Loss: -0.2634, Dev Loss confidence interval: -0.2718, -0.2550, LR: 0.002000
# Step 170, Train Loss: -0.3807, Dev Loss: -0.3402, Dev Loss confidence interval: -0.3474, -0.3330, LR: 0.002000
# Step 180, Train Loss: -0.4719, Dev Loss: -0.4379, Dev Loss confidence interval: -0.4457, -0.4301, LR: 0.002000
# Step 190, Train Loss: -0.4708, Dev Loss: -0.4387, Dev Loss confidence interval: -0.4468, -0.4305, LR: 0.002000
# Step 200, Train Loss: -0.5829, Dev Loss: -0.5440, Dev Loss confidence interval: -0.5514, -0.5367, LR: 0.001000
# Step 210, Train Loss: -0.6671, Dev Loss: -0.6257, Dev Loss confidence interval: -0.6336, -0.6178, LR: 0.001000
# Step 220, Train Loss: -0.7190, Dev Loss: -0.6768, Dev Loss confidence interval: -0.6849, -0.6687, LR: 0.001000
# Step 230, Train Loss: -0.7614, Dev Loss: -0.7179, Dev Loss confidence interval: -0.7262, -0.7097, LR: 0.001000
# Step 240, Train Loss: -0.7938, Dev Loss: -0.7488, Dev Loss confidence interval: -0.7572, -0.7404, LR: 0.001000
# Step 250, Train Loss: -0.8194, Dev Loss: -0.7732, Dev Loss confidence interval: -0.7818, -0.7646, LR: 0.001000
# Step 260, Train Loss: -0.8430, Dev Loss: -0.7959, Dev Loss confidence interval: -0.8046, -0.7872, LR: 0.001000
# Step 270, Train Loss: -0.8611, Dev Loss: -0.8133, Dev Loss confidence interval: -0.8221, -0.8045, LR: 0.001000
# Step 280, Train Loss: -0.8759, Dev Loss: -0.8272, Dev Loss confidence interval: -0.8360, -0.8183, LR: 0.001000
# Step 290, Train Loss: -0.8852, Dev Loss: -0.8363, Dev Loss confidence interval: -0.8452, -0.8275, LR: 0.001000
# Step 300, Train Loss: -0.8960, Dev Loss: -0.8459, Dev Loss confidence interval: -0.8548, -0.8369, LR: 0.001000
# Step 310, Train Loss: -0.9020, Dev Loss: -0.8513, Dev Loss confidence interval: -0.8602, -0.8424, LR: 0.001000
# Step 320, Train Loss: -0.9087, Dev Loss: -0.8575, Dev Loss confidence interval: -0.8664, -0.8485, LR: 0.001000
# Step 330, Train Loss: -0.9129, Dev Loss: -0.8600, Dev Loss confidence interval: -0.8690, -0.8509, LR: 0.001000
# Step 340, Train Loss: -0.9208, Dev Loss: -0.8669, Dev Loss confidence interval: -0.8759, -0.8578, LR: 0.001000
# Step 350, Train Loss: -0.9155, Dev Loss: -0.8604, Dev Loss confidence interval: -0.8696, -0.8512, LR: 0.001000
# Step 360, Train Loss: -0.9205, Dev Loss: -0.8660, Dev Loss confidence interval: -0.8751, -0.8568, LR: 0.001000
# Step 370, Train Loss: -0.9294, Dev Loss: -0.8731, Dev Loss confidence interval: -0.8824, -0.8638, LR: 0.001000
# Step 380, Train Loss: -0.9343, Dev Loss: -0.8784, Dev Loss confidence interval: -0.8876, -0.8691, LR: 0.001000
# Step 390, Train Loss: -0.9413, Dev Loss: -0.8854, Dev Loss confidence interval: -0.8946, -0.8763, LR: 0.001000
# Step 400, Train Loss: -0.9437, Dev Loss: -0.8872, Dev Loss confidence interval: -0.8964, -0.8780, LR: 0.000500
# Best epoch: 400
# Final Train Loss: -0.9437, Final Train Loss confidence interval: -0.9491, -0.9383
# Final Dev Loss: -0.8872, Final Dev Loss confidence interval: -0.8966, -0.8778
# Test Loss: -0.9848, Test Loss confidence interval: -0.9946, -0.9750

# %%
import matplotlib.pyplot as plt
import numpy as np

steps = np.arange(0, len(train_losses) * 10, 10)  # Since you log every 10 steps

plt.figure(figsize=(10, 6))
plt.plot(steps, train_losses, label='Train Loss', linewidth=2)
plt.plot(steps, dev_losses, label='Dev Loss', linewidth=2)
plt.xlabel('Training Step')
plt.ylabel('Loss (Negative Log-Likelihood)')
plt.title(f"Training and Validation Loss of {dist_type}_NoReg_NoRV")
plt.legend()
plt.grid(True, alpha=0.3)
plt.axhline(y=0, color='r', linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()
